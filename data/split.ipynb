# %%
import json
from sklearn.model_selection import train_test_split

# %%
import json
import random
from itertools import permutations

def convert_label_studio_to_re_format(
    input_file, 
    output_file, 
    negative_ratio=0.5 
):
    """
    Chuyển đổi JSON export từ Label Studio sang định dạng train cho RBERT.
    Đã sửa để hỗ trợ cả Single Object JSON và List JSON.
    """
    
    try:
        with open(input_file, 'r', encoding='utf-8') as f:
            ls_data = json.load(f)
    except FileNotFoundError:
        print(f"Lỗi: Không tìm thấy file {input_file}")
        return []

    # --- SỬA LỖI QUAN TRỌNG: Chuẩn hóa dữ liệu về dạng List ---
    # Nếu file json chỉ chứa 1 object (bắt đầu bằng { "id":... }), ta gói nó vào list
    if isinstance(ls_data, dict):
        ls_data = [ls_data]
    
    final_data = []
    stats = {"positive": 0, "negative": 0, "relations": {}}

    for task in ls_data:
        # 1. Lấy văn bản gốc
        # Kiểm tra kỹ key chứa text (thường là 'text' hoặc 'sentence' tùy config Label Studio)
        data_block = task.get('data', {})
        text = data_block.get('text') or data_block.get('sentence')
        
        if not text:
            print(f"Bỏ qua Task ID {task.get('id', 'Unknown')}: Không tìm thấy text.")
            continue

        # 2. Parse Entities (Nodes)
        entities = {}
        annotations = task.get('annotations', [])
        if not annotations:
            continue
            
        # Lấy annotation đầu tiên (thường là bản mới nhất hoặc ground_truth)
        result = annotations[0].get('result', [])
        
        # Bước 2a: Map ID -> Entity Info
        for item in result:
            if item['type'] == 'labels':
                entity_id = item['id']
                value = item['value']
                
                # Lấy nhãn đầu tiên trong mảng labels
                label_type = value['labels'][0] if value.get('labels') else "Unknown"

                entities[entity_id] = {
                    'text': value['text'],
                    'start': value['start'],
                    'end': value['end'],
                    'type': label_type  # Quan trọng cho Type-Aware Model
                }

        # Bước 2b: Lấy Relations (Edges)
        existing_relations = set() 
        
        for item in result:
            if item['type'] == 'relation':
                from_id = item['from_id']
                to_id = item['to_id']
                relation_label = item['labels'][0] if item.get('labels') else "NO_RELATION"
                
                if from_id in entities and to_id in entities:
                    subj = entities[from_id]
                    obj = entities[to_id]
                    
                    sample = {
                        "text": text,
                        "relation": relation_label,
                        "subj": subj,
                        "obj": obj
                    }
                    final_data.append(sample)
                    existing_relations.add((from_id, to_id))
                    
                    stats["positive"] += 1
                    stats["relations"][relation_label] = stats["relations"].get(relation_label, 0) + 1

        # Bước 3: Negative Sampling (Tạo mẫu No_Relation)
        entity_ids = list(entities.keys())
        all_pairs = list(permutations(entity_ids, 2)) 
        
        potential_negatives = []
        for e1_id, e2_id in all_pairs:
            if (e1_id, e2_id) not in existing_relations:
                potential_negatives.append((e1_id, e2_id))
        
        # Logic lấy số lượng negative sample
        num_neg_to_take = int(len(existing_relations) * negative_ratio)
        
        # Nếu có entity nhưng chưa có relation nào, vẫn lấy 1 mẫu negative để model học
        if len(existing_relations) == 0 and len(potential_negatives) > 0 and negative_ratio > 0:
             num_neg_to_take = 1
        # Nếu tính ra 0 nhưng user muốn lấy (negative_ratio > 0) và có relations, tối thiểu lấy 1
        elif len(existing_relations) > 0 and num_neg_to_take == 0 and negative_ratio > 0:
             num_neg_to_take = 1

        random.shuffle(potential_negatives)
        selected_negatives = potential_negatives[:num_neg_to_take]
        
        for e1_id, e2_id in selected_negatives:
            subj = entities[e1_id]
            obj = entities[e2_id]
            
            sample = {
                "text": text,
                "relation": "No_Relation",
                "subj": subj,
                "obj": obj
            }
            final_data.append(sample)
            stats["negative"] += 1

    # Lưu file
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(final_data, f, ensure_ascii=False, indent=2)

    print("=== Conversion Completed ===")
    print(f"Total samples generated: {len(final_data)}")
    print(f"Positive samples: {stats['positive']}")
    print(f"Negative samples: {stats['negative']}")
    print("Relation Types Breakdown:", stats["relations"])
    return final_data

# --- CHẠY VỚI DỮ LIỆU CỦA BẠN ---
# Lưu đoạn JSON bạn đưa vào file tên 'dataset2.json' trước khi chạy
convert_label_studio_to_re_format("dataset2.json", "train_data_fixed.json", negative_ratio=1.0)
# Out:
# === Conversion Completed ===
# Total samples generated: 1185
# Positive samples: 488
# Negative samples: 697
# Relation Types Breakdown: {'TREATED_WITH': 98, 'CAUSES': 145, 'REVEALS': 23, 'HAS_MANIFESTATION': 210, 'NO_RELATION': 12}
# [{'text': 'bảng phân loại teo thực quản của gross : giúp quyết định điều trị và tiên lượng bệnh nhóm a : teo thực quản không có lỗ dò ( 8% ) nhóm b : teo thực quản có lỗ dò ở đầu gần thực quản – khí quản ( &lt; 1% ) nhóm c : teo thực quản có lỗ dò ở đầu xa thực quản - khí quản ( 87% ) nhóm d : teo thực quản có lỗ dò ở hai đầu thực quản – khí quản ( &lt; 1% ) nhóm e : dò thực quản - khí quản không teo ( dò dạng h ) ( 4% ) nhóm f : hẹp thực quản ( &lt;1% ) các biện pháp điều trị bệnh teo thực quản nguyên tắc điều trị teo thực quản : chuyển viện sớm đến bệnh viện có khoa phẫu thuật nhi .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'teo thực quản',
#    'start': 510,
#    'end': 523,
#    'type': 'DISEASE'},
#   'obj': {'text': 'phẫu thuật',
#    'start': 564,
#    'end': 574,
#    'type': 'TREATMENT'}},
#  {'text': 'bảng phân loại teo thực quản của gross : giúp quyết định điều trị và tiên lượng bệnh nhóm a : teo thực quản không có lỗ dò ( 8% ) nhóm b : teo thực quản có lỗ dò ở đầu gần thực quản – khí quản ( &lt; 1% ) nhóm c : teo thực quản có lỗ dò ở đầu xa thực quản - khí quản ( 87% ) nhóm d : teo thực quản có lỗ dò ở hai đầu thực quản – khí quản ( &lt; 1% ) nhóm e : dò thực quản - khí quản không teo ( dò dạng h ) ( 4% ) nhóm f : hẹp thực quản ( &lt;1% ) các biện pháp điều trị bệnh teo thực quản nguyên tắc điều trị teo thực quản : chuyển viện sớm đến bệnh viện có khoa phẫu thuật nhi .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'teo thực quản',
#    'start': 284,
#    'end': 297,
#    'type': 'DISEASE'},
#   'obj': {'text': 'teo thực quản',
#    'start': 214,
#    'end': 227,
#    'type': 'DISEASE'}},
#  {'text': 'các phương pháp điều trị thoát vị bẹn ở trẻ chủ đề : nhi trẻ em thoát vị bẹn thoát vị đùi phẫu thuật thoát vị bẹn thoát vị bẹn ở trẻ em thoát vị bẹn ở người lớn',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'thoát vị bẹn', 'start': 25, 'end': 37, 'type': 'DISEASE'},
#   'obj': {'text': 'phẫu thuật', 'start': 90, 'end': 100, 'type': 'TREATMENT'}},
#  {'text': 'các phương pháp điều trị thoát vị bẹn ở trẻ chủ đề : nhi trẻ em thoát vị bẹn thoát vị đùi phẫu thuật thoát vị bẹn thoát vị bẹn ở trẻ em thoát vị bẹn ở người lớn',
#   'relation': 'No_Relation',
#   'subj': {'text': 'thoát vị bẹn',
#    'start': 136,
#    'end': 148,
#    'type': 'DISEASE'},
#   'obj': {'text': 'phẫu thuật', 'start': 90, 'end': 100, 'type': 'TREATMENT'}},
#  {'text': 'hormone thay đổi thay đổi nội tiết tố do thai kỳ , kinh nguyệt , sử dụng thuốc tránh thai hoặc điều kiện nội tiết như suy giáp có thể gây ra viêm mũi không dị ứng .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'thay đổi nội tiết tố do thai kỳ',
#    'start': 17,
#    'end': 48,
#    'type': 'CAUSE'},
#   'obj': {'text': 'viêm mũi không dị ứng',
#    'start': 141,
#    'end': 162,
#    'type': 'DISEASE'}},
#  {'text': 'hormone thay đổi thay đổi nội tiết tố do thai kỳ , kinh nguyệt , sử dụng thuốc tránh thai hoặc điều kiện nội tiết như suy giáp có thể gây ra viêm mũi không dị ứng .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'hormone thay đổi', 'start': 0, 'end': 16, 'type': 'CAUSE'},
#   'obj': {'text': 'viêm mũi không dị ứng',
#    'start': 141,
#    'end': 162,
#    'type': 'DISEASE'}},
#  {'text': 'hormone thay đổi thay đổi nội tiết tố do thai kỳ , kinh nguyệt , sử dụng thuốc tránh thai hoặc điều kiện nội tiết như suy giáp có thể gây ra viêm mũi không dị ứng .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'sử dụng thuốc tránh thai',
#    'start': 65,
#    'end': 89,
#    'type': 'CAUSE'},
#   'obj': {'text': 'viêm mũi không dị ứng',
#    'start': 141,
#    'end': 162,
#    'type': 'DISEASE'}},
#  {'text': 'hormone thay đổi thay đổi nội tiết tố do thai kỳ , kinh nguyệt , sử dụng thuốc tránh thai hoặc điều kiện nội tiết như suy giáp có thể gây ra viêm mũi không dị ứng .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'suy giáp', 'start': 118, 'end': 126, 'type': 'CAUSE'},
#   'obj': {'text': 'viêm mũi không dị ứng',
#    'start': 141,
#    'end': 162,
#    'type': 'DISEASE'}},
#  {'text': 'hormone thay đổi thay đổi nội tiết tố do thai kỳ , kinh nguyệt , sử dụng thuốc tránh thai hoặc điều kiện nội tiết như suy giáp có thể gây ra viêm mũi không dị ứng .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'kinh nguyệt', 'start': 51, 'end': 62, 'type': 'CAUSE'},
#   'obj': {'text': 'điều kiện nội tiết',
#    'start': 95,
#    'end': 113,
#    'type': 'CAUSE'}},
#  {'text': 'hormone thay đổi thay đổi nội tiết tố do thai kỳ , kinh nguyệt , sử dụng thuốc tránh thai hoặc điều kiện nội tiết như suy giáp có thể gây ra viêm mũi không dị ứng .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'sử dụng thuốc tránh thai',
#    'start': 65,
#    'end': 89,
#    'type': 'CAUSE'},
#   'obj': {'text': 'điều kiện nội tiết',
#    'start': 95,
#    'end': 113,
#    'type': 'CAUSE'}},
#  {'text': 'hormone thay đổi thay đổi nội tiết tố do thai kỳ , kinh nguyệt , sử dụng thuốc tránh thai hoặc điều kiện nội tiết như suy giáp có thể gây ra viêm mũi không dị ứng .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'hormone thay đổi', 'start': 0, 'end': 16, 'type': 'CAUSE'},
#   'obj': {'text': 'sử dụng thuốc tránh thai',
#    'start': 65,
#    'end': 89,
#    'type': 'CAUSE'}},
#  {'text': 'hormone thay đổi thay đổi nội tiết tố do thai kỳ , kinh nguyệt , sử dụng thuốc tránh thai hoặc điều kiện nội tiết như suy giáp có thể gây ra viêm mũi không dị ứng .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'viêm mũi không dị ứng',
#    'start': 141,
#    'end': 162,
#    'type': 'DISEASE'},
#   'obj': {'text': 'kinh nguyệt', 'start': 51, 'end': 62, 'type': 'CAUSE'}},
#  {'text': 'bệnh sốt rét là bệnh truyền nhiễm do loài ký sinh trùng plasmodium gây ra , gồm : plasmodium falciparum , plasmodium vivax , plasmodium malariae , plasmodium ovale và plasmodium knowlesi .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'ký sinh trùng plasmodium',
#    'start': 42,
#    'end': 66,
#    'type': 'CAUSE'},
#   'obj': {'text': 'bệnh sốt rét', 'start': 0, 'end': 12, 'type': 'DISEASE'}},
#  {'text': 'bệnh sốt rét là bệnh truyền nhiễm do loài ký sinh trùng plasmodium gây ra , gồm : plasmodium falciparum , plasmodium vivax , plasmodium malariae , plasmodium ovale và plasmodium knowlesi .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'plasmodium falciparum',
#    'start': 82,
#    'end': 103,
#    'type': 'CAUSE'},
#   'obj': {'text': 'bệnh sốt rét', 'start': 0, 'end': 12, 'type': 'DISEASE'}},
#  {'text': 'bệnh sốt rét là bệnh truyền nhiễm do loài ký sinh trùng plasmodium gây ra , gồm : plasmodium falciparum , plasmodium vivax , plasmodium malariae , plasmodium ovale và plasmodium knowlesi .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'plasmodium vivax',
#    'start': 106,
#    'end': 122,
#    'type': 'CAUSE'},
#   'obj': {'text': 'bệnh sốt rét', 'start': 0, 'end': 12, 'type': 'DISEASE'}},
#  {'text': 'bệnh sốt rét là bệnh truyền nhiễm do loài ký sinh trùng plasmodium gây ra , gồm : plasmodium falciparum , plasmodium vivax , plasmodium malariae , plasmodium ovale và plasmodium knowlesi .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'plasmodium malariae',
#    'start': 125,
#    'end': 144,
#    'type': 'CAUSE'},
#   'obj': {'text': 'bệnh sốt rét', 'start': 0, 'end': 12, 'type': 'DISEASE'}},
#  {'text': 'bệnh sốt rét là bệnh truyền nhiễm do loài ký sinh trùng plasmodium gây ra , gồm : plasmodium falciparum , plasmodium vivax , plasmodium malariae , plasmodium ovale và plasmodium knowlesi .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'plasmodium ovale',
#    'start': 147,
#    'end': 163,
#    'type': 'CAUSE'},
#   'obj': {'text': 'bệnh sốt rét', 'start': 0, 'end': 12, 'type': 'DISEASE'}},
#  {'text': 'bệnh sốt rét là bệnh truyền nhiễm do loài ký sinh trùng plasmodium gây ra , gồm : plasmodium falciparum , plasmodium vivax , plasmodium malariae , plasmodium ovale và plasmodium knowlesi .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'plasmodium knowlesi',
#    'start': 167,
#    'end': 186,
#    'type': 'CAUSE'},
#   'obj': {'text': 'bệnh sốt rét', 'start': 0, 'end': 12, 'type': 'DISEASE'}},
#  {'text': 'bệnh sốt rét là bệnh truyền nhiễm do loài ký sinh trùng plasmodium gây ra , gồm : plasmodium falciparum , plasmodium vivax , plasmodium malariae , plasmodium ovale và plasmodium knowlesi .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'plasmodium ovale',
#    'start': 147,
#    'end': 163,
#    'type': 'CAUSE'},
#   'obj': {'text': 'plasmodium falciparum',
#    'start': 82,
#    'end': 103,
#    'type': 'CAUSE'}},
#  {'text': 'bệnh sốt rét là bệnh truyền nhiễm do loài ký sinh trùng plasmodium gây ra , gồm : plasmodium falciparum , plasmodium vivax , plasmodium malariae , plasmodium ovale và plasmodium knowlesi .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'plasmodium malariae',
#    'start': 125,
#    'end': 144,
#    'type': 'CAUSE'},
#   'obj': {'text': 'plasmodium ovale',
#    'start': 147,
#    'end': 163,
#    'type': 'CAUSE'}},
#  {'text': 'bệnh sốt rét là bệnh truyền nhiễm do loài ký sinh trùng plasmodium gây ra , gồm : plasmodium falciparum , plasmodium vivax , plasmodium malariae , plasmodium ovale và plasmodium knowlesi .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'bệnh sốt rét', 'start': 0, 'end': 12, 'type': 'DISEASE'},
#   'obj': {'text': 'plasmodium ovale',
#    'start': 147,
#    'end': 163,
#    'type': 'CAUSE'}},
#  {'text': 'bệnh sốt rét là bệnh truyền nhiễm do loài ký sinh trùng plasmodium gây ra , gồm : plasmodium falciparum , plasmodium vivax , plasmodium malariae , plasmodium ovale và plasmodium knowlesi .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'plasmodium knowlesi',
#    'start': 167,
#    'end': 186,
#    'type': 'CAUSE'},
#   'obj': {'text': 'plasmodium vivax',
#    'start': 106,
#    'end': 122,
#    'type': 'CAUSE'}},
#  {'text': 'bệnh sốt rét là bệnh truyền nhiễm do loài ký sinh trùng plasmodium gây ra , gồm : plasmodium falciparum , plasmodium vivax , plasmodium malariae , plasmodium ovale và plasmodium knowlesi .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'plasmodium vivax',
#    'start': 106,
#    'end': 122,
#    'type': 'CAUSE'},
#   'obj': {'text': 'plasmodium ovale',
#    'start': 147,
#    'end': 163,
#    'type': 'CAUSE'}},
#  {'text': 'bệnh sốt rét là bệnh truyền nhiễm do loài ký sinh trùng plasmodium gây ra , gồm : plasmodium falciparum , plasmodium vivax , plasmodium malariae , plasmodium ovale và plasmodium knowlesi .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'plasmodium vivax',
#    'start': 106,
#    'end': 122,
#    'type': 'CAUSE'},
#   'obj': {'text': 'ký sinh trùng plasmodium',
#    'start': 42,
#    'end': 66,
#    'type': 'CAUSE'}},
#  {'text': 'mắc thoát vị đùi hiếm gặp , người phụ nữ tày khỏi bệnh sau 1 ngày mổ “đi lại dễ dàng không cần nạng , cảm giác ấy thật tuyệt” chủ đề : đùi thoát vị bẹn thoát vị đùi thoát vị bẹn trẻ em thoát vị bẹn ở người lớn phẫu thuật thoát vị đùi điều trị thoát vị đùi',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'thoát vị đùi',
#    'start': 221,
#    'end': 233,
#    'type': 'DISEASE'},
#   'obj': {'text': 'phẫu thuật',
#    'start': 210,
#    'end': 220,
#    'type': 'TREATMENT'}},
#  {'text': 'mắc thoát vị đùi hiếm gặp , người phụ nữ tày khỏi bệnh sau 1 ngày mổ “đi lại dễ dàng không cần nạng , cảm giác ấy thật tuyệt” chủ đề : đùi thoát vị bẹn thoát vị đùi thoát vị bẹn trẻ em thoát vị bẹn ở người lớn phẫu thuật thoát vị đùi điều trị thoát vị đùi',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'thoát vị bẹn',
#    'start': 139,
#    'end': 151,
#    'type': 'DISEASE'},
#   'obj': {'text': 'phẫu thuật',
#    'start': 210,
#    'end': 220,
#    'type': 'TREATMENT'}},
#  {'text': 'mắc thoát vị đùi hiếm gặp , người phụ nữ tày khỏi bệnh sau 1 ngày mổ “đi lại dễ dàng không cần nạng , cảm giác ấy thật tuyệt” chủ đề : đùi thoát vị bẹn thoát vị đùi thoát vị bẹn trẻ em thoát vị bẹn ở người lớn phẫu thuật thoát vị đùi điều trị thoát vị đùi',
#   'relation': 'No_Relation',
#   'subj': {'text': 'thoát vị đùi',
#    'start': 243,
#    'end': 255,
#    'type': 'DISEASE'},
#   'obj': {'text': 'thoát vị bẹn',
#    'start': 139,
#    'end': 151,
#    'type': 'DISEASE'}},
#  {'text': 'mắc thoát vị đùi hiếm gặp , người phụ nữ tày khỏi bệnh sau 1 ngày mổ “đi lại dễ dàng không cần nạng , cảm giác ấy thật tuyệt” chủ đề : đùi thoát vị bẹn thoát vị đùi thoát vị bẹn trẻ em thoát vị bẹn ở người lớn phẫu thuật thoát vị đùi điều trị thoát vị đùi',
#   'relation': 'No_Relation',
#   'subj': {'text': 'thoát vị đùi',
#    'start': 243,
#    'end': 255,
#    'type': 'DISEASE'},
#   'obj': {'text': 'phẫu thuật',
#    'start': 210,
#    'end': 220,
#    'type': 'TREATMENT'}},
#  {'text': 'đôi khi các vi khuẩn gây nhiễm trùng gây ra viêm nắp thanh quản ở nơi khác trong cơ thể , chẳng hạn như viêm phổi , viêm màng não hoặc nhiễm trùng máu ( nhiễm trùng huyết ) .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'vi khuẩn', 'start': 12, 'end': 20, 'type': 'CAUSE'},
#   'obj': {'text': 'nhiễm trùng', 'start': 25, 'end': 36, 'type': 'DISEASE'}},
#  {'text': 'đôi khi các vi khuẩn gây nhiễm trùng gây ra viêm nắp thanh quản ở nơi khác trong cơ thể , chẳng hạn như viêm phổi , viêm màng não hoặc nhiễm trùng máu ( nhiễm trùng huyết ) .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'vi khuẩn', 'start': 12, 'end': 20, 'type': 'CAUSE'},
#   'obj': {'text': 'viêm nắp thanh quản',
#    'start': 44,
#    'end': 63,
#    'type': 'DISEASE'}},
#  {'text': 'đôi khi các vi khuẩn gây nhiễm trùng gây ra viêm nắp thanh quản ở nơi khác trong cơ thể , chẳng hạn như viêm phổi , viêm màng não hoặc nhiễm trùng máu ( nhiễm trùng huyết ) .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'vi khuẩn', 'start': 12, 'end': 20, 'type': 'CAUSE'},
#   'obj': {'text': 'viêm phổi', 'start': 104, 'end': 113, 'type': 'DISEASE'}},
#  {'text': 'đôi khi các vi khuẩn gây nhiễm trùng gây ra viêm nắp thanh quản ở nơi khác trong cơ thể , chẳng hạn như viêm phổi , viêm màng não hoặc nhiễm trùng máu ( nhiễm trùng huyết ) .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'vi khuẩn', 'start': 12, 'end': 20, 'type': 'CAUSE'},
#   'obj': {'text': 'viêm màng não',
#    'start': 116,
#    'end': 129,
#    'type': 'DISEASE'}},
#  {'text': 'đôi khi các vi khuẩn gây nhiễm trùng gây ra viêm nắp thanh quản ở nơi khác trong cơ thể , chẳng hạn như viêm phổi , viêm màng não hoặc nhiễm trùng máu ( nhiễm trùng huyết ) .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'vi khuẩn', 'start': 12, 'end': 20, 'type': 'CAUSE'},
#   'obj': {'text': 'nhiễm trùng máu',
#    'start': 135,
#    'end': 150,
#    'type': 'DISEASE'}},
#  {'text': 'đôi khi các vi khuẩn gây nhiễm trùng gây ra viêm nắp thanh quản ở nơi khác trong cơ thể , chẳng hạn như viêm phổi , viêm màng não hoặc nhiễm trùng máu ( nhiễm trùng huyết ) .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'vi khuẩn', 'start': 12, 'end': 20, 'type': 'CAUSE'},
#   'obj': {'text': 'nhiễm trùng huyết',
#    'start': 153,
#    'end': 170,
#    'type': 'DISEASE'}},
#  {'text': 'đôi khi các vi khuẩn gây nhiễm trùng gây ra viêm nắp thanh quản ở nơi khác trong cơ thể , chẳng hạn như viêm phổi , viêm màng não hoặc nhiễm trùng máu ( nhiễm trùng huyết ) .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'viêm phổi', 'start': 104, 'end': 113, 'type': 'DISEASE'},
#   'obj': {'text': 'nhiễm trùng máu',
#    'start': 135,
#    'end': 150,
#    'type': 'DISEASE'}},
#  {'text': 'đôi khi các vi khuẩn gây nhiễm trùng gây ra viêm nắp thanh quản ở nơi khác trong cơ thể , chẳng hạn như viêm phổi , viêm màng não hoặc nhiễm trùng máu ( nhiễm trùng huyết ) .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'nhiễm trùng huyết',
#    'start': 153,
#    'end': 170,
#    'type': 'DISEASE'},
#   'obj': {'text': 'vi khuẩn', 'start': 12, 'end': 20, 'type': 'CAUSE'}},
#  {'text': 'đôi khi các vi khuẩn gây nhiễm trùng gây ra viêm nắp thanh quản ở nơi khác trong cơ thể , chẳng hạn như viêm phổi , viêm màng não hoặc nhiễm trùng máu ( nhiễm trùng huyết ) .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'viêm màng não',
#    'start': 116,
#    'end': 129,
#    'type': 'DISEASE'},
#   'obj': {'text': 'viêm phổi', 'start': 104, 'end': 113, 'type': 'DISEASE'}},
#  {'text': 'đôi khi các vi khuẩn gây nhiễm trùng gây ra viêm nắp thanh quản ở nơi khác trong cơ thể , chẳng hạn như viêm phổi , viêm màng não hoặc nhiễm trùng máu ( nhiễm trùng huyết ) .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'viêm màng não',
#    'start': 116,
#    'end': 129,
#    'type': 'DISEASE'},
#   'obj': {'text': 'nhiễm trùng', 'start': 25, 'end': 36, 'type': 'DISEASE'}},
#  {'text': 'đôi khi các vi khuẩn gây nhiễm trùng gây ra viêm nắp thanh quản ở nơi khác trong cơ thể , chẳng hạn như viêm phổi , viêm màng não hoặc nhiễm trùng máu ( nhiễm trùng huyết ) .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'viêm phổi', 'start': 104, 'end': 113, 'type': 'DISEASE'},
#   'obj': {'text': 'nhiễm trùng huyết',
#    'start': 153,
#    'end': 170,
#    'type': 'DISEASE'}},
#  {'text': 'đôi khi các vi khuẩn gây nhiễm trùng gây ra viêm nắp thanh quản ở nơi khác trong cơ thể , chẳng hạn như viêm phổi , viêm màng não hoặc nhiễm trùng máu ( nhiễm trùng huyết ) .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'nhiễm trùng máu',
#    'start': 135,
#    'end': 150,
#    'type': 'DISEASE'},
#   'obj': {'text': 'viêm phổi', 'start': 104, 'end': 113, 'type': 'DISEASE'}},
#  {'text': 'chụp cắt lớp vi tính ổ bụng đánh giá vị trí , kích thước và mức độ xâm lấn xung quanh của ung thư túi mật siêu âm ổ bụng phương pháp đơn giản , dễ thực hiện giúp đánh giá sơ bộ túi mật và đường mật cũng như cơ quan trong ổ bụng các biện pháp điều trị bệnh ung thư túi mật điều trị ung thư túi mật bao gồm các phương pháp sau : phẫu thuật cắt túi mật : cắt bỏ túi mật đơn giản .',
#   'relation': 'REVEALS',
#   'subj': {'text': 'chụp cắt lớp vi tính ổ bụng',
#    'start': 0,
#    'end': 27,
#    'type': 'DIAGNOSTIC'},
#   'obj': {'text': 'ung thư túi mật',
#    'start': 90,
#    'end': 105,
#    'type': 'DISEASE'}},
#  {'text': 'chụp cắt lớp vi tính ổ bụng đánh giá vị trí , kích thước và mức độ xâm lấn xung quanh của ung thư túi mật siêu âm ổ bụng phương pháp đơn giản , dễ thực hiện giúp đánh giá sơ bộ túi mật và đường mật cũng như cơ quan trong ổ bụng các biện pháp điều trị bệnh ung thư túi mật điều trị ung thư túi mật bao gồm các phương pháp sau : phẫu thuật cắt túi mật : cắt bỏ túi mật đơn giản .',
#   'relation': 'REVEALS',
#   'subj': {'text': 'siêu âm ổ bụng',
#    'start': 106,
#    'end': 120,
#    'type': 'DIAGNOSTIC'},
#   'obj': {'text': 'bệnh ung thư túi mật',
#    'start': 251,
#    'end': 271,
#    'type': 'DISEASE'}},
#  {'text': 'chụp cắt lớp vi tính ổ bụng đánh giá vị trí , kích thước và mức độ xâm lấn xung quanh của ung thư túi mật siêu âm ổ bụng phương pháp đơn giản , dễ thực hiện giúp đánh giá sơ bộ túi mật và đường mật cũng như cơ quan trong ổ bụng các biện pháp điều trị bệnh ung thư túi mật điều trị ung thư túi mật bao gồm các phương pháp sau : phẫu thuật cắt túi mật : cắt bỏ túi mật đơn giản .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'ung thư túi mật',
#    'start': 281,
#    'end': 296,
#    'type': 'DISEASE'},
#   'obj': {'text': 'phẫu thuật cắt túi mật',
#    'start': 327,
#    'end': 349,
#    'type': 'TREATMENT'}},
#  {'text': 'chụp cắt lớp vi tính ổ bụng đánh giá vị trí , kích thước và mức độ xâm lấn xung quanh của ung thư túi mật siêu âm ổ bụng phương pháp đơn giản , dễ thực hiện giúp đánh giá sơ bộ túi mật và đường mật cũng như cơ quan trong ổ bụng các biện pháp điều trị bệnh ung thư túi mật điều trị ung thư túi mật bao gồm các phương pháp sau : phẫu thuật cắt túi mật : cắt bỏ túi mật đơn giản .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'phẫu thuật cắt túi mật',
#    'start': 327,
#    'end': 349,
#    'type': 'TREATMENT'},
#   'obj': {'text': 'bệnh ung thư túi mật',
#    'start': 251,
#    'end': 271,
#    'type': 'DISEASE'}},
#  {'text': 'chụp cắt lớp vi tính ổ bụng đánh giá vị trí , kích thước và mức độ xâm lấn xung quanh của ung thư túi mật siêu âm ổ bụng phương pháp đơn giản , dễ thực hiện giúp đánh giá sơ bộ túi mật và đường mật cũng như cơ quan trong ổ bụng các biện pháp điều trị bệnh ung thư túi mật điều trị ung thư túi mật bao gồm các phương pháp sau : phẫu thuật cắt túi mật : cắt bỏ túi mật đơn giản .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'ung thư túi mật',
#    'start': 281,
#    'end': 296,
#    'type': 'DISEASE'},
#   'obj': {'text': 'bệnh ung thư túi mật',
#    'start': 251,
#    'end': 271,
#    'type': 'DISEASE'}},
#  {'text': 'chụp cắt lớp vi tính ổ bụng đánh giá vị trí , kích thước và mức độ xâm lấn xung quanh của ung thư túi mật siêu âm ổ bụng phương pháp đơn giản , dễ thực hiện giúp đánh giá sơ bộ túi mật và đường mật cũng như cơ quan trong ổ bụng các biện pháp điều trị bệnh ung thư túi mật điều trị ung thư túi mật bao gồm các phương pháp sau : phẫu thuật cắt túi mật : cắt bỏ túi mật đơn giản .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'phẫu thuật cắt túi mật',
#    'start': 327,
#    'end': 349,
#    'type': 'TREATMENT'},
#   'obj': {'text': 'ung thư túi mật',
#    'start': 281,
#    'end': 296,
#    'type': 'DISEASE'}},
#  {'text': 'đối tượng nguy cơ bệnh thiếu máu cơ tim nam giới tuổi cao hút thuốc lá béo phì đái tháo đường rối loạn lipid máu tăng huyết áp lối sống tĩnh tại , ít vận động phòng ngừa bệnh thiếu máu cơ tim bỏ thuốc lá giảm cân nếu thừa cân tập thể dục thường xuyên : ít nhất 30 phút mỗi ngày ,5 ngày mỗi tuần chế độ ăn lành mạnh : nhiều rau xanh , hoa quả , hạn chế mỡ động vật thay bằng dầu thực vật , hạn chế phủ tạng động vật , giảm muối trong thức ăn , không ăn các đồ muối như dưa chua , cà muối… kiểm soát huyết áp bằng thay đổi chế độ ăn kèm uống thuốc đều đặn kiểm soát đường máu , lipid máu các biện pháp chẩn đoán bệnh thiếu máu cơ tim điện tâm đồ : là phương tiện bắt buộc phải thực hiện đầu tiên để chẩn đoán bệnh lý mạch vành .',
#   'relation': 'REVEALS',
#   'subj': {'text': 'điện tâm đồ',
#    'start': 632,
#    'end': 643,
#    'type': 'DIAGNOSTIC'},
#   'obj': {'text': 'bệnh thiếu máu cơ tim',
#    'start': 610,
#    'end': 631,
#    'type': 'DISEASE'}},
#  {'text': 'đối tượng nguy cơ bệnh thiếu máu cơ tim nam giới tuổi cao hút thuốc lá béo phì đái tháo đường rối loạn lipid máu tăng huyết áp lối sống tĩnh tại , ít vận động phòng ngừa bệnh thiếu máu cơ tim bỏ thuốc lá giảm cân nếu thừa cân tập thể dục thường xuyên : ít nhất 30 phút mỗi ngày ,5 ngày mỗi tuần chế độ ăn lành mạnh : nhiều rau xanh , hoa quả , hạn chế mỡ động vật thay bằng dầu thực vật , hạn chế phủ tạng động vật , giảm muối trong thức ăn , không ăn các đồ muối như dưa chua , cà muối… kiểm soát huyết áp bằng thay đổi chế độ ăn kèm uống thuốc đều đặn kiểm soát đường máu , lipid máu các biện pháp chẩn đoán bệnh thiếu máu cơ tim điện tâm đồ : là phương tiện bắt buộc phải thực hiện đầu tiên để chẩn đoán bệnh lý mạch vành .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'bệnh thiếu máu cơ tim',
#    'start': 610,
#    'end': 631,
#    'type': 'DISEASE'},
#   'obj': {'text': 'bệnh thiếu máu cơ tim',
#    'start': 170,
#    'end': 191,
#    'type': 'DISEASE'}},
#  {'text': 'men gan : loại trừ các nguyên nhân khác gây vàng da ldh ( lactate dehydrogenase ) : đánh giá độ nặng của tình trạng tan máu test coombs định lượng bilirubin máu phân tích nước tiểu các biện pháp điều trị bệnh thiếu men g6pd điều trị bệnh thiếu men g6pd quan trọng nhất là loại bỏ các yếu tố khởi phát một đợt cấp , bao gồm : tránh dùng thức ăn hay các loại thuốc đã được xác định gây tan máu .',
#   'relation': 'REVEALS',
#   'subj': {'text': 'test coombs',
#    'start': 124,
#    'end': 135,
#    'type': 'DIAGNOSTIC'},
#   'obj': {'text': 'vàng da', 'start': 44, 'end': 51, 'type': 'SYMPTOM'}},
#  {'text': 'men gan : loại trừ các nguyên nhân khác gây vàng da ldh ( lactate dehydrogenase ) : đánh giá độ nặng của tình trạng tan máu test coombs định lượng bilirubin máu phân tích nước tiểu các biện pháp điều trị bệnh thiếu men g6pd điều trị bệnh thiếu men g6pd quan trọng nhất là loại bỏ các yếu tố khởi phát một đợt cấp , bao gồm : tránh dùng thức ăn hay các loại thuốc đã được xác định gây tan máu .',
#   'relation': 'REVEALS',
#   'subj': {'text': 'định lượng bilirubin máu',
#    'start': 136,
#    'end': 160,
#    'type': 'DIAGNOSTIC'},
#   'obj': {'text': 'vàng da', 'start': 44, 'end': 51, 'type': 'SYMPTOM'}},
#  {'text': 'men gan : loại trừ các nguyên nhân khác gây vàng da ldh ( lactate dehydrogenase ) : đánh giá độ nặng của tình trạng tan máu test coombs định lượng bilirubin máu phân tích nước tiểu các biện pháp điều trị bệnh thiếu men g6pd điều trị bệnh thiếu men g6pd quan trọng nhất là loại bỏ các yếu tố khởi phát một đợt cấp , bao gồm : tránh dùng thức ăn hay các loại thuốc đã được xác định gây tan máu .',
#   'relation': 'REVEALS',
#   'subj': {'text': 'phân tích nước tiểu',
#    'start': 161,
#    'end': 180,
#    'type': 'DIAGNOSTIC'},
#   'obj': {'text': 'vàng da', 'start': 44, 'end': 51, 'type': 'SYMPTOM'}},
#  {'text': 'men gan : loại trừ các nguyên nhân khác gây vàng da ldh ( lactate dehydrogenase ) : đánh giá độ nặng của tình trạng tan máu test coombs định lượng bilirubin máu phân tích nước tiểu các biện pháp điều trị bệnh thiếu men g6pd điều trị bệnh thiếu men g6pd quan trọng nhất là loại bỏ các yếu tố khởi phát một đợt cấp , bao gồm : tránh dùng thức ăn hay các loại thuốc đã được xác định gây tan máu .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'vàng da', 'start': 44, 'end': 51, 'type': 'SYMPTOM'},
#   'obj': {'text': 'định lượng bilirubin máu',
#    'start': 136,
#    'end': 160,
#    'type': 'DIAGNOSTIC'}},
#  {'text': 'men gan : loại trừ các nguyên nhân khác gây vàng da ldh ( lactate dehydrogenase ) : đánh giá độ nặng của tình trạng tan máu test coombs định lượng bilirubin máu phân tích nước tiểu các biện pháp điều trị bệnh thiếu men g6pd điều trị bệnh thiếu men g6pd quan trọng nhất là loại bỏ các yếu tố khởi phát một đợt cấp , bao gồm : tránh dùng thức ăn hay các loại thuốc đã được xác định gây tan máu .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'phân tích nước tiểu',
#    'start': 161,
#    'end': 180,
#    'type': 'DIAGNOSTIC'},
#   'obj': {'text': 'bệnh thiếu men g6pd',
#    'start': 204,
#    'end': 223,
#    'type': 'DISEASE'}},
#  {'text': 'men gan : loại trừ các nguyên nhân khác gây vàng da ldh ( lactate dehydrogenase ) : đánh giá độ nặng của tình trạng tan máu test coombs định lượng bilirubin máu phân tích nước tiểu các biện pháp điều trị bệnh thiếu men g6pd điều trị bệnh thiếu men g6pd quan trọng nhất là loại bỏ các yếu tố khởi phát một đợt cấp , bao gồm : tránh dùng thức ăn hay các loại thuốc đã được xác định gây tan máu .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'test coombs',
#    'start': 124,
#    'end': 135,
#    'type': 'DIAGNOSTIC'},
#   'obj': {'text': 'bệnh thiếu men g6pd',
#    'start': 233,
#    'end': 252,
#    'type': 'DISEASE'}},
#  {'text': 'nếu siêu âm lần đầu không thấy sùi , phải làm siêu âm lại sau 7 – 10 ngày khi lâm sàng vẫn còn nghi ngờ viêm nội tâm mạc , thậm chí phải làm lại siêu âm sớm hơn đối với viêm nội tâm mạc do s . aureus .',
#   'relation': 'REVEALS',
#   'subj': {'text': 'siêu âm', 'start': 4, 'end': 11, 'type': 'DIAGNOSTIC'},
#   'obj': {'text': 'viêm nội tâm mạc',
#    'start': 104,
#    'end': 120,
#    'type': 'DISEASE'}},
#  {'text': 'nếu siêu âm lần đầu không thấy sùi , phải làm siêu âm lại sau 7 – 10 ngày khi lâm sàng vẫn còn nghi ngờ viêm nội tâm mạc , thậm chí phải làm lại siêu âm sớm hơn đối với viêm nội tâm mạc do s . aureus .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'viêm nội tâm mạc',
#    'start': 169,
#    'end': 185,
#    'type': 'DISEASE'},
#   'obj': {'text': 's . aureus', 'start': 189, 'end': 199, 'type': 'SYMPTOM'}},
#  {'text': 'nếu siêu âm lần đầu không thấy sùi , phải làm siêu âm lại sau 7 – 10 ngày khi lâm sàng vẫn còn nghi ngờ viêm nội tâm mạc , thậm chí phải làm lại siêu âm sớm hơn đối với viêm nội tâm mạc do s . aureus .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'viêm nội tâm mạc',
#    'start': 169,
#    'end': 185,
#    'type': 'DISEASE'},
#   'obj': {'text': 'siêu âm', 'start': 46, 'end': 53, 'type': 'DIAGNOSTIC'}},
#  {'text': 'nếu siêu âm lần đầu không thấy sùi , phải làm siêu âm lại sau 7 – 10 ngày khi lâm sàng vẫn còn nghi ngờ viêm nội tâm mạc , thậm chí phải làm lại siêu âm sớm hơn đối với viêm nội tâm mạc do s . aureus .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'siêu âm', 'start': 46, 'end': 53, 'type': 'DIAGNOSTIC'},
#   'obj': {'text': 's . aureus', 'start': 189, 'end': 199, 'type': 'SYMPTOM'}},
#  {'text': 'chụp x - quang nếu có khối u hoặc sưng ở hàm , bác sĩ có thể yêu cầu chụp x - quang hàm và răng để tìm khối u . nếu đã được chẩn đoán mắc bệnh ung thư , chụp x - quang ngực có thể được thực hiện để xem liệu ung thư đã lan đến phổi hay chưa .',
#   'relation': 'REVEALS',
#   'subj': {'text': 'chụp x - quang hàm và răng',
#    'start': 69,
#    'end': 95,
#    'type': 'DIAGNOSTIC'},
#   'obj': {'text': 'bệnh ung thư',
#    'start': 138,
#    'end': 150,
#    'type': 'DISEASE'}},
#  {'text': 'chụp x - quang nếu có khối u hoặc sưng ở hàm , bác sĩ có thể yêu cầu chụp x - quang hàm và răng để tìm khối u . nếu đã được chẩn đoán mắc bệnh ung thư , chụp x - quang ngực có thể được thực hiện để xem liệu ung thư đã lan đến phổi hay chưa .',
#   'relation': 'REVEALS',
#   'subj': {'text': 'chụp x - quang ngực',
#    'start': 153,
#    'end': 172,
#    'type': 'DIAGNOSTIC'},
#   'obj': {'text': 'ung thư', 'start': 207, 'end': 214, 'type': 'DISEASE'}},
#  {'text': 'chụp x - quang nếu có khối u hoặc sưng ở hàm , bác sĩ có thể yêu cầu chụp x - quang hàm và răng để tìm khối u . nếu đã được chẩn đoán mắc bệnh ung thư , chụp x - quang ngực có thể được thực hiện để xem liệu ung thư đã lan đến phổi hay chưa .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'ung thư', 'start': 207, 'end': 214, 'type': 'DISEASE'},
#   'obj': {'text': 'sưng ở hàm', 'start': 34, 'end': 44, 'type': 'SYMPTOM'}},
#  {'text': 'chụp x - quang nếu có khối u hoặc sưng ở hàm , bác sĩ có thể yêu cầu chụp x - quang hàm và răng để tìm khối u . nếu đã được chẩn đoán mắc bệnh ung thư , chụp x - quang ngực có thể được thực hiện để xem liệu ung thư đã lan đến phổi hay chưa .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'sưng ở hàm', 'start': 34, 'end': 44, 'type': 'SYMPTOM'},
#   'obj': {'text': 'bệnh ung thư',
#    'start': 138,
#    'end': 150,
#    'type': 'DISEASE'}},
#  {'text': 'chụp x - quang nếu có khối u hoặc sưng ở hàm , bác sĩ có thể yêu cầu chụp x - quang hàm và răng để tìm khối u . nếu đã được chẩn đoán mắc bệnh ung thư , chụp x - quang ngực có thể được thực hiện để xem liệu ung thư đã lan đến phổi hay chưa .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'ung thư', 'start': 207, 'end': 214, 'type': 'DISEASE'},
#   'obj': {'text': 'chụp x - quang ngực',
#    'start': 153,
#    'end': 172,
#    'type': 'DIAGNOSTIC'}},
#  {'text': 'chụp x - quang nếu có khối u hoặc sưng ở hàm , bác sĩ có thể yêu cầu chụp x - quang hàm và răng để tìm khối u . nếu đã được chẩn đoán mắc bệnh ung thư , chụp x - quang ngực có thể được thực hiện để xem liệu ung thư đã lan đến phổi hay chưa .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'sưng ở hàm', 'start': 34, 'end': 44, 'type': 'SYMPTOM'},
#   'obj': {'text': 'chụp x - quang hàm và răng',
#    'start': 69,
#    'end': 95,
#    'type': 'DIAGNOSTIC'}},
#  {'text': 'điều trị ngoại khoa cho viêm nội tâm mạc nhiễm khuẩn là lấy đi những mảnh sùi hoặc hoại tử mà không thể điều trị nội khoa được , sửa lại van hoặc thay van bị tổn thương .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'viêm nội tâm mạc nhiễm khuẩn',
#    'start': 24,
#    'end': 52,
#    'type': 'DISEASE'},
#   'obj': {'text': 'sửa lại van',
#    'start': 129,
#    'end': 140,
#    'type': 'TREATMENT'}},
#  {'text': 'điều trị ngoại khoa cho viêm nội tâm mạc nhiễm khuẩn là lấy đi những mảnh sùi hoặc hoại tử mà không thể điều trị nội khoa được , sửa lại van hoặc thay van bị tổn thương .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'viêm nội tâm mạc nhiễm khuẩn',
#    'start': 24,
#    'end': 52,
#    'type': 'DISEASE'},
#   'obj': {'text': 'thay van', 'start': 146, 'end': 154, 'type': 'TREATMENT'}},
#  {'text': 'điều trị ngoại khoa cho viêm nội tâm mạc nhiễm khuẩn là lấy đi những mảnh sùi hoặc hoại tử mà không thể điều trị nội khoa được , sửa lại van hoặc thay van bị tổn thương .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'viêm nội tâm mạc nhiễm khuẩn',
#    'start': 24,
#    'end': 52,
#    'type': 'DISEASE'},
#   'obj': {'text': 'sùi', 'start': 74, 'end': 77, 'type': 'SYMPTOM'}},
#  {'text': 'điều trị ngoại khoa cho viêm nội tâm mạc nhiễm khuẩn là lấy đi những mảnh sùi hoặc hoại tử mà không thể điều trị nội khoa được , sửa lại van hoặc thay van bị tổn thương .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'viêm nội tâm mạc nhiễm khuẩn',
#    'start': 24,
#    'end': 52,
#    'type': 'DISEASE'},
#   'obj': {'text': 'hoại tử', 'start': 83, 'end': 90, 'type': 'SYMPTOM'}},
#  {'text': 'điều trị ngoại khoa cho viêm nội tâm mạc nhiễm khuẩn là lấy đi những mảnh sùi hoặc hoại tử mà không thể điều trị nội khoa được , sửa lại van hoặc thay van bị tổn thương .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'ngoại khoa', 'start': 9, 'end': 19, 'type': 'TREATMENT'},
#   'obj': {'text': 'sửa lại van',
#    'start': 129,
#    'end': 140,
#    'type': 'TREATMENT'}},
#  {'text': 'điều trị ngoại khoa cho viêm nội tâm mạc nhiễm khuẩn là lấy đi những mảnh sùi hoặc hoại tử mà không thể điều trị nội khoa được , sửa lại van hoặc thay van bị tổn thương .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'ngoại khoa', 'start': 9, 'end': 19, 'type': 'TREATMENT'},
#   'obj': {'text': 'hoại tử', 'start': 83, 'end': 90, 'type': 'SYMPTOM'}},
#  {'text': 'điều trị ngoại khoa cho viêm nội tâm mạc nhiễm khuẩn là lấy đi những mảnh sùi hoặc hoại tử mà không thể điều trị nội khoa được , sửa lại van hoặc thay van bị tổn thương .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'thay van', 'start': 146, 'end': 154, 'type': 'TREATMENT'},
#   'obj': {'text': 'viêm nội tâm mạc nhiễm khuẩn',
#    'start': 24,
#    'end': 52,
#    'type': 'DISEASE'}},
#  {'text': 'điều trị ngoại khoa cho viêm nội tâm mạc nhiễm khuẩn là lấy đi những mảnh sùi hoặc hoại tử mà không thể điều trị nội khoa được , sửa lại van hoặc thay van bị tổn thương .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'viêm nội tâm mạc nhiễm khuẩn',
#    'start': 24,
#    'end': 52,
#    'type': 'DISEASE'},
#   'obj': {'text': 'ngoại khoa', 'start': 9, 'end': 19, 'type': 'TREATMENT'}},
#  {'text': 'bệnh nhân bị hội chứng brugada có triệu chứng như ngất hay ngừng tuần hoàn khi được cứu sống cần chỉ định cấy máy tạo nhịp – phá rung tự động ( icd ) .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'hội chứng brugada',
#    'start': 13,
#    'end': 30,
#    'type': 'DISEASE'},
#   'obj': {'text': 'ngất', 'start': 50, 'end': 54, 'type': 'SYMPTOM'}},
#  {'text': 'bệnh nhân bị hội chứng brugada có triệu chứng như ngất hay ngừng tuần hoàn khi được cứu sống cần chỉ định cấy máy tạo nhịp – phá rung tự động ( icd ) .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'hội chứng brugada',
#    'start': 13,
#    'end': 30,
#    'type': 'DISEASE'},
#   'obj': {'text': 'ngừng tuần hoàn',
#    'start': 59,
#    'end': 74,
#    'type': 'SYMPTOM'}},
#  {'text': 'bệnh nhân bị hội chứng brugada có triệu chứng như ngất hay ngừng tuần hoàn khi được cứu sống cần chỉ định cấy máy tạo nhịp – phá rung tự động ( icd ) .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'hội chứng brugada',
#    'start': 13,
#    'end': 30,
#    'type': 'DISEASE'},
#   'obj': {'text': 'cấy máy tạo nhịp',
#    'start': 106,
#    'end': 122,
#    'type': 'TREATMENT'}},
#  {'text': 'bệnh nhân bị hội chứng brugada có triệu chứng như ngất hay ngừng tuần hoàn khi được cứu sống cần chỉ định cấy máy tạo nhịp – phá rung tự động ( icd ) .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'hội chứng brugada',
#    'start': 13,
#    'end': 30,
#    'type': 'DISEASE'},
#   'obj': {'text': 'phá rung tự động',
#    'start': 125,
#    'end': 141,
#    'type': 'TREATMENT'}},
#  {'text': 'bệnh nhân bị hội chứng brugada có triệu chứng như ngất hay ngừng tuần hoàn khi được cứu sống cần chỉ định cấy máy tạo nhịp – phá rung tự động ( icd ) .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'ngừng tuần hoàn',
#    'start': 59,
#    'end': 74,
#    'type': 'SYMPTOM'},
#   'obj': {'text': 'icd', 'start': 144, 'end': 147, 'type': 'TREATMENT'}},
#  {'text': 'bệnh nhân bị hội chứng brugada có triệu chứng như ngất hay ngừng tuần hoàn khi được cứu sống cần chỉ định cấy máy tạo nhịp – phá rung tự động ( icd ) .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'ngất', 'start': 50, 'end': 54, 'type': 'SYMPTOM'},
#   'obj': {'text': 'ngừng tuần hoàn',
#    'start': 59,
#    'end': 74,
#    'type': 'SYMPTOM'}},
#  {'text': 'bệnh nhân bị hội chứng brugada có triệu chứng như ngất hay ngừng tuần hoàn khi được cứu sống cần chỉ định cấy máy tạo nhịp – phá rung tự động ( icd ) .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'ngừng tuần hoàn',
#    'start': 59,
#    'end': 74,
#    'type': 'SYMPTOM'},
#   'obj': {'text': 'ngất', 'start': 50, 'end': 54, 'type': 'SYMPTOM'}},
#  {'text': 'bệnh nhân bị hội chứng brugada có triệu chứng như ngất hay ngừng tuần hoàn khi được cứu sống cần chỉ định cấy máy tạo nhịp – phá rung tự động ( icd ) .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'icd', 'start': 144, 'end': 147, 'type': 'TREATMENT'},
#   'obj': {'text': 'phá rung tự động',
#    'start': 125,
#    'end': 141,
#    'type': 'TREATMENT'}},
#  {'text': 'trường hợp bệnh sốt rét xác định : trường hợp bệnh sốt rét xác định là trường hợp có ký sinh trùng sốt rét trong máu được xác định bằng xét nghiệm lam máu nhuộm giemsa hoặc xét nghiệm chẩn đoán nhanh phát hiện kháng nguyên hoặc kỹ thuật sinh học phân tử .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'ký sinh trùng sốt rét',
#    'start': 85,
#    'end': 106,
#    'type': 'CAUSE'},
#   'obj': {'text': 'sốt rét', 'start': 51, 'end': 58, 'type': 'DISEASE'}},
#  {'text': 'trường hợp bệnh sốt rét xác định : trường hợp bệnh sốt rét xác định là trường hợp có ký sinh trùng sốt rét trong máu được xác định bằng xét nghiệm lam máu nhuộm giemsa hoặc xét nghiệm chẩn đoán nhanh phát hiện kháng nguyên hoặc kỹ thuật sinh học phân tử .',
#   'relation': 'REVEALS',
#   'subj': {'text': 'xét nghiệm lam máu nhuộm giemsa',
#    'start': 136,
#    'end': 167,
#    'type': 'DIAGNOSTIC'},
#   'obj': {'text': 'sốt rét', 'start': 51, 'end': 58, 'type': 'DISEASE'}},
#  {'text': 'trường hợp bệnh sốt rét xác định : trường hợp bệnh sốt rét xác định là trường hợp có ký sinh trùng sốt rét trong máu được xác định bằng xét nghiệm lam máu nhuộm giemsa hoặc xét nghiệm chẩn đoán nhanh phát hiện kháng nguyên hoặc kỹ thuật sinh học phân tử .',
#   'relation': 'REVEALS',
#   'subj': {'text': 'xét nghiệm chẩn đoán nhanh phát hiện kháng nguyên',
#    'start': 173,
#    'end': 222,
#    'type': 'DIAGNOSTIC'},
#   'obj': {'text': 'sốt rét', 'start': 51, 'end': 58, 'type': 'DISEASE'}},
#  {'text': 'trường hợp bệnh sốt rét xác định : trường hợp bệnh sốt rét xác định là trường hợp có ký sinh trùng sốt rét trong máu được xác định bằng xét nghiệm lam máu nhuộm giemsa hoặc xét nghiệm chẩn đoán nhanh phát hiện kháng nguyên hoặc kỹ thuật sinh học phân tử .',
#   'relation': 'REVEALS',
#   'subj': {'text': 'kỹ thuật sinh học phân tử',
#    'start': 228,
#    'end': 253,
#    'type': 'DIAGNOSTIC'},
#   'obj': {'text': 'sốt rét', 'start': 51, 'end': 58, 'type': 'DISEASE'}},
#  {'text': 'trường hợp bệnh sốt rét xác định : trường hợp bệnh sốt rét xác định là trường hợp có ký sinh trùng sốt rét trong máu được xác định bằng xét nghiệm lam máu nhuộm giemsa hoặc xét nghiệm chẩn đoán nhanh phát hiện kháng nguyên hoặc kỹ thuật sinh học phân tử .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'xét nghiệm chẩn đoán nhanh phát hiện kháng nguyên',
#    'start': 173,
#    'end': 222,
#    'type': 'DIAGNOSTIC'},
#   'obj': {'text': 'kỹ thuật sinh học phân tử',
#    'start': 228,
#    'end': 253,
#    'type': 'DIAGNOSTIC'}},
#  {'text': 'trường hợp bệnh sốt rét xác định : trường hợp bệnh sốt rét xác định là trường hợp có ký sinh trùng sốt rét trong máu được xác định bằng xét nghiệm lam máu nhuộm giemsa hoặc xét nghiệm chẩn đoán nhanh phát hiện kháng nguyên hoặc kỹ thuật sinh học phân tử .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'sốt rét', 'start': 16, 'end': 23, 'type': 'DISEASE'},
#   'obj': {'text': 'ký sinh trùng sốt rét',
#    'start': 85,
#    'end': 106,
#    'type': 'CAUSE'}},
#  {'text': 'trường hợp bệnh sốt rét xác định : trường hợp bệnh sốt rét xác định là trường hợp có ký sinh trùng sốt rét trong máu được xác định bằng xét nghiệm lam máu nhuộm giemsa hoặc xét nghiệm chẩn đoán nhanh phát hiện kháng nguyên hoặc kỹ thuật sinh học phân tử .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'sốt rét', 'start': 51, 'end': 58, 'type': 'DISEASE'},
#   'obj': {'text': 'ký sinh trùng sốt rét',
#    'start': 85,
#    'end': 106,
#    'type': 'CAUSE'}},
#  {'text': 'trường hợp bệnh sốt rét xác định : trường hợp bệnh sốt rét xác định là trường hợp có ký sinh trùng sốt rét trong máu được xác định bằng xét nghiệm lam máu nhuộm giemsa hoặc xét nghiệm chẩn đoán nhanh phát hiện kháng nguyên hoặc kỹ thuật sinh học phân tử .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'ký sinh trùng sốt rét',
#    'start': 85,
#    'end': 106,
#    'type': 'CAUSE'},
#   'obj': {'text': 'sốt rét', 'start': 16, 'end': 23, 'type': 'DISEASE'}},
#  {'text': 'thuốc thư giãn cơ bắp , có thể bao gồm thuốc nitrate , như isosorbide ( isordil ) , nifedipine ( procardia ) , diltiazem ( cardizem , tiazac… ) hoặc dicyclomin ( bentyl ) .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'diltiazem', 'start': 111, 'end': 120, 'type': 'TREATMENT'},
#   'obj': {'text': 'tiazac', 'start': 134, 'end': 140, 'type': 'TREATMENT'}},
#  {'text': 'đối tượng nguy cơ bệnh tăng huyết áp thai kỳ tiền sản giật ở thai kỳ trước tuổi &gt;40 hoặc &lt;18 tăng huyết áp mạn tính bệnh thận mạn bệnh tự miễn ( lupus ban đỏ hệ thống , hội chứng kháng phospholipid ) đái tháo đường béo phì có thai bằng thụ tinh nhân tạo đa thai phòng ngừa bệnh tăng huyết áp thai kỳ tránh mang thai , sinh nở khi tuổi cao giảm cân trước khi mang thai ( nếu thừa cân ) chế độ ăn lành mạnh : nhiều rau xanh , hoa quả , ít mỡ động vật , thay bằng dầu thực vật để giảm nguy cơ mắc đái tháo đường thai kỳ tập thể dục thường xuyên trước khi mang thai .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'bệnh tăng huyết áp thai kỳ',
#    'start': 18,
#    'end': 44,
#    'type': 'DISEASE'},
#   'obj': {'text': 'giảm cân trước khi mang thai',
#    'start': 345,
#    'end': 373,
#    'type': 'TREATMENT'}},
#  {'text': 'đối tượng nguy cơ bệnh tăng huyết áp thai kỳ tiền sản giật ở thai kỳ trước tuổi &gt;40 hoặc &lt;18 tăng huyết áp mạn tính bệnh thận mạn bệnh tự miễn ( lupus ban đỏ hệ thống , hội chứng kháng phospholipid ) đái tháo đường béo phì có thai bằng thụ tinh nhân tạo đa thai phòng ngừa bệnh tăng huyết áp thai kỳ tránh mang thai , sinh nở khi tuổi cao giảm cân trước khi mang thai ( nếu thừa cân ) chế độ ăn lành mạnh : nhiều rau xanh , hoa quả , ít mỡ động vật , thay bằng dầu thực vật để giảm nguy cơ mắc đái tháo đường thai kỳ tập thể dục thường xuyên trước khi mang thai .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'bệnh tăng huyết áp thai kỳ',
#    'start': 18,
#    'end': 44,
#    'type': 'DISEASE'},
#   'obj': {'text': 'tập thể dục thường xuyên',
#    'start': 523,
#    'end': 547,
#    'type': 'TREATMENT'}},
#  {'text': 'đối tượng nguy cơ bệnh tăng huyết áp thai kỳ tiền sản giật ở thai kỳ trước tuổi &gt;40 hoặc &lt;18 tăng huyết áp mạn tính bệnh thận mạn bệnh tự miễn ( lupus ban đỏ hệ thống , hội chứng kháng phospholipid ) đái tháo đường béo phì có thai bằng thụ tinh nhân tạo đa thai phòng ngừa bệnh tăng huyết áp thai kỳ tránh mang thai , sinh nở khi tuổi cao giảm cân trước khi mang thai ( nếu thừa cân ) chế độ ăn lành mạnh : nhiều rau xanh , hoa quả , ít mỡ động vật , thay bằng dầu thực vật để giảm nguy cơ mắc đái tháo đường thai kỳ tập thể dục thường xuyên trước khi mang thai .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'đái tháo đường thai kỳ',
#    'start': 500,
#    'end': 522,
#    'type': 'DISEASE'},
#   'obj': {'text': 'chế độ ăn lành mạnh',
#    'start': 391,
#    'end': 410,
#    'type': 'TREATMENT'}},
#  {'text': 'đối tượng nguy cơ bệnh tăng huyết áp thai kỳ tiền sản giật ở thai kỳ trước tuổi &gt;40 hoặc &lt;18 tăng huyết áp mạn tính bệnh thận mạn bệnh tự miễn ( lupus ban đỏ hệ thống , hội chứng kháng phospholipid ) đái tháo đường béo phì có thai bằng thụ tinh nhân tạo đa thai phòng ngừa bệnh tăng huyết áp thai kỳ tránh mang thai , sinh nở khi tuổi cao giảm cân trước khi mang thai ( nếu thừa cân ) chế độ ăn lành mạnh : nhiều rau xanh , hoa quả , ít mỡ động vật , thay bằng dầu thực vật để giảm nguy cơ mắc đái tháo đường thai kỳ tập thể dục thường xuyên trước khi mang thai .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'chế độ ăn lành mạnh',
#    'start': 391,
#    'end': 410,
#    'type': 'TREATMENT'},
#   'obj': {'text': 'giảm cân trước khi mang thai',
#    'start': 345,
#    'end': 373,
#    'type': 'TREATMENT'}},
#  {'text': 'đối tượng nguy cơ bệnh tăng huyết áp thai kỳ tiền sản giật ở thai kỳ trước tuổi &gt;40 hoặc &lt;18 tăng huyết áp mạn tính bệnh thận mạn bệnh tự miễn ( lupus ban đỏ hệ thống , hội chứng kháng phospholipid ) đái tháo đường béo phì có thai bằng thụ tinh nhân tạo đa thai phòng ngừa bệnh tăng huyết áp thai kỳ tránh mang thai , sinh nở khi tuổi cao giảm cân trước khi mang thai ( nếu thừa cân ) chế độ ăn lành mạnh : nhiều rau xanh , hoa quả , ít mỡ động vật , thay bằng dầu thực vật để giảm nguy cơ mắc đái tháo đường thai kỳ tập thể dục thường xuyên trước khi mang thai .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'bệnh tăng huyết áp thai kỳ',
#    'start': 18,
#    'end': 44,
#    'type': 'DISEASE'},
#   'obj': {'text': 'tiền sản giật', 'start': 45, 'end': 58, 'type': 'DISEASE'}},
#  {'text': 'đối tượng nguy cơ bệnh tăng huyết áp thai kỳ tiền sản giật ở thai kỳ trước tuổi &gt;40 hoặc &lt;18 tăng huyết áp mạn tính bệnh thận mạn bệnh tự miễn ( lupus ban đỏ hệ thống , hội chứng kháng phospholipid ) đái tháo đường béo phì có thai bằng thụ tinh nhân tạo đa thai phòng ngừa bệnh tăng huyết áp thai kỳ tránh mang thai , sinh nở khi tuổi cao giảm cân trước khi mang thai ( nếu thừa cân ) chế độ ăn lành mạnh : nhiều rau xanh , hoa quả , ít mỡ động vật , thay bằng dầu thực vật để giảm nguy cơ mắc đái tháo đường thai kỳ tập thể dục thường xuyên trước khi mang thai .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'bệnh tăng huyết áp thai kỳ',
#    'start': 279,
#    'end': 305,
#    'type': 'DISEASE'},
#   'obj': {'text': 'béo phì', 'start': 221, 'end': 228, 'type': 'DISEASE'}},
#  {'text': 'nam giới bị mắc một số bệnh viêm nhiễm ở cơ quan sinh dục như viêm tinh hoàn , viêm mào tinh hoàn , viêm niệu đạo , viêm tuyến tiền liệt … biến chứng từ việc lây nhiễm một số bệnh xã hội lây truyền qua đường tình dục như bệnh lậu , giang mai , sùi mào gà … sự xuất hiện một số khối u ở cơ quan sinh dục : ung thư tuyến tiền liệt , ung thư mào tinh hoàn … chấn thương : tắc ống dẫn tinh có thể xảy ra khi nam giới gặp một chấn thương nào đó .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'chấn thương', 'start': 421, 'end': 432, 'type': 'CAUSE'},
#   'obj': {'text': 'tắc ống dẫn tinh',
#    'start': 369,
#    'end': 385,
#    'type': 'DISEASE'}},
#  {'text': 'nam giới bị mắc một số bệnh viêm nhiễm ở cơ quan sinh dục như viêm tinh hoàn , viêm mào tinh hoàn , viêm niệu đạo , viêm tuyến tiền liệt … biến chứng từ việc lây nhiễm một số bệnh xã hội lây truyền qua đường tình dục như bệnh lậu , giang mai , sùi mào gà … sự xuất hiện một số khối u ở cơ quan sinh dục : ung thư tuyến tiền liệt , ung thư mào tinh hoàn … chấn thương : tắc ống dẫn tinh có thể xảy ra khi nam giới gặp một chấn thương nào đó .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'ung thư mào tinh hoàn',
#    'start': 331,
#    'end': 352,
#    'type': 'DISEASE'},
#   'obj': {'text': 'tắc ống dẫn tinh',
#    'start': 369,
#    'end': 385,
#    'type': 'DISEASE'}},
#  {'text': 'giai đoạn khởi phát của bệnh : sốt 38 – 39 o c; đau đầu; miệng khô , kém ăn; cơ thể mệt mỏi , suy nhược; đau góc hàm và đau họng; tuyến mang tai đau nhức và to dần .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'sốt', 'start': 31, 'end': 34, 'type': 'SYMPTOM'},
#   'obj': {'text': 'đau góc hàm', 'start': 105, 'end': 116, 'type': 'SYMPTOM'}},
#  {'text': 'tìm kiếm sự chăm sóc y tế kịp thời nếu nôn đi kèm với các dấu hiệu cảnh báo khác , chẳng hạn như : tức ngực; đau bụng dữ dội hoặc chuột rút ; nhìn mờ; sự hoang mang; sốt cao và cứng cổ; phân hoặc mùi phân trong chất nôn; chảy máu trực tràng .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'nhìn mờ', 'start': 143, 'end': 150, 'type': 'SYMPTOM'},
#   'obj': {'text': 'sự hoang mang;',
#    'start': 152,
# ...
#   'relation': 'No_Relation',
#   'subj': {'text': 'phân nhầy có máu',
#    'start': 128,
#    'end': 144,
#    'type': 'SYMPTOM'},
#   'obj': {'text': 'nôn ói không thể ăn uống',
#    'start': 73,
#    'end': 97,
#    'type': 'SYMPTOM'}},
#  {'text': 'trường hợp nặng : nếu các biểu hiện tiêu chảy nhiễm trùng trở nặng như : nôn ói không thể ăn uống , tiêu chảy phân nước nhiều , phân nhầy có máu , sốt cao hoặc rất mệt mỏi , người bệnh nên cân nhắc nhập viện để thực hiện các phương pháp điều trị chuyên môn như : bồi hoàn nước và điện giải qua truyền dịch tĩnh mạch , sử dụng thuốc kháng sinh theo chỉ định của bác sĩ . . nếu thực hiện chăm sóc đúng cách , người bệnh sẽ cảm thấy đỡ hơn trong vòng vài ngày đến một tuần , hoặc có thể mất vài tuần trước khi hệ thống đường ruột , dạ dày hồi phục hoàn toàn .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'tiêu chảy phân nước nhiều',
#    'start': 100,
#    'end': 125,
#    'type': 'SYMPTOM'},
#   'obj': {'text': 'rất mệt mỏi', 'start': 160, 'end': 171, 'type': 'SYMPTOM'}},
#  {'text': 'trường hợp nặng : nếu các biểu hiện tiêu chảy nhiễm trùng trở nặng như : nôn ói không thể ăn uống , tiêu chảy phân nước nhiều , phân nhầy có máu , sốt cao hoặc rất mệt mỏi , người bệnh nên cân nhắc nhập viện để thực hiện các phương pháp điều trị chuyên môn như : bồi hoàn nước và điện giải qua truyền dịch tĩnh mạch , sử dụng thuốc kháng sinh theo chỉ định của bác sĩ . . nếu thực hiện chăm sóc đúng cách , người bệnh sẽ cảm thấy đỡ hơn trong vòng vài ngày đến một tuần , hoặc có thể mất vài tuần trước khi hệ thống đường ruột , dạ dày hồi phục hoàn toàn .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'tiêu chảy phân nước nhiều',
#    'start': 100,
#    'end': 125,
#    'type': 'SYMPTOM'},
#   'obj': {'text': 'sốt cao', 'start': 147, 'end': 154, 'type': 'SYMPTOM'}},
#  {'text': 'trường hợp nặng : nếu các biểu hiện tiêu chảy nhiễm trùng trở nặng như : nôn ói không thể ăn uống , tiêu chảy phân nước nhiều , phân nhầy có máu , sốt cao hoặc rất mệt mỏi , người bệnh nên cân nhắc nhập viện để thực hiện các phương pháp điều trị chuyên môn như : bồi hoàn nước và điện giải qua truyền dịch tĩnh mạch , sử dụng thuốc kháng sinh theo chỉ định của bác sĩ . . nếu thực hiện chăm sóc đúng cách , người bệnh sẽ cảm thấy đỡ hơn trong vòng vài ngày đến một tuần , hoặc có thể mất vài tuần trước khi hệ thống đường ruột , dạ dày hồi phục hoàn toàn .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'tiêu chảy phân nước nhiều',
#    'start': 100,
#    'end': 125,
#    'type': 'SYMPTOM'},
#   'obj': {'text': 'điện giải qua truyền dịch tĩnh mạch',
#    'start': 280,
#    'end': 315,
#    'type': 'TREATMENT'}},
#  {'text': 'trường hợp nặng : nếu các biểu hiện tiêu chảy nhiễm trùng trở nặng như : nôn ói không thể ăn uống , tiêu chảy phân nước nhiều , phân nhầy có máu , sốt cao hoặc rất mệt mỏi , người bệnh nên cân nhắc nhập viện để thực hiện các phương pháp điều trị chuyên môn như : bồi hoàn nước và điện giải qua truyền dịch tĩnh mạch , sử dụng thuốc kháng sinh theo chỉ định của bác sĩ . . nếu thực hiện chăm sóc đúng cách , người bệnh sẽ cảm thấy đỡ hơn trong vòng vài ngày đến một tuần , hoặc có thể mất vài tuần trước khi hệ thống đường ruột , dạ dày hồi phục hoàn toàn .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'bồi hoàn nước',
#    'start': 263,
#    'end': 276,
#    'type': 'TREATMENT'},
#   'obj': {'text': 'tiêu chảy nhiễm trùng',
#    'start': 36,
#    'end': 57,
#    'type': 'DISEASE'}},
#  {'text': 'trường hợp nặng : nếu các biểu hiện tiêu chảy nhiễm trùng trở nặng như : nôn ói không thể ăn uống , tiêu chảy phân nước nhiều , phân nhầy có máu , sốt cao hoặc rất mệt mỏi , người bệnh nên cân nhắc nhập viện để thực hiện các phương pháp điều trị chuyên môn như : bồi hoàn nước và điện giải qua truyền dịch tĩnh mạch , sử dụng thuốc kháng sinh theo chỉ định của bác sĩ . . nếu thực hiện chăm sóc đúng cách , người bệnh sẽ cảm thấy đỡ hơn trong vòng vài ngày đến một tuần , hoặc có thể mất vài tuần trước khi hệ thống đường ruột , dạ dày hồi phục hoàn toàn .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'rất mệt mỏi', 'start': 160, 'end': 171, 'type': 'SYMPTOM'},
#   'obj': {'text': 'sốt cao', 'start': 147, 'end': 154, 'type': 'SYMPTOM'}},
#  {'text': 'trường hợp nặng : nếu các biểu hiện tiêu chảy nhiễm trùng trở nặng như : nôn ói không thể ăn uống , tiêu chảy phân nước nhiều , phân nhầy có máu , sốt cao hoặc rất mệt mỏi , người bệnh nên cân nhắc nhập viện để thực hiện các phương pháp điều trị chuyên môn như : bồi hoàn nước và điện giải qua truyền dịch tĩnh mạch , sử dụng thuốc kháng sinh theo chỉ định của bác sĩ . . nếu thực hiện chăm sóc đúng cách , người bệnh sẽ cảm thấy đỡ hơn trong vòng vài ngày đến một tuần , hoặc có thể mất vài tuần trước khi hệ thống đường ruột , dạ dày hồi phục hoàn toàn .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'phân nhầy có máu',
#    'start': 128,
#    'end': 144,
#    'type': 'SYMPTOM'},
#   'obj': {'text': 'tiêu chảy nhiễm trùng',
#    'start': 36,
#    'end': 57,
#    'type': 'DISEASE'}},
#  {'text': 'đối với viêm mạch ít nghiêm trọng hơn , khởi đầu điều trị bằng corticosteroid kết hợp với các thuốc ức chế miễn dịch ít độc ví dụ như : methotrexate , azathioprine , mycophenolate mofetil hoặc rituximab .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'viêm mạch', 'start': 8, 'end': 17, 'type': 'DISEASE'},
#   'obj': {'text': 'corticosteroid',
#    'start': 63,
#    'end': 77,
#    'type': 'TREATMENT'}},
#  {'text': 'đối với viêm mạch ít nghiêm trọng hơn , khởi đầu điều trị bằng corticosteroid kết hợp với các thuốc ức chế miễn dịch ít độc ví dụ như : methotrexate , azathioprine , mycophenolate mofetil hoặc rituximab .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'viêm mạch', 'start': 8, 'end': 17, 'type': 'DISEASE'},
#   'obj': {'text': 'methotrexate',
#    'start': 136,
#    'end': 148,
#    'type': 'TREATMENT'}},
#  {'text': 'đối với viêm mạch ít nghiêm trọng hơn , khởi đầu điều trị bằng corticosteroid kết hợp với các thuốc ức chế miễn dịch ít độc ví dụ như : methotrexate , azathioprine , mycophenolate mofetil hoặc rituximab .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'viêm mạch', 'start': 8, 'end': 17, 'type': 'DISEASE'},
#   'obj': {'text': 'azathioprine',
#    'start': 151,
#    'end': 163,
#    'type': 'TREATMENT'}},
#  {'text': 'đối với viêm mạch ít nghiêm trọng hơn , khởi đầu điều trị bằng corticosteroid kết hợp với các thuốc ức chế miễn dịch ít độc ví dụ như : methotrexate , azathioprine , mycophenolate mofetil hoặc rituximab .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'viêm mạch', 'start': 8, 'end': 17, 'type': 'DISEASE'},
#   'obj': {'text': 'mycophenolate mofetil',
#    'start': 166,
#    'end': 187,
#    'type': 'TREATMENT'}},
#  {'text': 'đối với viêm mạch ít nghiêm trọng hơn , khởi đầu điều trị bằng corticosteroid kết hợp với các thuốc ức chế miễn dịch ít độc ví dụ như : methotrexate , azathioprine , mycophenolate mofetil hoặc rituximab .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'viêm mạch', 'start': 8, 'end': 17, 'type': 'DISEASE'},
#   'obj': {'text': 'rituximab', 'start': 193, 'end': 202, 'type': 'TREATMENT'}},
#  {'text': 'đối với viêm mạch ít nghiêm trọng hơn , khởi đầu điều trị bằng corticosteroid kết hợp với các thuốc ức chế miễn dịch ít độc ví dụ như : methotrexate , azathioprine , mycophenolate mofetil hoặc rituximab .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'methotrexate',
#    'start': 136,
#    'end': 148,
#    'type': 'TREATMENT'},
#   'obj': {'text': 'corticosteroid',
#    'start': 63,
#    'end': 77,
#    'type': 'TREATMENT'}},
#  {'text': 'đối với viêm mạch ít nghiêm trọng hơn , khởi đầu điều trị bằng corticosteroid kết hợp với các thuốc ức chế miễn dịch ít độc ví dụ như : methotrexate , azathioprine , mycophenolate mofetil hoặc rituximab .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'corticosteroid',
#    'start': 63,
#    'end': 77,
#    'type': 'TREATMENT'},
#   'obj': {'text': 'rituximab', 'start': 193, 'end': 202, 'type': 'TREATMENT'}},
#  {'text': 'đối với viêm mạch ít nghiêm trọng hơn , khởi đầu điều trị bằng corticosteroid kết hợp với các thuốc ức chế miễn dịch ít độc ví dụ như : methotrexate , azathioprine , mycophenolate mofetil hoặc rituximab .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'mycophenolate mofetil',
#    'start': 166,
#    'end': 187,
#    'type': 'TREATMENT'},
#   'obj': {'text': 'rituximab', 'start': 193, 'end': 202, 'type': 'TREATMENT'}},
#  {'text': 'đối với viêm mạch ít nghiêm trọng hơn , khởi đầu điều trị bằng corticosteroid kết hợp với các thuốc ức chế miễn dịch ít độc ví dụ như : methotrexate , azathioprine , mycophenolate mofetil hoặc rituximab .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'rituximab', 'start': 193, 'end': 202, 'type': 'TREATMENT'},
#   'obj': {'text': 'viêm mạch', 'start': 8, 'end': 17, 'type': 'DISEASE'}},
#  {'text': 'đối với viêm mạch ít nghiêm trọng hơn , khởi đầu điều trị bằng corticosteroid kết hợp với các thuốc ức chế miễn dịch ít độc ví dụ như : methotrexate , azathioprine , mycophenolate mofetil hoặc rituximab .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'azathioprine',
#    'start': 151,
#    'end': 163,
#    'type': 'TREATMENT'},
#   'obj': {'text': 'rituximab', 'start': 193, 'end': 202, 'type': 'TREATMENT'}},
#  {'text': 'ht như là một liệu pháp kết hợp estrogen cộng với progestin , có thể làm tăng nguy cơ ung thư vú , chứng mất trí , bệnh tim , đột quỵ và các cục máu đông , do đó nó không thường được sử dụng để ngăn ngừa khối u đại tràng .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'ht', 'start': 0, 'end': 2, 'type': 'CAUSE'},
#   'obj': {'text': 'ung thư vú', 'start': 86, 'end': 96, 'type': 'DISEASE'}},
#  {'text': 'ht như là một liệu pháp kết hợp estrogen cộng với progestin , có thể làm tăng nguy cơ ung thư vú , chứng mất trí , bệnh tim , đột quỵ và các cục máu đông , do đó nó không thường được sử dụng để ngăn ngừa khối u đại tràng .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'ht', 'start': 0, 'end': 2, 'type': 'CAUSE'},
#   'obj': {'text': 'chứng mất trí',
#    'start': 99,
#    'end': 112,
#    'type': 'DISEASE'}},
#  {'text': 'ht như là một liệu pháp kết hợp estrogen cộng với progestin , có thể làm tăng nguy cơ ung thư vú , chứng mất trí , bệnh tim , đột quỵ và các cục máu đông , do đó nó không thường được sử dụng để ngăn ngừa khối u đại tràng .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'ht', 'start': 0, 'end': 2, 'type': 'CAUSE'},
#   'obj': {'text': 'bệnh tim', 'start': 115, 'end': 123, 'type': 'DISEASE'}},
#  {'text': 'ht như là một liệu pháp kết hợp estrogen cộng với progestin , có thể làm tăng nguy cơ ung thư vú , chứng mất trí , bệnh tim , đột quỵ và các cục máu đông , do đó nó không thường được sử dụng để ngăn ngừa khối u đại tràng .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'ht', 'start': 0, 'end': 2, 'type': 'CAUSE'},
#   'obj': {'text': 'đột quỵ', 'start': 126, 'end': 133, 'type': 'DISEASE'}},
#  {'text': 'ht như là một liệu pháp kết hợp estrogen cộng với progestin , có thể làm tăng nguy cơ ung thư vú , chứng mất trí , bệnh tim , đột quỵ và các cục máu đông , do đó nó không thường được sử dụng để ngăn ngừa khối u đại tràng .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'chứng mất trí',
#    'start': 99,
#    'end': 112,
#    'type': 'DISEASE'},
#   'obj': {'text': 'ht', 'start': 0, 'end': 2, 'type': 'CAUSE'}},
#  {'text': 'ht như là một liệu pháp kết hợp estrogen cộng với progestin , có thể làm tăng nguy cơ ung thư vú , chứng mất trí , bệnh tim , đột quỵ và các cục máu đông , do đó nó không thường được sử dụng để ngăn ngừa khối u đại tràng .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'bệnh tim', 'start': 115, 'end': 123, 'type': 'DISEASE'},
#   'obj': {'text': 'chứng mất trí',
#    'start': 99,
#    'end': 112,
#    'type': 'DISEASE'}},
#  {'text': 'ht như là một liệu pháp kết hợp estrogen cộng với progestin , có thể làm tăng nguy cơ ung thư vú , chứng mất trí , bệnh tim , đột quỵ và các cục máu đông , do đó nó không thường được sử dụng để ngăn ngừa khối u đại tràng .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'bệnh tim', 'start': 115, 'end': 123, 'type': 'DISEASE'},
#   'obj': {'text': 'đột quỵ', 'start': 126, 'end': 133, 'type': 'DISEASE'}},
#  {'text': 'ht như là một liệu pháp kết hợp estrogen cộng với progestin , có thể làm tăng nguy cơ ung thư vú , chứng mất trí , bệnh tim , đột quỵ và các cục máu đông , do đó nó không thường được sử dụng để ngăn ngừa khối u đại tràng .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'ung thư vú', 'start': 86, 'end': 96, 'type': 'DISEASE'},
#   'obj': {'text': 'ht', 'start': 0, 'end': 2, 'type': 'CAUSE'}},
#  {'text': 'triệu chứng thường gặp những dấu hiệu và triệu chứng của viêm màng ngoài tim khi viêm màng ngoài tim do vi khuẩn , bạn có thể bị sốt , ớn lạnh , tăng số lượng bạch cầu .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'viêm màng ngoài tim do vi khuẩn ',
#    'start': 81,
#    'end': 113,
#    'type': 'DISEASE'},
#   'obj': {'text': 'viêm màng ngoài tim',
#    'start': 57,
#    'end': 76,
#    'type': 'DISEASE'}},
#  {'text': 'hãy đến gặp bác sĩ ngay khi bạn có các dấu hiệu hoặc có nguy cơ cao của bệnh u trung thất như như : đau ngực , ho , sốt , khó thở , sút cân .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'bệnh u trung thất',
#    'start': 72,
#    'end': 89,
#    'type': 'DISEASE'},
#   'obj': {'text': 'sốt', 'start': 116, 'end': 119, 'type': 'SYMPTOM'}},
#  {'text': 'quan ngại lớn nhất của nhiễm trùng huyết là tập hợp những biểu hiện lâm sàng của tình trạng nhiễm trùng – nhiễm độc toàn thân , gây choáng ( sốc ) , suy đa tạng và tử vong nhanh .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'nhiễm độc', 'start': 106, 'end': 115, 'type': 'SYMPTOM'},
#   'obj': {'text': 'nhiễm trùng huyết',
#    'start': 23,
#    'end': 40,
#    'type': 'DISEASE'}},
#  {'text': 'tránh chảy nước mũi là rất quan trọng khi có vách ngăn lệch vì chất nhờn có thể trở thành chặn tại đoạn mũi hẹp , gây khó chịu , nhỏ giọt mũi sau hay cuối cùng nhiễm trùng xoang .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'chảy nước mũi', 'start': 6, 'end': 19, 'type': 'SYMPTOM'},
#   'obj': {'text': 'khó chịu', 'start': 118, 'end': 126, 'type': 'SYMPTOM'}},
#  {'text': 'khối u mũi nhỏ có thể không gây ra có vấn đề và không được chú ý . polyp mũi lớn hơn có thể chặn đường mũi , viêm xoang và gây ra khó thở , mất khứu giác , viêm xoang thường xuyên và các vấn đề khác .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'mất khứu giác',
#    'start': 140,
#    'end': 153,
#    'type': 'SYMPTOM'},
#   'obj': {'text': 'viêm xoang', 'start': 109, 'end': 119, 'type': 'DISEASE'}},
#  {'text': 'xquang ổ bụng : xquang ổ bụng không chuẩn bị hoặc chụp ruột non có thuốc barium sinh thiết : sinh thiết làm giải phẫu bệnh tổn thương là tiêu chuẩn chính trong chẩn đoán ung thư ruột non .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'sinh thiết', 'start': 80, 'end': 90, 'type': 'DIAGNOSTIC'},
#   'obj': {'text': 'chụp ruột non có thuốc barium',
#    'start': 50,
#    'end': 79,
#    'type': 'DIAGNOSTIC'}},
#  {'text': 'hình ảnh bụng hoặc vùng bụng với siêu âm , x quang hoặc chụp cắt lớp vi tính ( ct ) có thể phát hiện tắc ruột do lồng ruột .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'tắc ruột', 'start': 101, 'end': 109, 'type': 'DISEASE'},
#   'obj': {'text': 'ct ', 'start': 79, 'end': 82, 'type': 'DIAGNOSTIC'}},
#  {'text': 'siêu âm qua nội soi : có thể góp phần chẩn đoán ung thư tụy chụp cắt lớp vi tính ( ct scan ) : đây là xét nghiệm được lựa chọn để giúp chẩn đoán ung thư tụy .',
#   'relation': 'No_Relation',
#   'subj': {'text': 'ung thư tụy', 'start': 48, 'end': 59, 'type': 'DISEASE'},
#   'obj': {'text': 'ung thư tụy', 'start': 145, 'end': 156, 'type': 'DISEASE'}},
#  ...]

# %%
with open('train_data_fixed.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

labels = [item['relation'] for item in data]

# 2. Split train/temp (80/20)
train_data, temp_data = train_test_split(
    data, 
    test_size=0.2, 
    random_state=42, 
    stratify=labels
)

# 3. Split dev/test (50/50)
temp_labels = [item['relation'] for item in temp_data]
dev_data, test_data = train_test_split(
    temp_data, 
    test_size=0.5, 
    random_state=42, 
    stratify=temp_labels
)

# 4. Save
def save_json(data, filename):
    with open(filename, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=4)

save_json(train_data, 'train.json')
save_json(dev_data, 'dev.json')
save_json(test_data, 'test.json')

print(f"Train: {len(train_data)}, Dev: {len(dev_data)}, Test: {len(test_data)}")
# Out:
# Train: 948, Dev: 118, Test: 119

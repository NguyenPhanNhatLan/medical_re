# %%
import json
from sklearn.model_selection import train_test_split

# %%
import json
import random
from itertools import permutations

def convert_label_studio_to_re_format(
    input_file, 
    output_file, 
    negative_ratio=0.5 
):
    """
    Chuyển đổi JSON export từ Label Studio sang định dạng train cho RBERT.
    Đã sửa để hỗ trợ cả Single Object JSON và List JSON.
    """
    
    try:
        with open(input_file, 'r', encoding='utf-8') as f:
            ls_data = json.load(f)
    except FileNotFoundError:
        print(f"Lỗi: Không tìm thấy file {input_file}")
        return []

    # --- SỬA LỖI QUAN TRỌNG: Chuẩn hóa dữ liệu về dạng List ---
    # Nếu file json chỉ chứa 1 object (bắt đầu bằng { "id":... }), ta gói nó vào list
    if isinstance(ls_data, dict):
        ls_data = [ls_data]
    
    final_data = []
    stats = {"positive": 0, "negative": 0, "relations": {}}

    for task in ls_data:
        # 1. Lấy văn bản gốc
        # Kiểm tra kỹ key chứa text (thường là 'text' hoặc 'sentence' tùy config Label Studio)
        data_block = task.get('data', {})
        text = data_block.get('text') or data_block.get('sentence')
        
        if not text:
            print(f"Bỏ qua Task ID {task.get('id', 'Unknown')}: Không tìm thấy text.")
            continue

        # 2. Parse Entities (Nodes)
        entities = {}
        annotations = task.get('annotations', [])
        if not annotations:
            continue
            
        # Lấy annotation đầu tiên (thường là bản mới nhất hoặc ground_truth)
        result = annotations[0].get('result', [])
        
        # Bước 2a: Map ID -> Entity Info
        for item in result:
            if item['type'] == 'labels':
                entity_id = item['id']
                value = item['value']
                
                # Lấy nhãn đầu tiên trong mảng labels
                label_type = value['labels'][0] if value.get('labels') else "Unknown"

                entities[entity_id] = {
                    'text': value['text'],
                    'start': value['start'],
                    'end': value['end'],
                    'type': label_type  # Quan trọng cho Type-Aware Model
                }

        # Bước 2b: Lấy Relations (Edges)
        existing_relations = set() 
        
        for item in result:
            if item['type'] == 'relation':
                from_id = item['from_id']
                to_id = item['to_id']
                relation_label = item['labels'][0] if item.get('labels') else "NO_RELATION"
                
                if from_id in entities and to_id in entities:
                    subj = entities[from_id]
                    obj = entities[to_id]
                    
                    sample = {
                        "text": text,
                        "relation": relation_label,
                        "subj": subj,
                        "obj": obj
                    }
                    final_data.append(sample)
                    existing_relations.add((from_id, to_id))
                    
                    stats["positive"] += 1
                    stats["relations"][relation_label] = stats["relations"].get(relation_label, 0) + 1

        # Bước 3: Negative Sampling (Tạo mẫu No_Relation)
        entity_ids = list(entities.keys())
        all_pairs = list(permutations(entity_ids, 2)) 
        
        potential_negatives = []
        for e1_id, e2_id in all_pairs:
            if (e1_id, e2_id) not in existing_relations:
                potential_negatives.append((e1_id, e2_id))
        
        # Logic lấy số lượng negative sample
        num_neg_to_take = int(len(existing_relations) * negative_ratio)
        
        # Nếu có entity nhưng chưa có relation nào, vẫn lấy 1 mẫu negative để model học
        if len(existing_relations) == 0 and len(potential_negatives) > 0 and negative_ratio > 0:
             num_neg_to_take = 1
        # Nếu tính ra 0 nhưng user muốn lấy (negative_ratio > 0) và có relations, tối thiểu lấy 1
        elif len(existing_relations) > 0 and num_neg_to_take == 0 and negative_ratio > 0:
             num_neg_to_take = 1

        random.shuffle(potential_negatives)
        selected_negatives = potential_negatives[:num_neg_to_take]
        
        for e1_id, e2_id in selected_negatives:
            subj = entities[e1_id]
            obj = entities[e2_id]
            
            sample = {
                "text": text,
                "relation": "NO_RELATION",
                "subj": subj,
                "obj": obj
            }
            final_data.append(sample)
            stats["negative"] += 1

    # Lưu file
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(final_data, f, ensure_ascii=False, indent=2)

    print("=== Conversion Completed ===")
    print(f"Total samples generated: {len(final_data)}")
    print(f"Positive samples: {stats['positive']}")
    print(f"Negative samples: {stats['negative']}")
    print("Relation Types Breakdown:", stats["relations"])
    return final_data

# --- CHẠY VỚI DỮ LIỆU CỦA BẠN ---
# Lưu đoạn JSON bạn đưa vào file tên 'dataset2.json' trước khi chạy
convert_label_studio_to_re_format("full.json", "full_data.json", negative_ratio=1.0)
# Out:
# === Conversion Completed ===
# Total samples generated: 4721
# Positive samples: 2337
# Negative samples: 2384
# Relation Types Breakdown: {'CAUSES': 537, 'TREATED_WITH': 459, 'HAS_MANIFESTATION': 1120, 'REVEALS': 200, 'NO_RELATION': 21}
# [{'text': 'tuy nhiên , adalimumab , infliximab mang một số nguy cơ nhiễm trùng , bao gồm cả bệnh lao và nhiễm nấm nghiêm trọng .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'adalimumab', 'start': 12, 'end': 22, 'type': 'TREATMENT'},
#   'obj': {'text': 'bệnh lao', 'start': 81, 'end': 89, 'type': 'DISEASE'}},
#  {'text': 'tuy nhiên , adalimumab , infliximab mang một số nguy cơ nhiễm trùng , bao gồm cả bệnh lao và nhiễm nấm nghiêm trọng .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'adalimumab', 'start': 12, 'end': 22, 'type': 'TREATMENT'},
#   'obj': {'text': 'nhiễm nấm', 'start': 93, 'end': 102, 'type': 'DISEASE'}},
#  {'text': 'tuy nhiên , adalimumab , infliximab mang một số nguy cơ nhiễm trùng , bao gồm cả bệnh lao và nhiễm nấm nghiêm trọng .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'infliximab', 'start': 25, 'end': 35, 'type': 'TREATMENT'},
#   'obj': {'text': 'bệnh lao', 'start': 81, 'end': 89, 'type': 'DISEASE'}},
#  {'text': 'tuy nhiên , adalimumab , infliximab mang một số nguy cơ nhiễm trùng , bao gồm cả bệnh lao và nhiễm nấm nghiêm trọng .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'infliximab', 'start': 25, 'end': 35, 'type': 'TREATMENT'},
#   'obj': {'text': 'nhiễm nấm', 'start': 93, 'end': 102, 'type': 'DISEASE'}},
#  {'text': 'tuy nhiên , adalimumab , infliximab mang một số nguy cơ nhiễm trùng , bao gồm cả bệnh lao và nhiễm nấm nghiêm trọng .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'adalimumab', 'start': 12, 'end': 22, 'type': 'TREATMENT'},
#   'obj': {'text': 'infliximab', 'start': 25, 'end': 35, 'type': 'TREATMENT'}},
#  {'text': 'tuy nhiên , adalimumab , infliximab mang một số nguy cơ nhiễm trùng , bao gồm cả bệnh lao và nhiễm nấm nghiêm trọng .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'bệnh lao', 'start': 81, 'end': 89, 'type': 'DISEASE'},
#   'obj': {'text': 'adalimumab', 'start': 12, 'end': 22, 'type': 'TREATMENT'}},
#  {'text': 'tuy nhiên , adalimumab , infliximab mang một số nguy cơ nhiễm trùng , bao gồm cả bệnh lao và nhiễm nấm nghiêm trọng .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'nhiễm nấm', 'start': 93, 'end': 102, 'type': 'DISEASE'},
#   'obj': {'text': 'infliximab', 'start': 25, 'end': 35, 'type': 'TREATMENT'}},
#  {'text': 'tuy nhiên , adalimumab , infliximab mang một số nguy cơ nhiễm trùng , bao gồm cả bệnh lao và nhiễm nấm nghiêm trọng .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'nhiễm nấm', 'start': 93, 'end': 102, 'type': 'DISEASE'},
#   'obj': {'text': 'adalimumab', 'start': 12, 'end': 22, 'type': 'TREATMENT'}},
#  {'text': 'phòng ngừa bệnh thoát vị đùi để ngăn chặn thoát vị đùi , cần tuân theo các biện pháp sau : chế độ ăn uống nhiều chất xơ và uống nhiều nước để ngăn chặn táo bón và phải gắng sức khi đi cầu .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'bệnh thoát vị đùi',
#    'start': 11,
#    'end': 28,
#    'type': 'DISEASE'},
#   'obj': {'text': 'chế độ ăn uống nhiều chất xơ',
#    'start': 91,
#    'end': 119,
#    'type': 'TREATMENT'}},
#  {'text': 'phòng ngừa bệnh thoát vị đùi để ngăn chặn thoát vị đùi , cần tuân theo các biện pháp sau : chế độ ăn uống nhiều chất xơ và uống nhiều nước để ngăn chặn táo bón và phải gắng sức khi đi cầu .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'bệnh thoát vị đùi',
#    'start': 11,
#    'end': 28,
#    'type': 'DISEASE'},
#   'obj': {'text': 'uống nhiều nước',
#    'start': 123,
#    'end': 138,
#    'type': 'TREATMENT'}},
#  {'text': 'phòng ngừa bệnh thoát vị đùi để ngăn chặn thoát vị đùi , cần tuân theo các biện pháp sau : chế độ ăn uống nhiều chất xơ và uống nhiều nước để ngăn chặn táo bón và phải gắng sức khi đi cầu .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'bệnh thoát vị đùi',
#    'start': 11,
#    'end': 28,
#    'type': 'DISEASE'},
#   'obj': {'text': 'táo bón', 'start': 152, 'end': 159, 'type': 'SYMPTOM'}},
#  {'text': 'phòng ngừa bệnh thoát vị đùi để ngăn chặn thoát vị đùi , cần tuân theo các biện pháp sau : chế độ ăn uống nhiều chất xơ và uống nhiều nước để ngăn chặn táo bón và phải gắng sức khi đi cầu .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'táo bón', 'start': 152, 'end': 159, 'type': 'SYMPTOM'},
#   'obj': {'text': 'bệnh thoát vị đùi',
#    'start': 11,
#    'end': 28,
#    'type': 'DISEASE'}},
#  {'text': 'phòng ngừa bệnh thoát vị đùi để ngăn chặn thoát vị đùi , cần tuân theo các biện pháp sau : chế độ ăn uống nhiều chất xơ và uống nhiều nước để ngăn chặn táo bón và phải gắng sức khi đi cầu .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'thoát vị đùi', 'start': 42, 'end': 54, 'type': 'DISEASE'},
#   'obj': {'text': 'uống nhiều nước',
#    'start': 123,
#    'end': 138,
#    'type': 'TREATMENT'}},
#  {'text': 'phòng ngừa bệnh thoát vị đùi để ngăn chặn thoát vị đùi , cần tuân theo các biện pháp sau : chế độ ăn uống nhiều chất xơ và uống nhiều nước để ngăn chặn táo bón và phải gắng sức khi đi cầu .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'chế độ ăn uống nhiều chất xơ',
#    'start': 91,
#    'end': 119,
#    'type': 'TREATMENT'},
#   'obj': {'text': 'uống nhiều nước',
#    'start': 123,
#    'end': 138,
#    'type': 'TREATMENT'}},
#  {'text': 'ví dụ , quá nhiều vitamin k có thể bỏ qua khả năng làm loãng máu và ngăn ngừa đông máu của warfarin .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'quá nhiều vitamin k',
#    'start': 8,
#    'end': 27,
#    'type': 'CAUSE'},
#   'obj': {'text': 'làm loãng máu', 'start': 51, 'end': 64, 'type': 'DISEASE'}},
#  {'text': 'ví dụ , quá nhiều vitamin k có thể bỏ qua khả năng làm loãng máu và ngăn ngừa đông máu của warfarin .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'quá nhiều vitamin k',
#    'start': 8,
#    'end': 27,
#    'type': 'CAUSE'},
#   'obj': {'text': 'ngăn ngừa đông máu',
#    'start': 68,
#    'end': 86,
#    'type': 'DISEASE'}},
#  {'text': 'ví dụ , quá nhiều vitamin k có thể bỏ qua khả năng làm loãng máu và ngăn ngừa đông máu của warfarin .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'ngăn ngừa đông máu',
#    'start': 68,
#    'end': 86,
#    'type': 'DISEASE'},
#   'obj': {'text': 'làm loãng máu', 'start': 51, 'end': 64, 'type': 'DISEASE'}},
#  {'text': 'ví dụ , quá nhiều vitamin k có thể bỏ qua khả năng làm loãng máu và ngăn ngừa đông máu của warfarin .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'ngăn ngừa đông máu',
#    'start': 68,
#    'end': 86,
#    'type': 'DISEASE'},
#   'obj': {'text': 'quá nhiều vitamin k',
#    'start': 8,
#    'end': 27,
#    'type': 'CAUSE'}},
#  {'text': 'lạm dụng thuốc xịt mũi thuốc thông mũi có thể gây ra một loại viêm mũi không dị ứng gọi là viêm mũi medicamentosa .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'lạm dụng thuốc xịt mũi',
#    'start': 0,
#    'end': 22,
#    'type': 'CAUSE'},
#   'obj': {'text': 'viêm mũi không dị ứng',
#    'start': 62,
#    'end': 83,
#    'type': 'DISEASE'}},
#  {'text': 'lạm dụng thuốc xịt mũi thuốc thông mũi có thể gây ra một loại viêm mũi không dị ứng gọi là viêm mũi medicamentosa .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'lạm dụng thuốc xịt mũi',
#    'start': 0,
#    'end': 22,
#    'type': 'CAUSE'},
#   'obj': {'text': 'viêm mũi medicamentosa',
#    'start': 91,
#    'end': 113,
#    'type': 'DISEASE'}},
#  {'text': 'lạm dụng thuốc xịt mũi thuốc thông mũi có thể gây ra một loại viêm mũi không dị ứng gọi là viêm mũi medicamentosa .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'thuốc thông mũi ',
#    'start': 23,
#    'end': 39,
#    'type': 'CAUSE'},
#   'obj': {'text': 'viêm mũi không dị ứng',
#    'start': 62,
#    'end': 83,
#    'type': 'DISEASE'}},
#  {'text': 'lạm dụng thuốc xịt mũi thuốc thông mũi có thể gây ra một loại viêm mũi không dị ứng gọi là viêm mũi medicamentosa .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'thuốc thông mũi ',
#    'start': 23,
#    'end': 39,
#    'type': 'CAUSE'},
#   'obj': {'text': 'viêm mũi medicamentosa',
#    'start': 91,
#    'end': 113,
#    'type': 'DISEASE'}},
#  {'text': 'lạm dụng thuốc xịt mũi thuốc thông mũi có thể gây ra một loại viêm mũi không dị ứng gọi là viêm mũi medicamentosa .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'lạm dụng thuốc xịt mũi',
#    'start': 0,
#    'end': 22,
#    'type': 'CAUSE'},
#   'obj': {'text': 'thuốc thông mũi ',
#    'start': 23,
#    'end': 39,
#    'type': 'CAUSE'}},
#  {'text': 'lạm dụng thuốc xịt mũi thuốc thông mũi có thể gây ra một loại viêm mũi không dị ứng gọi là viêm mũi medicamentosa .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'viêm mũi không dị ứng',
#    'start': 62,
#    'end': 83,
#    'type': 'DISEASE'},
#   'obj': {'text': 'lạm dụng thuốc xịt mũi',
#    'start': 0,
#    'end': 22,
#    'type': 'CAUSE'}},
#  {'text': 'lạm dụng thuốc xịt mũi thuốc thông mũi có thể gây ra một loại viêm mũi không dị ứng gọi là viêm mũi medicamentosa .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'viêm mũi không dị ứng',
#    'start': 62,
#    'end': 83,
#    'type': 'DISEASE'},
#   'obj': {'text': 'viêm mũi medicamentosa',
#    'start': 91,
#    'end': 113,
#    'type': 'DISEASE'}},
#  {'text': 'lạm dụng thuốc xịt mũi thuốc thông mũi có thể gây ra một loại viêm mũi không dị ứng gọi là viêm mũi medicamentosa .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'thuốc thông mũi ',
#    'start': 23,
#    'end': 39,
#    'type': 'CAUSE'},
#   'obj': {'text': 'lạm dụng thuốc xịt mũi',
#    'start': 0,
#    'end': 22,
#    'type': 'CAUSE'}},
#  {'text': 'những tiếng thổi tâm trương có thể tồn tại cùng với tiếng thổi do hẹp van hai lá : tiếng thổi tâm trương sớm của hở van hai lá đồng mắc ( ar ) , có thể lan đến mỏm tim .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'hẹp van hai lá',
#    'start': 66,
#    'end': 80,
#    'type': 'DISEASE'},
#   'obj': {'text': 'tiếng thổi tâm trương',
#    'start': 6,
#    'end': 27,
#    'type': 'SYMPTOM'}},
#  {'text': 'những tiếng thổi tâm trương có thể tồn tại cùng với tiếng thổi do hẹp van hai lá : tiếng thổi tâm trương sớm của hở van hai lá đồng mắc ( ar ) , có thể lan đến mỏm tim .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'hở van hai lá',
#    'start': 113,
#    'end': 126,
#    'type': 'DISEASE'},
#   'obj': {'text': 'tiếng thổi tâm trương',
#    'start': 83,
#    'end': 104,
#    'type': 'SYMPTOM'}},
#  {'text': 'những tiếng thổi tâm trương có thể tồn tại cùng với tiếng thổi do hẹp van hai lá : tiếng thổi tâm trương sớm của hở van hai lá đồng mắc ( ar ) , có thể lan đến mỏm tim .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'hở van hai lá',
#    'start': 113,
#    'end': 126,
#    'type': 'DISEASE'},
#   'obj': {'text': 'tiếng thổi tâm trương',
#    'start': 6,
#    'end': 27,
#    'type': 'SYMPTOM'}},
#  {'text': 'những tiếng thổi tâm trương có thể tồn tại cùng với tiếng thổi do hẹp van hai lá : tiếng thổi tâm trương sớm của hở van hai lá đồng mắc ( ar ) , có thể lan đến mỏm tim .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'tiếng thổi tâm trương',
#    'start': 6,
#    'end': 27,
#    'type': 'SYMPTOM'},
#   'obj': {'text': 'hẹp van hai lá',
#    'start': 66,
#    'end': 80,
#    'type': 'DISEASE'}},
#  {'text': 'phương pháp điều trị để đối phó với kháng sinh liên quan đến tiêu chảy nhẹ nếu bị tiêu chảy nhẹ , triệu chứng có thể hết trong vòng một vài ngày sau khi điều trị kháng sinh kết thúc .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'tiêu chảy', 'start': 61, 'end': 70, 'type': 'DISEASE'},
#   'obj': {'text': 'kháng sinh', 'start': 36, 'end': 46, 'type': 'TREATMENT'}},
#  {'text': 'phương pháp điều trị để đối phó với kháng sinh liên quan đến tiêu chảy nhẹ nếu bị tiêu chảy nhẹ , triệu chứng có thể hết trong vòng một vài ngày sau khi điều trị kháng sinh kết thúc .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'kháng sinh', 'start': 36, 'end': 46, 'type': 'TREATMENT'},
#   'obj': {'text': 'kháng sinh',
#    'start': 162,
#    'end': 172,
#    'type': 'TREATMENT'}},
#  {'text': 'một nhiễm trùng do vi khuẩn hoặc virus của chất lỏng này thường là những gì gây ra các triệu chứng của nhiễm trùng tai .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'vi khuẩn', 'start': 19, 'end': 27, 'type': 'CAUSE'},
#   'obj': {'text': 'nhiễm trùng', 'start': 4, 'end': 15, 'type': 'DISEASE'}},
#  {'text': 'một nhiễm trùng do vi khuẩn hoặc virus của chất lỏng này thường là những gì gây ra các triệu chứng của nhiễm trùng tai .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'virus', 'start': 33, 'end': 38, 'type': 'CAUSE'},
#   'obj': {'text': 'nhiễm trùng', 'start': 4, 'end': 15, 'type': 'DISEASE'}},
#  {'text': 'một nhiễm trùng do vi khuẩn hoặc virus của chất lỏng này thường là những gì gây ra các triệu chứng của nhiễm trùng tai .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'nhiễm trùng tai',
#    'start': 103,
#    'end': 118,
#    'type': 'DISEASE'},
#   'obj': {'text': 'virus', 'start': 33, 'end': 38, 'type': 'CAUSE'}},
#  {'text': 'một nhiễm trùng do vi khuẩn hoặc virus của chất lỏng này thường là những gì gây ra các triệu chứng của nhiễm trùng tai .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'virus', 'start': 33, 'end': 38, 'type': 'CAUSE'},
#   'obj': {'text': 'vi khuẩn', 'start': 19, 'end': 27, 'type': 'CAUSE'}},
#  {'text': 'phương pháp điều trị lạnh lạnh ( cryotherapy ) có thể được sử dụng để tiêu diệt các tế bào u ác tính ở một số u sắc tố mắt nhỏ , nhưng điều trị này không thường được sử dụng .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'u ác tính', 'start': 91, 'end': 100, 'type': 'DISEASE'},
#   'obj': {'text': 'điều trị lạnh',
#    'start': 12,
#    'end': 25,
#    'type': 'TREATMENT'}},
#  {'text': 'phương pháp điều trị lạnh lạnh ( cryotherapy ) có thể được sử dụng để tiêu diệt các tế bào u ác tính ở một số u sắc tố mắt nhỏ , nhưng điều trị này không thường được sử dụng .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'u ác tính', 'start': 91, 'end': 100, 'type': 'DISEASE'},
#   'obj': {'text': 'cryotherapy', 'start': 33, 'end': 44, 'type': 'TREATMENT'}},
#  {'text': 'phương pháp điều trị lạnh lạnh ( cryotherapy ) có thể được sử dụng để tiêu diệt các tế bào u ác tính ở một số u sắc tố mắt nhỏ , nhưng điều trị này không thường được sử dụng .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'u sắc tố mắt nhỏ',
#    'start': 110,
#    'end': 126,
#    'type': 'DISEASE'},
#   'obj': {'text': 'điều trị lạnh',
#    'start': 12,
#    'end': 25,
#    'type': 'TREATMENT'}},
#  {'text': 'phương pháp điều trị lạnh lạnh ( cryotherapy ) có thể được sử dụng để tiêu diệt các tế bào u ác tính ở một số u sắc tố mắt nhỏ , nhưng điều trị này không thường được sử dụng .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'u sắc tố mắt nhỏ',
#    'start': 110,
#    'end': 126,
#    'type': 'DISEASE'},
#   'obj': {'text': 'cryotherapy', 'start': 33, 'end': 44, 'type': 'TREATMENT'}},
#  {'text': 'phương pháp điều trị lạnh lạnh ( cryotherapy ) có thể được sử dụng để tiêu diệt các tế bào u ác tính ở một số u sắc tố mắt nhỏ , nhưng điều trị này không thường được sử dụng .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'điều trị lạnh',
#    'start': 12,
#    'end': 25,
#    'type': 'TREATMENT'},
#   'obj': {'text': 'cryotherapy', 'start': 33, 'end': 44, 'type': 'TREATMENT'}},
#  {'text': 'phương pháp điều trị lạnh lạnh ( cryotherapy ) có thể được sử dụng để tiêu diệt các tế bào u ác tính ở một số u sắc tố mắt nhỏ , nhưng điều trị này không thường được sử dụng .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'điều trị lạnh',
#    'start': 12,
#    'end': 25,
#    'type': 'TREATMENT'},
#   'obj': {'text': 'u ác tính', 'start': 91, 'end': 100, 'type': 'DISEASE'}},
#  {'text': 'phương pháp điều trị lạnh lạnh ( cryotherapy ) có thể được sử dụng để tiêu diệt các tế bào u ác tính ở một số u sắc tố mắt nhỏ , nhưng điều trị này không thường được sử dụng .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'cryotherapy', 'start': 33, 'end': 44, 'type': 'TREATMENT'},
#   'obj': {'text': 'điều trị lạnh',
#    'start': 12,
#    'end': 25,
#    'type': 'TREATMENT'}},
#  {'text': 'phương pháp điều trị lạnh lạnh ( cryotherapy ) có thể được sử dụng để tiêu diệt các tế bào u ác tính ở một số u sắc tố mắt nhỏ , nhưng điều trị này không thường được sử dụng .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'u ác tính', 'start': 91, 'end': 100, 'type': 'DISEASE'},
#   'obj': {'text': 'u sắc tố mắt nhỏ',
#    'start': 110,
#    'end': 126,
#    'type': 'DISEASE'}},
#  {'text': 'phòng chống dịch virus một số hình thức của viêm giác mạc do virus , chẳng hạn như viêm giác mạc do virus herpes , không thể loại bỏ hoàn toàn .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'virus herpes', 'start': 100, 'end': 112, 'type': 'CAUSE'},
#   'obj': {'text': 'viêm giác mạc', 'start': 83, 'end': 96, 'type': 'DISEASE'}},
#  {'text': 'phòng chống dịch virus một số hình thức của viêm giác mạc do virus , chẳng hạn như viêm giác mạc do virus herpes , không thể loại bỏ hoàn toàn .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'viêm giác mạc', 'start': 44, 'end': 57, 'type': 'DISEASE'},
#   'obj': {'text': 'virus', 'start': 17, 'end': 22, 'type': 'CAUSE'}},
#  {'text': 'phòng chống dịch virus một số hình thức của viêm giác mạc do virus , chẳng hạn như viêm giác mạc do virus herpes , không thể loại bỏ hoàn toàn .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'viêm giác mạc', 'start': 83, 'end': 96, 'type': 'DISEASE'},
#   'obj': {'text': 'viêm giác mạc', 'start': 44, 'end': 57, 'type': 'DISEASE'}},
#  {'text': 'phòng chống dịch virus một số hình thức của viêm giác mạc do virus , chẳng hạn như viêm giác mạc do virus herpes , không thể loại bỏ hoàn toàn .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'viêm giác mạc', 'start': 83, 'end': 96, 'type': 'DISEASE'},
#   'obj': {'text': 'virus herpes', 'start': 100, 'end': 112, 'type': 'CAUSE'}},
#  {'text': '. . sốt rét ác tính/biến chứng : sốt rét có biến chứng đe dọa tính mạng người bệnh , thường xảy ra trên người bệnh nhiễm p . falciparum hoặc nhiễm phối hợp p . falciparum .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'nhiễm p . falciparum',
#    'start': 115,
#    'end': 135,
#    'type': 'DISEASE'},
#   'obj': {'text': 'sốt rét', 'start': 4, 'end': 11, 'type': 'SYMPTOM'}},
#  {'text': '. . sốt rét ác tính/biến chứng : sốt rét có biến chứng đe dọa tính mạng người bệnh , thường xảy ra trên người bệnh nhiễm p . falciparum hoặc nhiễm phối hợp p . falciparum .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'nhiễm phối hợp p . falciparum',
#    'start': 141,
#    'end': 170,
#    'type': 'DISEASE'},
#   'obj': {'text': 'sốt rét', 'start': 4, 'end': 11, 'type': 'SYMPTOM'}},
#  {'text': '. . sốt rét ác tính/biến chứng : sốt rét có biến chứng đe dọa tính mạng người bệnh , thường xảy ra trên người bệnh nhiễm p . falciparum hoặc nhiễm phối hợp p . falciparum .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'nhiễm phối hợp p . falciparum',
#    'start': 141,
#    'end': 170,
#    'type': 'DISEASE'},
#   'obj': {'text': 'nhiễm p . falciparum',
#    'start': 115,
#    'end': 135,
#    'type': 'DISEASE'}},
#  {'text': '. . sốt rét ác tính/biến chứng : sốt rét có biến chứng đe dọa tính mạng người bệnh , thường xảy ra trên người bệnh nhiễm p . falciparum hoặc nhiễm phối hợp p . falciparum .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'sốt rét', 'start': 4, 'end': 11, 'type': 'SYMPTOM'},
#   'obj': {'text': 'nhiễm p . falciparum',
#    'start': 115,
#    'end': 135,
#    'type': 'DISEASE'}},
#  {'text': 'tác dụng phụ ngắn hạn bao gồm buồn nôn , mệt mỏi và tiêu chảy , và hiếm khi nó có thể gây viêm phổi có khả năng đe dọa tính mạng .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'mệt mỏi', 'start': 41, 'end': 48, 'type': 'DISEASE'},
#   'obj': {'text': 'buồn nôn', 'start': 30, 'end': 38, 'type': 'DISEASE'}},
#  {'text': 'các tình trạng tim liên quan đến đánh trống ngực bao gồm : trước cơn đau tim; bệnh động mạch vành; suy tim; các vấn đề về van tim; các vấn đề về cơ tim .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'bệnh động mạch vành',
#    'start': 78,
#    'end': 97,
#    'type': 'DISEASE'},
#   'obj': {'text': 'đánh trống ngực',
#    'start': 33,
#    'end': 48,
#    'type': 'SYMPTOM'}},
#  {'text': 'các tình trạng tim liên quan đến đánh trống ngực bao gồm : trước cơn đau tim; bệnh động mạch vành; suy tim; các vấn đề về van tim; các vấn đề về cơ tim .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'bệnh động mạch vành',
#    'start': 78,
#    'end': 97,
#    'type': 'DISEASE'},
#   'obj': {'text': 'cơn đau tim', 'start': 65, 'end': 76, 'type': 'SYMPTOM'}},
#  {'text': 'các tình trạng tim liên quan đến đánh trống ngực bao gồm : trước cơn đau tim; bệnh động mạch vành; suy tim; các vấn đề về van tim; các vấn đề về cơ tim .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'suy tim', 'start': 99, 'end': 106, 'type': 'DISEASE'},
#   'obj': {'text': 'đánh trống ngực',
#    'start': 33,
#    'end': 48,
#    'type': 'SYMPTOM'}},
#  {'text': 'các tình trạng tim liên quan đến đánh trống ngực bao gồm : trước cơn đau tim; bệnh động mạch vành; suy tim; các vấn đề về van tim; các vấn đề về cơ tim .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'suy tim', 'start': 99, 'end': 106, 'type': 'DISEASE'},
#   'obj': {'text': 'cơn đau tim', 'start': 65, 'end': 76, 'type': 'SYMPTOM'}},
#  {'text': 'các tình trạng tim liên quan đến đánh trống ngực bao gồm : trước cơn đau tim; bệnh động mạch vành; suy tim; các vấn đề về van tim; các vấn đề về cơ tim .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'cơn đau tim', 'start': 65, 'end': 76, 'type': 'SYMPTOM'},
#   'obj': {'text': 'bệnh động mạch vành',
#    'start': 78,
#    'end': 97,
#    'type': 'DISEASE'}},
#  {'text': 'các tình trạng tim liên quan đến đánh trống ngực bao gồm : trước cơn đau tim; bệnh động mạch vành; suy tim; các vấn đề về van tim; các vấn đề về cơ tim .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'đánh trống ngực',
#    'start': 33,
#    'end': 48,
#    'type': 'SYMPTOM'},
#   'obj': {'text': 'bệnh động mạch vành',
#    'start': 78,
#    'end': 97,
#    'type': 'DISEASE'}},
#  {'text': 'các tình trạng tim liên quan đến đánh trống ngực bao gồm : trước cơn đau tim; bệnh động mạch vành; suy tim; các vấn đề về van tim; các vấn đề về cơ tim .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'cơn đau tim', 'start': 65, 'end': 76, 'type': 'SYMPTOM'},
#   'obj': {'text': 'suy tim', 'start': 99, 'end': 106, 'type': 'DISEASE'}},
#  {'text': 'các tình trạng tim liên quan đến đánh trống ngực bao gồm : trước cơn đau tim; bệnh động mạch vành; suy tim; các vấn đề về van tim; các vấn đề về cơ tim .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'suy tim', 'start': 99, 'end': 106, 'type': 'DISEASE'},
#   'obj': {'text': 'bệnh động mạch vành',
#    'start': 78,
#    'end': 97,
#    'type': 'DISEASE'}},
#  {'text': 'trong thực tế , một số bệnh nhiễm trùng cổ họng do virus nhìn tồi tệ hơn nhiễm trùng do vi khuẩn liên cầu khuẩn .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'virus', 'start': 51, 'end': 56, 'type': 'CAUSE'},
#   'obj': {'text': 'bệnh nhiễm trùng cổ họng',
#    'start': 23,
#    'end': 47,
#    'type': 'DISEASE'}},
#  {'text': 'trong thực tế , một số bệnh nhiễm trùng cổ họng do virus nhìn tồi tệ hơn nhiễm trùng do vi khuẩn liên cầu khuẩn .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'vi khuẩn liên cầu khuẩn',
#    'start': 88,
#    'end': 111,
#    'type': 'CAUSE'},
#   'obj': {'text': ' nhiễm trùng', 'start': 72, 'end': 84, 'type': 'DISEASE'}},
#  {'text': 'trong thực tế , một số bệnh nhiễm trùng cổ họng do virus nhìn tồi tệ hơn nhiễm trùng do vi khuẩn liên cầu khuẩn .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'virus', 'start': 51, 'end': 56, 'type': 'CAUSE'},
#   'obj': {'text': 'vi khuẩn liên cầu khuẩn',
#    'start': 88,
#    'end': 111,
#    'type': 'CAUSE'}},
#  {'text': 'trong thực tế , một số bệnh nhiễm trùng cổ họng do virus nhìn tồi tệ hơn nhiễm trùng do vi khuẩn liên cầu khuẩn .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'bệnh nhiễm trùng cổ họng',
#    'start': 23,
#    'end': 47,
#    'type': 'DISEASE'},
#   'obj': {'text': ' nhiễm trùng', 'start': 72, 'end': 84, 'type': 'DISEASE'}},
#  {'text': 'phương pháp điều trị và thuốc viêm giác mạc không do nhiễm trùng điều trị viêm giác mạc không do nhiễm trùng thay đổi tùy theo nguyên nhân .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'do nhiễm trùng', 'start': 50, 'end': 64, 'type': 'CAUSE'},
#   'obj': {'text': 'viêm giác mạc', 'start': 30, 'end': 43, 'type': 'DISEASE'}},
#  {'text': 'phương pháp điều trị và thuốc viêm giác mạc không do nhiễm trùng điều trị viêm giác mạc không do nhiễm trùng thay đổi tùy theo nguyên nhân .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'do nhiễm trùng', 'start': 94, 'end': 108, 'type': 'CAUSE'},
#   'obj': {'text': 'viêm giác mạc', 'start': 74, 'end': 87, 'type': 'DISEASE'}},
#  {'text': 'phương pháp điều trị và thuốc viêm giác mạc không do nhiễm trùng điều trị viêm giác mạc không do nhiễm trùng thay đổi tùy theo nguyên nhân .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'do nhiễm trùng', 'start': 94, 'end': 108, 'type': 'CAUSE'},
#   'obj': {'text': 'do nhiễm trùng', 'start': 50, 'end': 64, 'type': 'CAUSE'}},
#  {'text': 'phương pháp điều trị và thuốc viêm giác mạc không do nhiễm trùng điều trị viêm giác mạc không do nhiễm trùng thay đổi tùy theo nguyên nhân .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'do nhiễm trùng', 'start': 50, 'end': 64, 'type': 'CAUSE'},
#   'obj': {'text': 'do nhiễm trùng', 'start': 94, 'end': 108, 'type': 'CAUSE'}},
#  {'text': 'trong khi thuốc kháng histamin đường uống không có vẻ giúp viêm mũi không dị ứng , chống dị ứng ở dạng thuốc xịt mũi có thể làm giảm triệu chứng của viêm mũi không dị ứng .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'viêm mũi không dị ứng',
#    'start': 149,
#    'end': 170,
#    'type': 'DISEASE'},
#   'obj': {'text': 'thuốc xịt mũi',
#    'start': 103,
#    'end': 116,
#    'type': 'TREATMENT'}},
#  {'text': 'trong khi thuốc kháng histamin đường uống không có vẻ giúp viêm mũi không dị ứng , chống dị ứng ở dạng thuốc xịt mũi có thể làm giảm triệu chứng của viêm mũi không dị ứng .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'viêm mũi không dị ứng',
#    'start': 149,
#    'end': 170,
#    'type': 'DISEASE'},
#   'obj': {'text': 'viêm mũi không dị ứng',
#    'start': 59,
#    'end': 80,
#    'type': 'DISEASE'}},
#  {'text': 'một chế độ ăn nhiều chất xơ , trái cây và rau quả như chế độ ăn địa trung hải có thể là tốt nhất cho những người có nguy cơ bị huyết khối tĩnh mạch sâu hoặc những người đã từng bị huyết khối tĩnh mạch sâu trước đó .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'huyết khối tĩnh mạch sâu',
#    'start': 127,
#    'end': 151,
#    'type': 'DISEASE'},
#   'obj': {'text': 'chế độ ăn nhiều chất xơ',
#    'start': 4,
#    'end': 27,
#    'type': 'TREATMENT'}},
#  {'text': 'một chế độ ăn nhiều chất xơ , trái cây và rau quả như chế độ ăn địa trung hải có thể là tốt nhất cho những người có nguy cơ bị huyết khối tĩnh mạch sâu hoặc những người đã từng bị huyết khối tĩnh mạch sâu trước đó .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'huyết khối tĩnh mạch sâu',
#    'start': 180,
#    'end': 204,
#    'type': 'DISEASE'},
#   'obj': {'text': 'hế độ ăn địa trung hải',
#    'start': 55,
#    'end': 77,
#    'type': 'TREATMENT'}},
#  {'text': 'một chế độ ăn nhiều chất xơ , trái cây và rau quả như chế độ ăn địa trung hải có thể là tốt nhất cho những người có nguy cơ bị huyết khối tĩnh mạch sâu hoặc những người đã từng bị huyết khối tĩnh mạch sâu trước đó .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'huyết khối tĩnh mạch sâu',
#    'start': 127,
#    'end': 151,
#    'type': 'DISEASE'},
#   'obj': {'text': 'hế độ ăn địa trung hải',
#    'start': 55,
#    'end': 77,
#    'type': 'TREATMENT'}},
#  {'text': 'một chế độ ăn nhiều chất xơ , trái cây và rau quả như chế độ ăn địa trung hải có thể là tốt nhất cho những người có nguy cơ bị huyết khối tĩnh mạch sâu hoặc những người đã từng bị huyết khối tĩnh mạch sâu trước đó .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'huyết khối tĩnh mạch sâu',
#    'start': 180,
#    'end': 204,
#    'type': 'DISEASE'},
#   'obj': {'text': 'chế độ ăn nhiều chất xơ',
#    'start': 4,
#    'end': 27,
#    'type': 'TREATMENT'}},
#  {'text': 'một chế độ ăn nhiều chất xơ , trái cây và rau quả như chế độ ăn địa trung hải có thể là tốt nhất cho những người có nguy cơ bị huyết khối tĩnh mạch sâu hoặc những người đã từng bị huyết khối tĩnh mạch sâu trước đó .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'huyết khối tĩnh mạch sâu',
#    'start': 180,
#    'end': 204,
#    'type': 'DISEASE'},
#   'obj': {'text': 'huyết khối tĩnh mạch sâu',
#    'start': 127,
#    'end': 151,
#    'type': 'DISEASE'}},
#  {'text': 'một chế độ ăn nhiều chất xơ , trái cây và rau quả như chế độ ăn địa trung hải có thể là tốt nhất cho những người có nguy cơ bị huyết khối tĩnh mạch sâu hoặc những người đã từng bị huyết khối tĩnh mạch sâu trước đó .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'huyết khối tĩnh mạch sâu',
#    'start': 127,
#    'end': 151,
#    'type': 'DISEASE'},
#   'obj': {'text': 'huyết khối tĩnh mạch sâu',
#    'start': 180,
#    'end': 204,
#    'type': 'DISEASE'}},
#  {'text': 'một chế độ ăn nhiều chất xơ , trái cây và rau quả như chế độ ăn địa trung hải có thể là tốt nhất cho những người có nguy cơ bị huyết khối tĩnh mạch sâu hoặc những người đã từng bị huyết khối tĩnh mạch sâu trước đó .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'chế độ ăn nhiều chất xơ',
#    'start': 4,
#    'end': 27,
#    'type': 'TREATMENT'},
#   'obj': {'text': 'hế độ ăn địa trung hải',
#    'start': 55,
#    'end': 77,
#    'type': 'TREATMENT'}},
#  {'text': 'một chế độ ăn nhiều chất xơ , trái cây và rau quả như chế độ ăn địa trung hải có thể là tốt nhất cho những người có nguy cơ bị huyết khối tĩnh mạch sâu hoặc những người đã từng bị huyết khối tĩnh mạch sâu trước đó .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'hế độ ăn địa trung hải',
#    'start': 55,
#    'end': 77,
#    'type': 'TREATMENT'},
#   'obj': {'text': 'chế độ ăn nhiều chất xơ',
#    'start': 4,
#    'end': 27,
#    'type': 'TREATMENT'}},
#  {'text': 'viêm gan do virus , bao gồm cả viêm gan a , b và c hoặc gây ra bởi tăng bạch cầu đơn nhân nhiễm khuẩn .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'do virus', 'start': 9, 'end': 17, 'type': 'CAUSE'},
#   'obj': {'text': 'viêm gan', 'start': 0, 'end': 8, 'type': 'DISEASE'}},
#  {'text': 'viêm gan do virus , bao gồm cả viêm gan a , b và c hoặc gây ra bởi tăng bạch cầu đơn nhân nhiễm khuẩn .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'tăng bạch cầu đơn nhân nhiễm khuẩn',
#    'start': 67,
#    'end': 101,
#    'type': 'CAUSE'},
#   'obj': {'text': 'viêm gan', 'start': 0, 'end': 8, 'type': 'DISEASE'}},
#  {'text': 'viêm gan do virus , bao gồm cả viêm gan a , b và c hoặc gây ra bởi tăng bạch cầu đơn nhân nhiễm khuẩn .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'viêm gan', 'start': 31, 'end': 39, 'type': 'DISEASE'},
#   'obj': {'text': 'viêm gan', 'start': 0, 'end': 8, 'type': 'DISEASE'}},
#  {'text': 'viêm gan do virus , bao gồm cả viêm gan a , b và c hoặc gây ra bởi tăng bạch cầu đơn nhân nhiễm khuẩn .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'do virus', 'start': 9, 'end': 17, 'type': 'CAUSE'},
#   'obj': {'text': 'viêm gan', 'start': 31, 'end': 39, 'type': 'DISEASE'}},
#  {'text': 'điều trị khối u tuyến nước bọt phụ thuộc vào loại , kích thước và giai đoạn của khối u tuyến nước bọt bao gồm phẫu thuật , có hoặc không có xạ trị .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'u tuyến nước bọt',
#    'start': 14,
#    'end': 30,
#    'type': 'DISEASE'},
#   'obj': {'text': 'phẫu thuật',
#    'start': 110,
#    'end': 120,
#    'type': 'TREATMENT'}},
#  {'text': 'điều trị khối u tuyến nước bọt phụ thuộc vào loại , kích thước và giai đoạn của khối u tuyến nước bọt bao gồm phẫu thuật , có hoặc không có xạ trị .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'u tuyến nước bọt',
#    'start': 14,
#    'end': 30,
#    'type': 'DISEASE'},
#   'obj': {'text': 'xạ trị', 'start': 140, 'end': 146, 'type': 'TREATMENT'}},
#  {'text': 'điều trị khối u tuyến nước bọt phụ thuộc vào loại , kích thước và giai đoạn của khối u tuyến nước bọt bao gồm phẫu thuật , có hoặc không có xạ trị .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'phẫu thuật',
#    'start': 110,
#    'end': 120,
#    'type': 'TREATMENT'},
#   'obj': {'text': 'xạ trị', 'start': 140, 'end': 146, 'type': 'TREATMENT'}},
#  {'text': 'điều trị khối u tuyến nước bọt phụ thuộc vào loại , kích thước và giai đoạn của khối u tuyến nước bọt bao gồm phẫu thuật , có hoặc không có xạ trị .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'xạ trị', 'start': 140, 'end': 146, 'type': 'TREATMENT'},
#   'obj': {'text': 'u tuyến nước bọt',
#    'start': 14,
#    'end': 30,
#    'type': 'DISEASE'}},
#  {'text': 'các biện pháp điều trị bệnh thoát vị đùi để điều trị thoát vị đùi , bệnh nhân sẽ được chỉ định đeo băng hoặc phẫu thuật .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'bệnh thoát vị đùi',
#    'start': 23,
#    'end': 40,
#    'type': 'DISEASE'},
#   'obj': {'text': 'đeo băng', 'start': 95, 'end': 103, 'type': 'TREATMENT'}},
#  {'text': 'các biện pháp điều trị bệnh thoát vị đùi để điều trị thoát vị đùi , bệnh nhân sẽ được chỉ định đeo băng hoặc phẫu thuật .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'bệnh thoát vị đùi',
#    'start': 23,
#    'end': 40,
#    'type': 'DISEASE'},
#   'obj': {'text': 'phẫu thuật',
#    'start': 109,
#    'end': 119,
#    'type': 'TREATMENT'}},
#  {'text': 'các biện pháp điều trị bệnh thoát vị đùi để điều trị thoát vị đùi , bệnh nhân sẽ được chỉ định đeo băng hoặc phẫu thuật .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'thoát vị đùi', 'start': 53, 'end': 65, 'type': 'DISEASE'},
#   'obj': {'text': 'bệnh thoát vị đùi',
#    'start': 23,
#    'end': 40,
#    'type': 'DISEASE'}},
#  {'text': 'các biện pháp điều trị bệnh thoát vị đùi để điều trị thoát vị đùi , bệnh nhân sẽ được chỉ định đeo băng hoặc phẫu thuật .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'đeo băng', 'start': 95, 'end': 103, 'type': 'TREATMENT'},
#   'obj': {'text': 'bệnh thoát vị đùi',
#    'start': 23,
#    'end': 40,
#    'type': 'DISEASE'}},
#  {'text': 'viêm thực quản do thuốc yếu tố có thể làm tăng nguy cơ viêm thực quản do thuốc thường liên quan đến vấn đề viên thuốc vào dạ dày bị chặn ở thực quản .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'do thuốc', 'start': 15, 'end': 23, 'type': 'CAUSE'},
#   'obj': {'text': 'viêm thực quản', 'start': 0, 'end': 14, 'type': 'DISEASE'}},
#  {'text': 'viêm thực quản do thuốc yếu tố có thể làm tăng nguy cơ viêm thực quản do thuốc thường liên quan đến vấn đề viên thuốc vào dạ dày bị chặn ở thực quản .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'do thuốc', 'start': 15, 'end': 23, 'type': 'CAUSE'},
#   'obj': {'text': 'viêm thực quản',
#    'start': 55,
#    'end': 69,
#    'type': 'DISEASE'}},
#  {'text': 'điều này có thể được thấy rõ hơn khi có một nhiễm trùng ( lạnh trên đường hô hấp ) hoặc dị ứng gây ra đoạn mũi bị sưng tấy và thu hẹp .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'nhiễm trùng', 'start': 44, 'end': 55, 'type': 'DISEASE'},
#   'obj': {'text': 'đoạn mũi bị sưng tấy',
#    'start': 102,
#    'end': 122,
#    'type': 'SYMPTOM'}},
#  {'text': 'điều này có thể được thấy rõ hơn khi có một nhiễm trùng ( lạnh trên đường hô hấp ) hoặc dị ứng gây ra đoạn mũi bị sưng tấy và thu hẹp .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'nhiễm trùng', 'start': 44, 'end': 55, 'type': 'DISEASE'},
#   'obj': {'text': 'thu hẹp', 'start': 126, 'end': 133, 'type': 'SYMPTOM'}},
#  {'text': 'điều này có thể được thấy rõ hơn khi có một nhiễm trùng ( lạnh trên đường hô hấp ) hoặc dị ứng gây ra đoạn mũi bị sưng tấy và thu hẹp .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'dị ứng', 'start': 88, 'end': 94, 'type': 'DISEASE'},
#   'obj': {'text': 'đoạn mũi bị sưng tấy',
#    'start': 102,
#    'end': 122,
#    'type': 'SYMPTOM'}},
#  {'text': 'điều này có thể được thấy rõ hơn khi có một nhiễm trùng ( lạnh trên đường hô hấp ) hoặc dị ứng gây ra đoạn mũi bị sưng tấy và thu hẹp .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'dị ứng', 'start': 88, 'end': 94, 'type': 'DISEASE'},
#   'obj': {'text': 'thu hẹp', 'start': 126, 'end': 133, 'type': 'SYMPTOM'}},
#  {'text': 'điều này có thể được thấy rõ hơn khi có một nhiễm trùng ( lạnh trên đường hô hấp ) hoặc dị ứng gây ra đoạn mũi bị sưng tấy và thu hẹp .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'đoạn mũi bị sưng tấy',
#    'start': 102,
#    'end': 122,
#    'type': 'SYMPTOM'},
#   'obj': {'text': 'dị ứng', 'start': 88, 'end': 94, 'type': 'DISEASE'}},
#  {'text': 'điều này có thể được thấy rõ hơn khi có một nhiễm trùng ( lạnh trên đường hô hấp ) hoặc dị ứng gây ra đoạn mũi bị sưng tấy và thu hẹp .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'đoạn mũi bị sưng tấy',
#    'start': 102,
#    'end': 122,
#    'type': 'SYMPTOM'},
#   'obj': {'text': 'thu hẹp', 'start': 126, 'end': 133, 'type': 'SYMPTOM'}},
#  {'text': 'điều này có thể được thấy rõ hơn khi có một nhiễm trùng ( lạnh trên đường hô hấp ) hoặc dị ứng gây ra đoạn mũi bị sưng tấy và thu hẹp .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'dị ứng', 'start': 88, 'end': 94, 'type': 'DISEASE'},
#   'obj': {'text': 'nhiễm trùng', 'start': 44, 'end': 55, 'type': 'DISEASE'}},
#  {'text': 'điều này có thể được thấy rõ hơn khi có một nhiễm trùng ( lạnh trên đường hô hấp ) hoặc dị ứng gây ra đoạn mũi bị sưng tấy và thu hẹp .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'thu hẹp', 'start': 126, 'end': 133, 'type': 'SYMPTOM'},
#   'obj': {'text': 'dị ứng', 'start': 88, 'end': 94, 'type': 'DISEASE'}},
#  {'text': 'sau khi cắt bỏ nút nhĩ thất , sẽ cần phải tiếp tục dùng thuốc làm loãng máu để giảm nguy cơ đột quỵ , bởi vì nhịp tim vẫn là rung nhĩ .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'đột quỵ', 'start': 92, 'end': 99, 'type': 'DISEASE'},
#   'obj': {'text': 'dùng thuốc làm loãng máu',
#    'start': 51,
#    'end': 75,
#    'type': 'TREATMENT'}},
#  {'text': 'sau khi cắt bỏ nút nhĩ thất , sẽ cần phải tiếp tục dùng thuốc làm loãng máu để giảm nguy cơ đột quỵ , bởi vì nhịp tim vẫn là rung nhĩ .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'rung nhĩ', 'start': 125, 'end': 133, 'type': 'DISEASE'},
#   'obj': {'text': 'dùng thuốc làm loãng máu',
#    'start': 51,
#    'end': 75,
#    'type': 'TREATMENT'}},
#  {'text': 'khi ăn quá nhiều hoặc khó chịu , chứng đầy hơi có thể là dấu hiệu của rối loạn sức khỏe , chẳng hạn như hội chứng ruột kích thích , bệnh celiac hoặc không dung nạp lactose .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'hội chứng ruột kích thích',
#    'start': 104,
#    'end': 129,
#    'type': 'DISEASE'},
#   'obj': {'text': 'chứng đầy hơi', 'start': 33, 'end': 46, 'type': 'SYMPTOM'}},
#  {'text': 'khi ăn quá nhiều hoặc khó chịu , chứng đầy hơi có thể là dấu hiệu của rối loạn sức khỏe , chẳng hạn như hội chứng ruột kích thích , bệnh celiac hoặc không dung nạp lactose .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'bệnh celiac', 'start': 132, 'end': 143, 'type': 'DISEASE'},
#   'obj': {'text': 'chứng đầy hơi', 'start': 33, 'end': 46, 'type': 'SYMPTOM'}},
#  {'text': 'khi ăn quá nhiều hoặc khó chịu , chứng đầy hơi có thể là dấu hiệu của rối loạn sức khỏe , chẳng hạn như hội chứng ruột kích thích , bệnh celiac hoặc không dung nạp lactose .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'khó chịu', 'start': 22, 'end': 30, 'type': 'SYMPTOM'},
#   'obj': {'text': 'hội chứng ruột kích thích',
#    'start': 104,
#    'end': 129,
#    'type': 'DISEASE'}},
#  {'text': 'khi ăn quá nhiều hoặc khó chịu , chứng đầy hơi có thể là dấu hiệu của rối loạn sức khỏe , chẳng hạn như hội chứng ruột kích thích , bệnh celiac hoặc không dung nạp lactose .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'hội chứng ruột kích thích',
#    'start': 104,
#    'end': 129,
#    'type': 'DISEASE'},
#   'obj': {'text': 'bệnh celiac', 'start': 132, 'end': 143, 'type': 'DISEASE'}},
#  {'text': 'biên tập viên : trần tiến phong đánh giá : trần trà my , trần phương phương định nghĩa chóng mặt lành tính chỉ những ngày bị chóng mặt bộc phát ( bppv ) , là một trong những nguyên nhân phổ biến nhất của chóng mặt , những cảm giác bất ngờ quay quay hay quay bên trong đầu .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'chóng mặt lành tính ',
#    'start': 87,
#    'end': 107,
#    'type': 'DISEASE'},
#   'obj': {'text': 'cảm giác bất ngờ quay quay hay quay bên trong đầu ',
#    'start': 223,
#    'end': 273,
#    'type': 'SYMPTOM'}},
#  {'text': 'biên tập viên : trần tiến phong đánh giá : trần trà my , trần phương phương định nghĩa chóng mặt lành tính chỉ những ngày bị chóng mặt bộc phát ( bppv ) , là một trong những nguyên nhân phổ biến nhất của chóng mặt , những cảm giác bất ngờ quay quay hay quay bên trong đầu .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'chóng mặt bộc phát ',
#    'start': 126,
#    'end': 145,
#    'type': 'DISEASE'},
#   'obj': {'text': 'chóng mặt lành tính ',
#    'start': 87,
#    'end': 107,
#    'type': 'DISEASE'}},
#  {'text': 'đôi khi , loại viêm mũi có thể trở thành mãn tính , chảy nước mũi gây đổi màu liên tục , đau mặt và áp suất ( viêm xoang ) .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'chảy nước mũi', 'start': 52, 'end': 65, 'type': 'CAUSE'},
#   'obj': {'text': 'đau mặt', 'start': 89, 'end': 96, 'type': 'DISEASE'}},
#  {'text': 'đôi khi , loại viêm mũi có thể trở thành mãn tính , chảy nước mũi gây đổi màu liên tục , đau mặt và áp suất ( viêm xoang ) .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'chảy nước mũi', 'start': 52, 'end': 65, 'type': 'CAUSE'},
#   'obj': {'text': 'viêm xoang ', 'start': 110, 'end': 121, 'type': 'DISEASE'}},
#  {'text': 'đôi khi , loại viêm mũi có thể trở thành mãn tính , chảy nước mũi gây đổi màu liên tục , đau mặt và áp suất ( viêm xoang ) .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'viêm mũi', 'start': 15, 'end': 23, 'type': 'DISEASE'},
#   'obj': {'text': 'viêm xoang ', 'start': 110, 'end': 121, 'type': 'DISEASE'}},
#  {'text': 'đôi khi , loại viêm mũi có thể trở thành mãn tính , chảy nước mũi gây đổi màu liên tục , đau mặt và áp suất ( viêm xoang ) .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'viêm mũi', 'start': 15, 'end': 23, 'type': 'DISEASE'},
#   'obj': {'text': 'chảy nước mũi', 'start': 52, 'end': 65, 'type': 'CAUSE'}},
#  {'text': '- nếu dị ứng đang đóng góp viêm xoang , các mũi chích ngừa dị ứng ( miễn dịch liệu pháp ) giúp giảm thiểu các phản ứng của cơ thể với dị nguyên cụ thể có thể giúp điều trị các nguyên nhân .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'dị ứng', 'start': 6, 'end': 12, 'type': 'DISEASE'},
#   'obj': {'text': 'mũi chích ngừa dị ứng',
#    'start': 44,
#    'end': 65,
#    'type': 'TREATMENT'}},
#  {'text': '- nếu dị ứng đang đóng góp viêm xoang , các mũi chích ngừa dị ứng ( miễn dịch liệu pháp ) giúp giảm thiểu các phản ứng của cơ thể với dị nguyên cụ thể có thể giúp điều trị các nguyên nhân .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'dị ứng', 'start': 6, 'end': 12, 'type': 'DISEASE'},
#   'obj': {'text': 'miễn dịch liệu pháp',
#    'start': 68,
#    'end': 87,
#    'type': 'TREATMENT'}},
#  {'text': '- nếu dị ứng đang đóng góp viêm xoang , các mũi chích ngừa dị ứng ( miễn dịch liệu pháp ) giúp giảm thiểu các phản ứng của cơ thể với dị nguyên cụ thể có thể giúp điều trị các nguyên nhân .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'viêm xoang', 'start': 27, 'end': 37, 'type': 'DISEASE'},
#   'obj': {'text': 'mũi chích ngừa dị ứng',
#    'start': 44,
#    'end': 65,
#    'type': 'TREATMENT'}},
#  {'text': '- nếu dị ứng đang đóng góp viêm xoang , các mũi chích ngừa dị ứng ( miễn dịch liệu pháp ) giúp giảm thiểu các phản ứng của cơ thể với dị nguyên cụ thể có thể giúp điều trị các nguyên nhân .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'viêm xoang', 'start': 27, 'end': 37, 'type': 'DISEASE'},
#   'obj': {'text': 'miễn dịch liệu pháp',
#    'start': 68,
#    'end': 87,
#    'type': 'TREATMENT'}},
#  {'text': '- nếu dị ứng đang đóng góp viêm xoang , các mũi chích ngừa dị ứng ( miễn dịch liệu pháp ) giúp giảm thiểu các phản ứng của cơ thể với dị nguyên cụ thể có thể giúp điều trị các nguyên nhân .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'dị ứng', 'start': 6, 'end': 12, 'type': 'DISEASE'},
#   'obj': {'text': 'viêm xoang', 'start': 27, 'end': 37, 'type': 'DISEASE'}},
#  {'text': '- nếu dị ứng đang đóng góp viêm xoang , các mũi chích ngừa dị ứng ( miễn dịch liệu pháp ) giúp giảm thiểu các phản ứng của cơ thể với dị nguyên cụ thể có thể giúp điều trị các nguyên nhân .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'mũi chích ngừa dị ứng',
#    'start': 44,
#    'end': 65,
#    'type': 'TREATMENT'},
#   'obj': {'text': 'dị ứng', 'start': 6, 'end': 12, 'type': 'DISEASE'}},
#  {'text': '- nếu dị ứng đang đóng góp viêm xoang , các mũi chích ngừa dị ứng ( miễn dịch liệu pháp ) giúp giảm thiểu các phản ứng của cơ thể với dị nguyên cụ thể có thể giúp điều trị các nguyên nhân .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'mũi chích ngừa dị ứng',
#    'start': 44,
#    'end': 65,
#    'type': 'TREATMENT'},
#   'obj': {'text': 'viêm xoang', 'start': 27, 'end': 37, 'type': 'DISEASE'}},
#  {'text': '- nếu dị ứng đang đóng góp viêm xoang , các mũi chích ngừa dị ứng ( miễn dịch liệu pháp ) giúp giảm thiểu các phản ứng của cơ thể với dị nguyên cụ thể có thể giúp điều trị các nguyên nhân .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'mũi chích ngừa dị ứng',
#    'start': 44,
#    'end': 65,
#    'type': 'TREATMENT'},
#   'obj': {'text': 'miễn dịch liệu pháp',
#    'start': 68,
#    'end': 87,
#    'type': 'TREATMENT'}},
#  {'text': 'ung thư thận giai đoạn 3 : ung thư đã xâm lấn các vùng lân cận như mô quanh thận , tuyến thượng thận , các tĩnh mạch lớn ung thư thận giai đoạn cuối : ung thư di căn tới các bộ phận khác của cơ thể , bệnh nhân mệt mỏi , suy kiệt dần dần .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'ung thư thận', 'start': 0, 'end': 12, 'type': 'DISEASE'},
#   'obj': {'text': 'mệt mỏ', 'start': 210, 'end': 216, 'type': 'SYMPTOM'}},
#  {'text': 'ung thư thận giai đoạn 3 : ung thư đã xâm lấn các vùng lân cận như mô quanh thận , tuyến thượng thận , các tĩnh mạch lớn ung thư thận giai đoạn cuối : ung thư di căn tới các bộ phận khác của cơ thể , bệnh nhân mệt mỏi , suy kiệt dần dần .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'ung thư thận', 'start': 0, 'end': 12, 'type': 'DISEASE'},
#   'obj': {'text': 'suy kiệt', 'start': 220, 'end': 228, 'type': 'SYMPTOM'}},
#  {'text': 'ung thư thận giai đoạn 3 : ung thư đã xâm lấn các vùng lân cận như mô quanh thận , tuyến thượng thận , các tĩnh mạch lớn ung thư thận giai đoạn cuối : ung thư di căn tới các bộ phận khác của cơ thể , bệnh nhân mệt mỏi , suy kiệt dần dần .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'ung thư thận',
#    'start': 121,
#    'end': 133,
#    'type': 'DISEASE'},
#   'obj': {'text': 'suy kiệt', 'start': 220, 'end': 228, 'type': 'SYMPTOM'}},
#  {'text': 'ung thư thận giai đoạn 3 : ung thư đã xâm lấn các vùng lân cận như mô quanh thận , tuyến thượng thận , các tĩnh mạch lớn ung thư thận giai đoạn cuối : ung thư di căn tới các bộ phận khác của cơ thể , bệnh nhân mệt mỏi , suy kiệt dần dần .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'suy kiệt', 'start': 220, 'end': 228, 'type': 'SYMPTOM'},
#   'obj': {'text': 'ung thư thận', 'start': 0, 'end': 12, 'type': 'DISEASE'}},
#  {'text': 'tác động của xơ vữa động mạch đối với sức khỏe xơ vữa động mạch gây tắc nghẽn mạch máu , cản trở sự lưu thông máu dẫn đến tê , đau ở bất cứ nơi nào bị tắc nghẽn .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'xơ vữa động mạch',
#    'start': 47,
#    'end': 63,
#    'type': 'DISEASE'},
#   'obj': {'text': 'tê', 'start': 122, 'end': 124, 'type': 'SYMPTOM'}},
#  {'text': 'tác động của xơ vữa động mạch đối với sức khỏe xơ vữa động mạch gây tắc nghẽn mạch máu , cản trở sự lưu thông máu dẫn đến tê , đau ở bất cứ nơi nào bị tắc nghẽn .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'xơ vữa động mạch',
#    'start': 47,
#    'end': 63,
#    'type': 'DISEASE'},
#   'obj': {'text': 'đau', 'start': 127, 'end': 130, 'type': 'SYMPTOM'}},
#  {'text': 'tác động của xơ vữa động mạch đối với sức khỏe xơ vữa động mạch gây tắc nghẽn mạch máu , cản trở sự lưu thông máu dẫn đến tê , đau ở bất cứ nơi nào bị tắc nghẽn .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'xơ vữa động mạch',
#    'start': 13,
#    'end': 29,
#    'type': 'DISEASE'},
#   'obj': {'text': 'đau', 'start': 127, 'end': 130, 'type': 'SYMPTOM'}},
#  {'text': 'tác động của xơ vữa động mạch đối với sức khỏe xơ vữa động mạch gây tắc nghẽn mạch máu , cản trở sự lưu thông máu dẫn đến tê , đau ở bất cứ nơi nào bị tắc nghẽn .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'đau', 'start': 127, 'end': 130, 'type': 'SYMPTOM'},
#   'obj': {'text': 'xơ vữa động mạch',
#    'start': 13,
#    'end': 29,
# ...
#   'obj': {'text': 'bệnh ung thư thận',
#    'start': 12,
#    'end': 29,
#    'type': 'DISEASE'}},
#  {'text': 'triệu chứng bệnh ung thư thận triệu chứng của ung thư thận được biểu hiện bởi tam chứng cổ điển : tiểu máu , khối u vùng thắt lưng và đau .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'ung thư thận', 'start': 46, 'end': 58, 'type': 'DISEASE'},
#   'obj': {'text': 'bệnh ung thư thận',
#    'start': 12,
#    'end': 29,
#    'type': 'DISEASE'}},
#  {'text': 'triệu chứng bệnh ung thư thận triệu chứng của ung thư thận được biểu hiện bởi tam chứng cổ điển : tiểu máu , khối u vùng thắt lưng và đau .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'khối u vùng thắt lưng',
#    'start': 109,
#    'end': 130,
#    'type': 'SYMPTOM'},
#   'obj': {'text': 'đau', 'start': 134, 'end': 137, 'type': 'SYMPTOM'}},
#  {'text': 'biến chứng có thể gặp khi mắc hở van động mạch chủ hở van động mạch chủ nếu không được phát hiện và can thiệp kịp thời , có thể gây ra các biến chứng nguy hiểm : suy tim : lượng máu từ động mạch chủ dội ngược về thất trái làm cho thất trái giãn dần ra ( quá tải thể tích thất trái ) , đến khi cơ tim không còn bù trừ được dẫn đến suy giảm co bóp và suy tim; viêm nội tâm mạc nhiễm khuẩn : dòng máu dội ngược từ động mạch chủ về thất trái gây tổn thương lớp nội mạc tim , tạo điều kiện cho vi khuẩn gây nhiễm trùng hay áp - xe; loạn nhịp tim; tử vong : nếu không được điều trị hoặc phẫu thuật kịp thời , dẫn đến suy tim không hồi phục .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'hở van động mạch chủ',
#    'start': 30,
#    'end': 50,
#    'type': 'CAUSE'},
#   'obj': {'text': 'suy tim', 'start': 162, 'end': 169, 'type': 'DISEASE'}},
#  {'text': 'biến chứng có thể gặp khi mắc hở van động mạch chủ hở van động mạch chủ nếu không được phát hiện và can thiệp kịp thời , có thể gây ra các biến chứng nguy hiểm : suy tim : lượng máu từ động mạch chủ dội ngược về thất trái làm cho thất trái giãn dần ra ( quá tải thể tích thất trái ) , đến khi cơ tim không còn bù trừ được dẫn đến suy giảm co bóp và suy tim; viêm nội tâm mạc nhiễm khuẩn : dòng máu dội ngược từ động mạch chủ về thất trái gây tổn thương lớp nội mạc tim , tạo điều kiện cho vi khuẩn gây nhiễm trùng hay áp - xe; loạn nhịp tim; tử vong : nếu không được điều trị hoặc phẫu thuật kịp thời , dẫn đến suy tim không hồi phục .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'suy tim', 'start': 162, 'end': 169, 'type': 'DISEASE'},
#   'obj': {'text': 'lượng máu từ động mạch chủ dội ngược về thất trái làm cho thất trái giãn dần ra',
#    'start': 172,
#    'end': 251,
#    'type': 'SYMPTOM'}},
#  {'text': 'biến chứng có thể gặp khi mắc hở van động mạch chủ hở van động mạch chủ nếu không được phát hiện và can thiệp kịp thời , có thể gây ra các biến chứng nguy hiểm : suy tim : lượng máu từ động mạch chủ dội ngược về thất trái làm cho thất trái giãn dần ra ( quá tải thể tích thất trái ) , đến khi cơ tim không còn bù trừ được dẫn đến suy giảm co bóp và suy tim; viêm nội tâm mạc nhiễm khuẩn : dòng máu dội ngược từ động mạch chủ về thất trái gây tổn thương lớp nội mạc tim , tạo điều kiện cho vi khuẩn gây nhiễm trùng hay áp - xe; loạn nhịp tim; tử vong : nếu không được điều trị hoặc phẫu thuật kịp thời , dẫn đến suy tim không hồi phục .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'suy tim', 'start': 349, 'end': 356, 'type': 'DISEASE'},
#   'obj': {'text': 'dòng máu dội ngược từ động mạch chủ về thất trái gây tổn thương lớp nội mạc tim',
#    'start': 389,
#    'end': 468,
#    'type': 'SYMPTOM'}},
#  {'text': 'biến chứng có thể gặp khi mắc hở van động mạch chủ hở van động mạch chủ nếu không được phát hiện và can thiệp kịp thời , có thể gây ra các biến chứng nguy hiểm : suy tim : lượng máu từ động mạch chủ dội ngược về thất trái làm cho thất trái giãn dần ra ( quá tải thể tích thất trái ) , đến khi cơ tim không còn bù trừ được dẫn đến suy giảm co bóp và suy tim; viêm nội tâm mạc nhiễm khuẩn : dòng máu dội ngược từ động mạch chủ về thất trái gây tổn thương lớp nội mạc tim , tạo điều kiện cho vi khuẩn gây nhiễm trùng hay áp - xe; loạn nhịp tim; tử vong : nếu không được điều trị hoặc phẫu thuật kịp thời , dẫn đến suy tim không hồi phục .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'viêm nội tâm mạc nhiễm khuẩn',
#    'start': 358,
#    'end': 386,
#    'type': 'DISEASE'},
#   'obj': {'text': 'dòng máu dội ngược từ động mạch chủ về thất trái gây tổn thương lớp nội mạc tim',
#    'start': 389,
#    'end': 468,
#    'type': 'SYMPTOM'}},
#  {'text': 'biến chứng có thể gặp khi mắc hở van động mạch chủ hở van động mạch chủ nếu không được phát hiện và can thiệp kịp thời , có thể gây ra các biến chứng nguy hiểm : suy tim : lượng máu từ động mạch chủ dội ngược về thất trái làm cho thất trái giãn dần ra ( quá tải thể tích thất trái ) , đến khi cơ tim không còn bù trừ được dẫn đến suy giảm co bóp và suy tim; viêm nội tâm mạc nhiễm khuẩn : dòng máu dội ngược từ động mạch chủ về thất trái gây tổn thương lớp nội mạc tim , tạo điều kiện cho vi khuẩn gây nhiễm trùng hay áp - xe; loạn nhịp tim; tử vong : nếu không được điều trị hoặc phẫu thuật kịp thời , dẫn đến suy tim không hồi phục .',
#   'relation': 'CAUSES',
#   'subj': {'text': 'vi khuẩn gây nhiễm trùng hay áp - xe',
#    'start': 489,
#    'end': 525,
#    'type': 'CAUSE'},
#   'obj': {'text': 'viêm nội tâm mạc nhiễm khuẩn',
#    'start': 358,
#    'end': 386,
#    'type': 'DISEASE'}},
#  {'text': 'biến chứng có thể gặp khi mắc hở van động mạch chủ hở van động mạch chủ nếu không được phát hiện và can thiệp kịp thời , có thể gây ra các biến chứng nguy hiểm : suy tim : lượng máu từ động mạch chủ dội ngược về thất trái làm cho thất trái giãn dần ra ( quá tải thể tích thất trái ) , đến khi cơ tim không còn bù trừ được dẫn đến suy giảm co bóp và suy tim; viêm nội tâm mạc nhiễm khuẩn : dòng máu dội ngược từ động mạch chủ về thất trái gây tổn thương lớp nội mạc tim , tạo điều kiện cho vi khuẩn gây nhiễm trùng hay áp - xe; loạn nhịp tim; tử vong : nếu không được điều trị hoặc phẫu thuật kịp thời , dẫn đến suy tim không hồi phục .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'lượng máu từ động mạch chủ dội ngược về thất trái làm cho thất trái giãn dần ra',
#    'start': 172,
#    'end': 251,
#    'type': 'SYMPTOM'},
#   'obj': {'text': 'vi khuẩn gây nhiễm trùng hay áp - xe',
#    'start': 489,
#    'end': 525,
#    'type': 'CAUSE'}},
#  {'text': 'biến chứng có thể gặp khi mắc hở van động mạch chủ hở van động mạch chủ nếu không được phát hiện và can thiệp kịp thời , có thể gây ra các biến chứng nguy hiểm : suy tim : lượng máu từ động mạch chủ dội ngược về thất trái làm cho thất trái giãn dần ra ( quá tải thể tích thất trái ) , đến khi cơ tim không còn bù trừ được dẫn đến suy giảm co bóp và suy tim; viêm nội tâm mạc nhiễm khuẩn : dòng máu dội ngược từ động mạch chủ về thất trái gây tổn thương lớp nội mạc tim , tạo điều kiện cho vi khuẩn gây nhiễm trùng hay áp - xe; loạn nhịp tim; tử vong : nếu không được điều trị hoặc phẫu thuật kịp thời , dẫn đến suy tim không hồi phục .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'suy tim', 'start': 349, 'end': 356, 'type': 'DISEASE'},
#   'obj': {'text': 'lượng máu từ động mạch chủ dội ngược về thất trái làm cho thất trái giãn dần ra',
#    'start': 172,
#    'end': 251,
#    'type': 'SYMPTOM'}},
#  {'text': 'biến chứng có thể gặp khi mắc hở van động mạch chủ hở van động mạch chủ nếu không được phát hiện và can thiệp kịp thời , có thể gây ra các biến chứng nguy hiểm : suy tim : lượng máu từ động mạch chủ dội ngược về thất trái làm cho thất trái giãn dần ra ( quá tải thể tích thất trái ) , đến khi cơ tim không còn bù trừ được dẫn đến suy giảm co bóp và suy tim; viêm nội tâm mạc nhiễm khuẩn : dòng máu dội ngược từ động mạch chủ về thất trái gây tổn thương lớp nội mạc tim , tạo điều kiện cho vi khuẩn gây nhiễm trùng hay áp - xe; loạn nhịp tim; tử vong : nếu không được điều trị hoặc phẫu thuật kịp thời , dẫn đến suy tim không hồi phục .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'lượng máu từ động mạch chủ dội ngược về thất trái làm cho thất trái giãn dần ra',
#    'start': 172,
#    'end': 251,
#    'type': 'SYMPTOM'},
#   'obj': {'text': 'suy tim', 'start': 162, 'end': 169, 'type': 'DISEASE'}},
#  {'text': 'biến chứng có thể gặp khi mắc hở van động mạch chủ hở van động mạch chủ nếu không được phát hiện và can thiệp kịp thời , có thể gây ra các biến chứng nguy hiểm : suy tim : lượng máu từ động mạch chủ dội ngược về thất trái làm cho thất trái giãn dần ra ( quá tải thể tích thất trái ) , đến khi cơ tim không còn bù trừ được dẫn đến suy giảm co bóp và suy tim; viêm nội tâm mạc nhiễm khuẩn : dòng máu dội ngược từ động mạch chủ về thất trái gây tổn thương lớp nội mạc tim , tạo điều kiện cho vi khuẩn gây nhiễm trùng hay áp - xe; loạn nhịp tim; tử vong : nếu không được điều trị hoặc phẫu thuật kịp thời , dẫn đến suy tim không hồi phục .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'hở van động mạch chủ',
#    'start': 30,
#    'end': 50,
#    'type': 'CAUSE'},
#   'obj': {'text': 'viêm nội tâm mạc nhiễm khuẩn',
#    'start': 358,
#    'end': 386,
#    'type': 'DISEASE'}},
#  {'text': 'biến chứng có thể gặp khi mắc hở van động mạch chủ hở van động mạch chủ nếu không được phát hiện và can thiệp kịp thời , có thể gây ra các biến chứng nguy hiểm : suy tim : lượng máu từ động mạch chủ dội ngược về thất trái làm cho thất trái giãn dần ra ( quá tải thể tích thất trái ) , đến khi cơ tim không còn bù trừ được dẫn đến suy giảm co bóp và suy tim; viêm nội tâm mạc nhiễm khuẩn : dòng máu dội ngược từ động mạch chủ về thất trái gây tổn thương lớp nội mạc tim , tạo điều kiện cho vi khuẩn gây nhiễm trùng hay áp - xe; loạn nhịp tim; tử vong : nếu không được điều trị hoặc phẫu thuật kịp thời , dẫn đến suy tim không hồi phục .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'suy tim', 'start': 349, 'end': 356, 'type': 'DISEASE'},
#   'obj': {'text': 'suy tim', 'start': 611, 'end': 618, 'type': 'DISEASE'}},
#  {'text': 'các biện pháp điều trị bệnh thiếu máu cơ tim điều trị thiếu máu cơ tim gồm có điều trị nội khoa và tái thông mạch vành bằng can thiệp , phẫu thuật .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'bệnh thiếu máu cơ tim',
#    'start': 23,
#    'end': 44,
#    'type': 'DISEASE'},
#   'obj': {'text': 'nội khoa', 'start': 87, 'end': 95, 'type': 'TREATMENT'}},
#  {'text': 'các biện pháp điều trị bệnh thiếu máu cơ tim điều trị thiếu máu cơ tim gồm có điều trị nội khoa và tái thông mạch vành bằng can thiệp , phẫu thuật .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'bệnh thiếu máu cơ tim',
#    'start': 23,
#    'end': 44,
#    'type': 'DISEASE'},
#   'obj': {'text': 'tái thông mạch vành bằng can thiệp',
#    'start': 99,
#    'end': 133,
#    'type': 'TREATMENT'}},
#  {'text': 'các biện pháp điều trị bệnh thiếu máu cơ tim điều trị thiếu máu cơ tim gồm có điều trị nội khoa và tái thông mạch vành bằng can thiệp , phẫu thuật .',
#   'relation': 'TREATED_WITH',
#   'subj': {'text': 'bệnh thiếu máu cơ tim',
#    'start': 23,
#    'end': 44,
#    'type': 'DISEASE'},
#   'obj': {'text': 'phẫu thuật',
#    'start': 136,
#    'end': 146,
#    'type': 'TREATMENT'}},
#  {'text': 'các biện pháp điều trị bệnh thiếu máu cơ tim điều trị thiếu máu cơ tim gồm có điều trị nội khoa và tái thông mạch vành bằng can thiệp , phẫu thuật .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'phẫu thuật',
#    'start': 136,
#    'end': 146,
#    'type': 'TREATMENT'},
#   'obj': {'text': 'thiếu máu cơ tim',
#    'start': 54,
#    'end': 70,
#    'type': 'DISEASE'}},
#  {'text': 'các biện pháp điều trị bệnh thiếu máu cơ tim điều trị thiếu máu cơ tim gồm có điều trị nội khoa và tái thông mạch vành bằng can thiệp , phẫu thuật .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'nội khoa', 'start': 87, 'end': 95, 'type': 'TREATMENT'},
#   'obj': {'text': 'phẫu thuật',
#    'start': 136,
#    'end': 146,
#    'type': 'TREATMENT'}},
#  {'text': 'các biện pháp điều trị bệnh thiếu máu cơ tim điều trị thiếu máu cơ tim gồm có điều trị nội khoa và tái thông mạch vành bằng can thiệp , phẫu thuật .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'nội khoa', 'start': 87, 'end': 95, 'type': 'TREATMENT'},
#   'obj': {'text': 'bệnh thiếu máu cơ tim',
#    'start': 23,
#    'end': 44,
#    'type': 'DISEASE'}},
#  {'text': 'trong liệt hành tủy tiến triển : lưỡi gà sa xuống , giảm phản xạ nôn , ứ đọng nước bọt ở họng , ho , lưỡi yếu có nhiều nếp nhăn .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'liệt hành tủy', 'start': 6, 'end': 19, 'type': 'DISEASE'},
#   'obj': {'text': 'lưỡi gà sa xuống',
#    'start': 33,
#    'end': 49,
#    'type': 'SYMPTOM'}},
#  {'text': 'trong liệt hành tủy tiến triển : lưỡi gà sa xuống , giảm phản xạ nôn , ứ đọng nước bọt ở họng , ho , lưỡi yếu có nhiều nếp nhăn .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'liệt hành tủy', 'start': 6, 'end': 19, 'type': 'DISEASE'},
#   'obj': {'text': 'giảm phản xạ nôn',
#    'start': 52,
#    'end': 68,
#    'type': 'SYMPTOM'}},
#  {'text': 'trong liệt hành tủy tiến triển : lưỡi gà sa xuống , giảm phản xạ nôn , ứ đọng nước bọt ở họng , ho , lưỡi yếu có nhiều nếp nhăn .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'liệt hành tủy', 'start': 6, 'end': 19, 'type': 'DISEASE'},
#   'obj': {'text': 'ứ đọng nước bọt ở họng',
#    'start': 71,
#    'end': 93,
#    'type': 'SYMPTOM'}},
#  {'text': 'trong liệt hành tủy tiến triển : lưỡi gà sa xuống , giảm phản xạ nôn , ứ đọng nước bọt ở họng , ho , lưỡi yếu có nhiều nếp nhăn .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'liệt hành tủy', 'start': 6, 'end': 19, 'type': 'DISEASE'},
#   'obj': {'text': 'ho', 'start': 96, 'end': 98, 'type': 'SYMPTOM'}},
#  {'text': 'trong liệt hành tủy tiến triển : lưỡi gà sa xuống , giảm phản xạ nôn , ứ đọng nước bọt ở họng , ho , lưỡi yếu có nhiều nếp nhăn .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'liệt hành tủy', 'start': 6, 'end': 19, 'type': 'DISEASE'},
#   'obj': {'text': 'lưỡi yếu có nhiều nếp nhăn',
#    'start': 101,
#    'end': 127,
#    'type': 'SYMPTOM'}},
#  {'text': 'trong liệt hành tủy tiến triển : lưỡi gà sa xuống , giảm phản xạ nôn , ứ đọng nước bọt ở họng , ho , lưỡi yếu có nhiều nếp nhăn .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'ứ đọng nước bọt ở họng',
#    'start': 71,
#    'end': 93,
#    'type': 'SYMPTOM'},
#   'obj': {'text': 'lưỡi yếu có nhiều nếp nhăn',
#    'start': 101,
#    'end': 127,
#    'type': 'SYMPTOM'}},
#  {'text': 'trong liệt hành tủy tiến triển : lưỡi gà sa xuống , giảm phản xạ nôn , ứ đọng nước bọt ở họng , ho , lưỡi yếu có nhiều nếp nhăn .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'giảm phản xạ nôn',
#    'start': 52,
#    'end': 68,
#    'type': 'SYMPTOM'},
#   'obj': {'text': 'lưỡi yếu có nhiều nếp nhăn',
#    'start': 101,
#    'end': 127,
#    'type': 'SYMPTOM'}},
#  {'text': 'trong liệt hành tủy tiến triển : lưỡi gà sa xuống , giảm phản xạ nôn , ứ đọng nước bọt ở họng , ho , lưỡi yếu có nhiều nếp nhăn .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'ho', 'start': 96, 'end': 98, 'type': 'SYMPTOM'},
#   'obj': {'text': 'giảm phản xạ nôn',
#    'start': 52,
#    'end': 68,
#    'type': 'SYMPTOM'}},
#  {'text': 'trong liệt hành tủy tiến triển : lưỡi gà sa xuống , giảm phản xạ nôn , ứ đọng nước bọt ở họng , ho , lưỡi yếu có nhiều nếp nhăn .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'ho', 'start': 96, 'end': 98, 'type': 'SYMPTOM'},
#   'obj': {'text': 'ứ đọng nước bọt ở họng',
#    'start': 71,
#    'end': 93,
#    'type': 'SYMPTOM'}},
#  {'text': 'trong liệt hành tủy tiến triển : lưỡi gà sa xuống , giảm phản xạ nôn , ứ đọng nước bọt ở họng , ho , lưỡi yếu có nhiều nếp nhăn .',
#   'relation': 'NO_RELATION',
#   'subj': {'text': 'lưỡi yếu có nhiều nếp nhăn',
#    'start': 101,
#    'end': 127,
#    'type': 'SYMPTOM'},
#   'obj': {'text': 'giảm phản xạ nôn',
#    'start': 52,
#    'end': 68,
#    'type': 'SYMPTOM'}},
#  {'text': 'nguyên nhân bệnh tăng thông khí có nhiều nguyên nhân có thể dẫn đến hội chứng tăng thông khí phổi nhưng lo âu và hoảng sợ ( rối loạn lo lắng ) là nguyên nhân chính dẫn đến tình trạng tăng nhanh nhịp thở .',
#   'relation': 'HAS_MANIFESTATION',
#   'subj': {'text': 'hội chứng tăng thông khí phổi',
#    'start': 68,
#    'end': 97,
#    'type': 'DISEASE'},
#   'obj': {'text': 'lo âu', 'start': 104, 'end': 109, 'type': 'SYMPTOM'}},
#  ...]

# %%
with open('train_data_fixed.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

labels = [item['relation'] for item in data]

# 2. Split train/temp (80/20)
train_data, temp_data = train_test_split(
    data, 
    test_size=0.2, 
    random_state=42, 
    stratify=labels
)

# 3. Split dev/test (50/50)
temp_labels = [item['relation'] for item in temp_data]
dev_data, test_data = train_test_split(
    temp_data, 
    test_size=0.5, 
    random_state=42, 
    stratify=temp_labels
)

# 4. Save
def save_json(data, filename):
    with open(filename, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=4)

save_json(train_data, 'train.json')
save_json(dev_data, 'dev.json')
save_json(test_data, 'test.json')

print(f"Train: {len(train_data)}, Dev: {len(dev_data)}, Test: {len(test_data)}")
# Out:
# Train: 948, Dev: 118, Test: 119

# %%
import json
from pathlib import Path
from itertools import permutations
from collections import Counter, defaultdict

# ====== 4 RELATION SCHEMA DUY NHẤT ======
# (subj_type, obj_type) -> relation_name
REL_SCHEMA = {
    ("DISEASE", "SYMPTOM"): "HAS_MANIFESTATION",
    ("CAUSE", "DISEASE"): "CAUSES",
    ("DISEASE", "TREATMENT"): "TREATED_WITH",
    ("DIAGNOSTIC", "DISEASE"): "REVEALS",
}

POS_REL_SET = set(REL_SCHEMA.values())
NO_REL = "No_Relation"


def load_ls(path: str):
    data = json.loads(Path(path).read_text(encoding="utf-8"))
    if isinstance(data, dict):
        data = [data]
    if not isinstance(data, list):
        raise ValueError("Top-level JSON phải là list tasks hoặc 1 task dict.")
    return data


def parse_task(task: dict):
    """Trả về text, entities_map, positive_pairs_set"""
    data_block = task.get("data", {}) or {}
    text = data_block.get("text") or data_block.get("sentence")
    if not text:
        return None, {}, set(), []

    anns = task.get("annotations") or []
    if not anns:
        return text, {}, set(), []

    result = (anns[0] or {}).get("result") or []

    # entity_id -> {text,start,end,type}
    entities = {}
    for item in result:
        if item.get("type") == "labels":
            eid = item.get("id")
            val = item.get("value") or {}
            labels = val.get("labels") or []
            if not eid or not labels:
                continue
            entities[eid] = {
                "text": val.get("text"),
                "start": val.get("start"),
                "end": val.get("end"),
                "type": labels[0],
            }

    # Positive relation pairs (from_id,to_id) chỉ tính khi label thuộc 4 relation schema
    positive_pairs = set()
    positive_items = []  # để xuất positive sample đúng label gốc nếu muốn

    for item in result:
        if item.get("type") != "relation":
            continue
        from_id = item.get("from_id")
        to_id = item.get("to_id")
        labels = item.get("labels") or []
        rel = labels[0] if labels else None

        if from_id in entities and to_id in entities and rel in POS_REL_SET:
            positive_pairs.add((from_id, to_id))
            positive_items.append((from_id, to_id, rel))

    return text, entities, positive_pairs, positive_items


def generate_dataset_full_no_relation(
    input_full="full.json",
    output_dataset="full_data.json",
    include_positive=True,
    include_valid_but_unlabeled_as_no_relation=False,
):
    """
    - No_Relation được generate cho mọi pair:
        + type1 == type2 OR (type1,type2) không nằm trong REL_SCHEMA
      và pair đó không nằm trong positive_pairs (đã gán relation thật).
    - Nếu include_valid_but_unlabeled_as_no_relation=True:
        + thêm cả những pair-type HỢP LỆ (nằm trong schema) nhưng KHÔNG được annotate
          -> cũng gán No_Relation (dùng khi bạn muốn model học "không phải lúc nào cặp hợp lệ cũng có quan hệ").
    """
    tasks = load_ls(input_full)
    final_data = []

    stats = {
        "positive": 0,
        "no_relation": 0,
        "no_relation_by_type_pair": Counter(),
        "positive_by_rel": Counter(),
        "skipped_tasks_no_text": 0,
        "skipped_tasks_no_entities": 0,
    }

    for task in tasks:
        text, entities, positive_pairs, positive_items = parse_task(task)

        if text is None:
            stats["skipped_tasks_no_text"] += 1
            continue
        if not entities:
            stats["skipped_tasks_no_entities"] += 1
            continue

        # 1) (Tuỳ chọn) add positive samples (giữ nguyên như LS đã gán)
        if include_positive:
            for from_id, to_id, rel in positive_items:
                final_data.append({
                    "text": text,
                    "relation": rel,
                    "subj": entities[from_id],
                    "obj": entities[to_id],
                })
                stats["positive"] += 1
                stats["positive_by_rel"][rel] += 1

        # 2) Generate No_Relation theo rule schema + same-type
        entity_ids = list(entities.keys())
        for e1_id, e2_id in permutations(entity_ids, 2):
            if (e1_id, e2_id) in positive_pairs:
                continue  # đã là positive thì không generate No_Relation

            t1 = entities[e1_id]["type"]
            t2 = entities[e2_id]["type"]

            same_type = (t1 == t2)
            in_schema = ((t1, t2) in REL_SCHEMA)

            # Rule bạn yêu cầu:
            # - nếu same-type OR NOT in_schema => No_Relation
            # - nếu in_schema nhưng chưa annotate:
            #     + mặc định: KHÔNG gán (để dataset không phình vì cặp hợp lệ chưa chắc là No_Relation)
            #     + nếu flag True: gán No_Relation luôn
            make_no_rel = same_type or (not in_schema) or (include_valid_but_unlabeled_as_no_relation and in_schema)

            if not make_no_rel:
                continue

            final_data.append({
                "text": text,
                "relation": NO_REL,
                "subj": entities[e1_id],
                "obj": entities[e2_id],
            })
            stats["no_relation"] += 1
            stats["no_relation_by_type_pair"][f"{t1}-{t2}"] += 1

    Path(output_dataset).write_text(json.dumps(final_data, ensure_ascii=False, indent=2), encoding="utf-8")

    print("=== DONE ===")
    print(f"Output: {output_dataset}")
    print(f"Total samples: {len(final_data)}")
    print(f"Positive: {stats['positive']}")
    print(f"No_Relation: {stats['no_relation']}")
    print("Positive breakdown:", dict(stats["positive_by_rel"]))
    print("Top No_Relation type-pairs:", stats["no_relation_by_type_pair"].most_common(15))
    print("Skipped (no text):", stats["skipped_tasks_no_text"])
    print("Skipped (no entities):", stats["skipped_tasks_no_entities"])

    return final_data, stats


if __name__ == "__main__":
    generate_dataset_full_no_relation(
        input_full="full.json",
        output_dataset="full_data.json",
        include_positive=True,
        include_valid_but_unlabeled_as_no_relation=False,  # đổi True nếu bạn muốn cả cặp hợp lệ nhưng không gán cũng là No_Relation
    )
# Out:
# === DONE ===
# Output: full_data.json
# Total samples: 27777
# Positive: 2316
# No_Relation: 25461
# Positive breakdown: {'CAUSES': 537, 'TREATED_WITH': 459, 'HAS_MANIFESTATION': 1120, 'REVEALS': 200}
# Top No_Relation type-pairs: [('SYMPTOM-SYMPTOM', 7082), ('DISEASE-DISEASE', 4838), ('SYMPTOM-DISEASE', 2908), ('TREATMENT-TREATMENT', 2602), ('CAUSE-CAUSE', 1736), ('TREATMENT-DISEASE', 1286), ('DISEASE-CAUSE', 1260), ('DIAGNOSTIC-DIAGNOSTIC', 934), ('DISEASE-DIAGNOSTIC', 697), ('SYMPTOM-TREATMENT', 386), ('TREATMENT-SYMPTOM', 386), ('SYMPTOM-CAUSE', 308), ('CAUSE-SYMPTOM', 307), ('SYMPTOM-DIAGNOSTIC', 139), ('DIAGNOSTIC-SYMPTOM', 136)]
# Skipped (no text): 0
# Skipped (no entities): 0

# %%
import json
import random
from collections import defaultdict, Counter
from pathlib import Path

NO_REL = "No_Relation"

def is_same_type(sample):
    return sample["subj"]["type"] == sample["obj"]["type"]

def type_pair(sample):
    return f'{sample["subj"]["type"]}-{sample["obj"]["type"]}'

def stratified_sample(groups, total_needed, seed=42):
    """
    groups: dict[key] -> list[samples]
    Lấy gần đều theo group key.
    """
    rng = random.Random(seed)
    keys = list(groups.keys())
    for k in keys:
        rng.shuffle(groups[k])

    # Nếu total_needed <= 0
    if total_needed <= 0:
        return []

    # Round-robin lấy đều
    picked = []
    idx = 0
    while len(picked) < total_needed and keys:
        k = keys[idx % len(keys)]
        if groups[k]:
            picked.append(groups[k].pop())
        else:
            keys.remove(k)
            # không tăng idx để tránh skip
            continue
        idx += 1

    return picked

def balance_dataset(
    input_file="full_data.json",
    output_file="full_data_balanced.json",
    neg_pos_ratio=2.0,          # NoRel = 2 * Pos
    same_type_fraction=0.3,     # 30% NoRel từ same-type bucket
    seed=42
):
    data = json.loads(Path(input_file).read_text(encoding="utf-8"))

    pos = [s for s in data if s.get("relation") != NO_REL]
    neg = [s for s in data if s.get("relation") == NO_REL]

    pos_n = len(pos)
    target_neg = int(pos_n * neg_pos_ratio)

    # Chia neg thành 2 bucket
    neg_same = [s for s in neg if is_same_type(s)]
    neg_cross = [s for s in neg if not is_same_type(s)]

    target_same = int(target_neg * same_type_fraction)
    target_cross = target_neg - target_same

    # group theo type-pair để stratified
    g_same = defaultdict(list)
    for s in neg_same:
        g_same[type_pair(s)].append(s)

    g_cross = defaultdict(list)
    for s in neg_cross:
        g_cross[type_pair(s)].append(s)

    picked_same = stratified_sample(g_same, min(target_same, len(neg_same)), seed=seed)
    picked_cross = stratified_sample(g_cross, min(target_cross, len(neg_cross)), seed=seed+1)

    # Nếu thiếu (pool không đủ), bù từ bucket còn lại
    picked = picked_same + picked_cross
    missing = target_neg - len(picked)

    if missing > 0:
        # bù từ những gì còn lại trong cross trước, rồi same
        rest_cross = []
        for lst in g_cross.values():
            rest_cross.extend(lst)
        rest_same = []
        for lst in g_same.values():
            rest_same.extend(lst)

        rng = random.Random(seed+2)
        rng.shuffle(rest_cross)
        rng.shuffle(rest_same)

        take = min(missing, len(rest_cross))
        picked += rest_cross[:take]
        missing -= take

        if missing > 0:
            take2 = min(missing, len(rest_same))
            picked += rest_same[:take2]
            missing -= take2

    balanced = pos + picked
    random.Random(seed).shuffle(balanced)

    # Stats
    c = Counter(s["relation"] for s in balanced)
    neg_pairs = Counter(type_pair(s) for s in balanced if s["relation"] == NO_REL)
    same_count = sum(1 for s in balanced if s["relation"] == NO_REL and is_same_type(s))

    Path(output_file).write_text(json.dumps(balanced, ensure_ascii=False, indent=2), encoding="utf-8")

    print("=== BALANCED DONE ===")
    print(f"Input: {input_file} | Output: {output_file}")
    print(f"Pos: {len(pos)}")
    print(f"Neg kept: {len(picked)} (target {target_neg})")
    print(f"  - same-type neg kept: {same_count} (~{same_count/max(1,len(picked)):.1%})")
    print("Relation breakdown:", dict(c))
    print("Top NoRel type-pairs:", neg_pairs.most_common(15))

if __name__ == "__main__":
    balance_dataset(
        input_file="full_data.json",
        output_file="full_data_balanced.json",
        neg_pos_ratio=2.0,       # thử 1.0 / 2.0 / 3.0
        same_type_fraction=0.3,  # thử 0.2 - 0.4
        seed=42
    )
# Out:
# === BALANCED DONE ===
# Input: full_data.json | Output: full_data_balanced.json
# Pos: 2316
# Neg kept: 4632 (target 4632)
#   - same-type neg kept: 1389 (~30.0%)
# Relation breakdown: {'No_Relation': 4632, 'HAS_MANIFESTATION': 1120, 'TREATED_WITH': 459, 'CAUSES': 537, 'REVEALS': 200}
# Top NoRel type-pairs: [('TREATMENT-DISEASE', 317), ('DISEASE-CAUSE', 317), ('DISEASE-DIAGNOSTIC', 316), ('TREATMENT-SYMPTOM', 316), ('SYMPTOM-TREATMENT', 316), ('SYMPTOM-DISEASE', 315), ('SYMPTOM-CAUSE', 308), ('CAUSE-SYMPTOM', 307), ('TREATMENT-TREATMENT', 278), ('SYMPTOM-SYMPTOM', 278), ('CAUSE-CAUSE', 278), ('DISEASE-DISEASE', 278), ('DIAGNOSTIC-DIAGNOSTIC', 277), ('SYMPTOM-DIAGNOSTIC', 139), ('DIAGNOSTIC-SYMPTOM', 136)]

# %%
import json
from collections import Counter
from pathlib import Path

INPUT_FILE = "full_data_balanced.json"
NO_REL = "No_Relation"

data = json.loads(Path(INPUT_FILE).read_text(encoding="utf-8"))

total = len(data)
rel_counter = Counter(s["relation"] for s in data)

print("=== FULL RELATION COUNT ===")
print("Total samples:", total)
print("\nRelation breakdown:")
for rel, cnt in rel_counter.most_common():
    ratio = cnt / total * 100
    print(f"{rel:20s} {cnt:6d} ({ratio:5.1f}%)")

print("\nPositive total:", total - rel_counter[NO_REL])
print("No_Relation total:", rel_counter[NO_REL])
# Out:
# === FULL RELATION COUNT ===
# Total samples: 6948
#
# Relation breakdown:
# No_Relation            4632 ( 66.7%)
# HAS_MANIFESTATION      1120 ( 16.1%)
# CAUSES                  537 (  7.7%)
# TREATED_WITH            459 (  6.6%)
# REVEALS                 200 (  2.9%)
#
# Positive total: 2316
# No_Relation total: 4632

# %%
import json
import random
from collections import defaultdict, Counter
from pathlib import Path

INPUT_FILE = "full_data_balanced.json"
OUT_TRAIN = "train_model.json"
OUT_DEV = "dev_model.json"
OUT_TEST = "test_model.json"

TRAIN_RATIO = 0.8
DEV_RATIO = 0.1
TEST_RATIO = 0.1

SEED = 42


def stratified_split(data, label_key="relation",
                     train_ratio=0.8, dev_ratio=0.1, seed=42):
    """
    Chia stratified theo label (relation).
    """
    rng = random.Random(seed)

    by_label = defaultdict(list)
    for item in data:
        by_label[item[label_key]].append(item)

    train, dev, test = [], [], []

    for label, items in by_label.items():
        rng.shuffle(items)
        n = len(items)

        n_train = int(n * train_ratio)
        n_dev = int(n * dev_ratio)
        n_test = n - n_train - n_dev  # phần còn lại

        train.extend(items[:n_train])
        dev.extend(items[n_train:n_train + n_dev])
        test.extend(items[n_train + n_dev:])

    rng.shuffle(train)
    rng.shuffle(dev)
    rng.shuffle(test)

    return train, dev, test


def save_json(path, data):
    Path(path).write_text(
        json.dumps(data, ensure_ascii=False, indent=2),
        encoding="utf-8"
    )


def print_stats(name, data):
    c = Counter(x["relation"] for x in data)
    print(f"\n{name}")
    print(f"  total: {len(data)}")
    for k, v in c.most_common():
        print(f"  {k:20s} {v}")


def main():
    data = json.loads(Path(INPUT_FILE).read_text(encoding="utf-8"))

    train, dev, test = stratified_split(
        data,
        train_ratio=TRAIN_RATIO,
        dev_ratio=DEV_RATIO,
        seed=SEED
    )

    save_json(OUT_TRAIN, train)
    save_json(OUT_DEV, dev)
    save_json(OUT_TEST, test)

    print("=== SPLIT DONE ===")
    print_stats("TRAIN", train)
    print_stats("DEV", dev)
    print_stats("TEST", test)


if __name__ == "__main__":
    main()
# Out:
# === SPLIT DONE ===
#
# TRAIN
#   total: 5557
#   No_Relation          3705
#   HAS_MANIFESTATION    896
#   CAUSES               429
#   TREATED_WITH         367
#   REVEALS              160
#
# DEV
#   total: 693
#   No_Relation          463
#   HAS_MANIFESTATION    112
#   CAUSES               53
#   TREATED_WITH         45
#   REVEALS              20
#
# TEST
#   total: 698
#   No_Relation          464
#   HAS_MANIFESTATION    112
#   CAUSES               55
#   TREATED_WITH         47
#   REVEALS              20

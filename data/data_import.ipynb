# %%
import re
import pandas as pd

from collections import Counter

# %%
import json


dataset = []
with open('../data/ViMedNER.txt', 'r', encoding='utf-8') as f:
    for dong in f:
        dataset.append(json.loads(dong.strip())) # .strip() để loại bỏ ký tự xuống dòng (\n) thừa

# %%
df = pd.DataFrame(dataset)
df.head()
# Out:
#      id                                               text  \
# 0  3504  kháng sinh dự phòng nếu đã được chỉ định trong...
# 1  3505  ngày nay các chuyên gia tin rằng viêm nội tâm ...
# 2  3506  hướng dẫn hiện nay khuyến cáo điều trị kháng s...
# 3  3507  bác sĩ vẫn có thể khuyên nên dùng kháng sinh p...
# 4  3508  đối với hầu hết những người có thông liên thất...
#
#                                       label Comments
# 0                     [[135, 163, DISEASE]]       []
# 1    [[33, 49, DISEASE], [101, 109, CAUSE]]       []
# 2                     [[129, 157, DISEASE]]       []
# 3                    [[84, 100, TREATMENT]]       []
# 4  [[31, 46, DISEASE], [160, 176, DISEASE]]       []

# %%
MAX_DISTANCE = 150

# %%
def calculate_distance(ent1, ent2):
    if ent1[1] < ent2[0]: return ent2[0] - ent1[1]
    elif ent2[1] < ent1[0]: return ent1[0] - ent2[1]
    return 0

# %%
import uuid
import json

# Giả định hàm calculate_distance và hằng số MAX_DISTANCE đã được định nghĩa ở trên
# MAX_DISTANCE = ...
# def calculate_distance(...): ...

ls_tasks = []

for row in dataset:
    text = row['text']
    origin_labels = row['label']
    
    task = {
        "data": {"text": text},
        "predictions": [{
            "model_version": "v1_rule_based",
            "result": []
        }]
    }
    
    entities_map = []
    
    # --- BƯỚC 1: Tạo Entities (Labels) ---
    for ent in origin_labels:
        start, end, label_name = ent
        
        region_id = str(uuid.uuid4())[:8]
        ner_result = {
            "id": region_id,
            "from_name": "label",
            "to_name": "text",
            "type": "labels",
            "value": {
                "start": start,
                "end": end,
                "text": text[start:end],
                "labels": [label_name]
            }
        }
        task["predictions"][0]["result"].append(ner_result)
        entities_map.append({
            "id": region_id,
            "start": start,
            "end": end,
            "label": label_name
        })

    # --- BƯỚC 2: Tạo Relations (Thực hiện sau khi đã có đủ hết entity của câu) ---
    # (Đưa đoạn này ra ngoài vòng lặp 'for ent in origin_labels')
    
    diseases = [e for e in entities_map if e['label'] == 'DISEASE']
    symptoms = [e for e in entities_map if e['label'] == 'SYMPTOM']
    treatments = [e for e in entities_map if e['label'] == 'TREATMENT']
    causes = [e for e in entities_map if e['label'] == 'CAUSE']
    diagnostics = [e for e in entities_map if e['label'] == 'DIAGNOSTIC']
    
    def add_relation(source, target, rel_name):
        dist = calculate_distance([source['start'], source['end']], 
                                  [target['start'], target['end']])
        if dist < MAX_DISTANCE:
            rel_result = {
                "from_id": source['id'],
                "to_id": target['id'],
                "type": "relation",
                "direction": "right",
                "labels": [rel_name]
            }
            task["predictions"][0]["result"].append(rel_result)
            
    # Rule: Disease -> Symptom
    for d in diseases:
        for s in symptoms:
            add_relation(d, s, "HAS_SYMPTOM")

    # Rule: Treatment -> Disease
    for t in treatments:
        for d in diseases:
            add_relation(t, d, "TREATS")

    # Rule: Cause -> Disease
    for c in causes:
        for d in diseases:
            add_relation(c, d, "CAUSES")
            
    # Rule: Diagnostic -> Disease
    for diag in diagnostics:
        for d in diseases:
            add_relation(diag, d, "DIAGNOSES")

    # --- BƯỚC 3: Append Task ---
    # (Quan trọng: Đặt ở đây, ngang hàng với 'task = ...', không thụt vào trong loop entity)
    ls_tasks.append(task)
        
with open("result_ls.json", 'w', encoding='utf-8') as f:
    json.dump(ls_tasks, f, ensure_ascii=False, indent=2)

# %%
ls_tasks
# Out:
# [{'data': {'text': 'kháng sinh dự phòng nếu đã được chỉ định trong quá khứ cần phải dùng kháng sinh trước khi thủ thuật nha khoa hoặc y tế để giảm nguy cơ viêm nội tâm mạc nhiễm khuẩn , nói chuyện với bác sĩ .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '378fc1fc',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 135,
#        'end': 163,
#        'text': 'viêm nội tâm mạc nhiễm khuẩn',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'ngày nay các chuyên gia tin rằng viêm nội tâm mạc nhiều hơn với khả năng xảy ra từ việc tiếp xúc với vi trùng một cách ngẫu nhiên hơn từ một thủ thuật nha khoa hoặc phẫu thuật điển hình .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': 'bb7dfc0d',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 33,
#        'end': 49,
#        'text': 'viêm nội tâm mạc',
#        'labels': ['DISEASE']}},
#      {'id': '33cae116',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 101,
#        'end': 109,
#        'text': 'vi trùng',
#        'labels': ['CAUSE']}},
#      {'from_id': '33cae116',
#       'to_id': 'bb7dfc0d',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['CAUSES']}]}]},
#  {'data': {'text': 'hướng dẫn hiện nay khuyến cáo điều trị kháng sinh dự phòng chỉ dành cho những người có nguy cơ cao bị biến chứng nghiêm trọng do viêm nội tâm mạc nhiễm khuẩn .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': 'd6e3f656',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 129,
#        'end': 157,
#        'text': 'viêm nội tâm mạc nhiễm khuẩn',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'bác sĩ vẫn có thể khuyên nên dùng kháng sinh phòng ngừa nếu : có một điều kiện hoặc van tim nhân tạo khác .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': 'ee47c3f8',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 84,
#        'end': 100,
#        'text': 'van tim nhân tạo',
#        'labels': ['TREATMENT']}}]}]},
#  {'data': {'text': 'đối với hầu hết những người có thông liên thất , thực hành tốt vệ sinh răng miệng và thường xuyên kiểm tra răng miệng là chiến lược hiệu quả nhất để phòng ngừa viêm nội tâm mạc .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '01d3fc76',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 31,
#        'end': 46,
#        'text': 'thông liên thất',
#        'labels': ['DISEASE']}},
#      {'id': '6293dfa4',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 160,
#        'end': 176,
#        'text': 'viêm nội tâm mạc',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'một đứa trẻ không thể đảo ngược tăng áp phổi ( hội chứng eisenmenger ) có hạn chế số lượng lớn nhất .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '6a7a2037',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 32,
#        'end': 44,
#        'text': 'tăng áp phổi',
#        'labels': ['DISEASE']}},
#      {'id': '286bd426',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 47,
#        'end': 68,
#        'text': 'hội chứng eisenmenger',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'mặc dù mọi trường hợp đều khác nhau , hãy nhớ rằng nhiều trẻ em bị dị thông liên thất phát triển cơ thể lành mạnh .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '7f8435b7',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 70,
#        'end': 85,
#        'text': 'thông liên thất',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'phòng chống trong hầu hết trường hợp , không thể làm bất cứ điều gì để ngăn chặn thông liên thất .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '7ed2b47c',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 81,
#        'end': 96,
#        'text': 'thông liên thất',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'nếu bị tiểu đường , làm việc với bác sĩ để chắc chắn nó được kiểm soát tốt trước khi mang thai .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '52cadb0f',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 7,
#        'end': 17,
#        'text': 'tiểu đường',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': ' biên tập viên : trần tiến phong đánh giá : trần trà my , trần phương phương định nghĩa bệnh viêm động mạch takayasu là một loại hiếm gặp của viêm mạch , một nhóm các rối loạn gây viêm mạch máu .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '35678fe7',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 88,
#        'end': 116,
#        'text': 'bệnh viêm động mạch takayasu',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'trong bệnh viêm động mạch takayasu , viêm tổn thương động mạch chủ - động mạch lớn mang máu từ tim tới phần còn lại của cơ thể - và các nhánh chính của động mạch chủ .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': 'a431fecf',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 6,
#        'end': 34,
#        'text': 'bệnh viêm động mạch takayasu',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'bệnh này có thể dẫn đến tắc nghẽn hoặc hẹp động mạch , hoặc động mạch giãn nở bất thường , gọi là chứng phình động mạch .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': 'ba805e04',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 60,
#        'end': 88,
#        'text': 'động mạch giãn nở bất thường',
#        'labels': ['SYMPTOM']}},
#      {'id': '764f45a5',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 98,
#        'end': 119,
#        'text': 'chứng phình động mạch',
#        'labels': ['DISEASE']}},
#      {'from_id': '764f45a5',
#       'to_id': 'ba805e04',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['HAS_SYMPTOM']}]}]},
#  {'data': {'text': 'bệnh viêm động mạch takayasu cũng có thể dẫn đến đau cánh tay hoặc đau ngực , huyết áp cao , và cuối cùng là suy tim hoặc đột quỵ .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '8751ca58',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 0,
#        'end': 28,
#        'text': 'bệnh viêm động mạch takayasu',
#        'labels': ['DISEASE']}},
#      {'id': '2fb9ba31',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 49,
#        'end': 61,
#        'text': 'đau cánh tay',
#        'labels': ['SYMPTOM']}},
#      {'id': '0c229ebc',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 67,
#        'end': 75,
#        'text': 'đau ngực',
#        'labels': ['SYMPTOM']}},
#      {'id': '8166d0ec',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 78,
#        'end': 90,
#        'text': 'huyết áp cao',
#        'labels': ['SYMPTOM']}},
#      {'id': '1341b437',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 109,
#        'end': 116,
#        'text': 'suy tim',
#        'labels': ['DISEASE']}},
#      {'id': 'f62c1c39',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 122,
#        'end': 129,
#        'text': 'đột quỵ',
#        'labels': ['DISEASE']}},
#      {'from_id': '8751ca58',
#       'to_id': '2fb9ba31',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['HAS_SYMPTOM']},
#      {'from_id': '8751ca58',
#       'to_id': '0c229ebc',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['HAS_SYMPTOM']},
#      {'from_id': '8751ca58',
#       'to_id': '8166d0ec',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['HAS_SYMPTOM']},
#      {'from_id': '1341b437',
#       'to_id': '2fb9ba31',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['HAS_SYMPTOM']},
#      {'from_id': '1341b437',
#       'to_id': '0c229ebc',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['HAS_SYMPTOM']},
#      {'from_id': '1341b437',
#       'to_id': '8166d0ec',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['HAS_SYMPTOM']},
#      {'from_id': 'f62c1c39',
#       'to_id': '2fb9ba31',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['HAS_SYMPTOM']},
#      {'from_id': 'f62c1c39',
#       'to_id': '0c229ebc',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['HAS_SYMPTOM']},
#      {'from_id': 'f62c1c39',
#       'to_id': '8166d0ec',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['HAS_SYMPTOM']}]}]},
#  {'data': {'text': 'ngay cả với phát hiện và điều trị sớm , tuy nhiên , bệnh viêm động mạch takayasu có thể là thách thức để quản lý .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '57c2fec6',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 52,
#        'end': 80,
#        'text': 'bệnh viêm động mạch takayasu',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'các triệu chứng các triệu chứng giai đoạn đầu bệnh viêm động mạch takayasu thường xảy ra trong hai giai đoạn .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '4e33a187',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 46,
#        'end': 74,
#        'text': 'bệnh viêm động mạch takayasu',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'mạch yếu hoặc vắng mặt ở cổ tay , viêm động mạch takayasu đôi khi gọi là bệnh mạch yếu vì động mạch thu hẹp có thể làm bắt mạch khó hoặc không thể phát hiện .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '62567389',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 34,
#        'end': 57,
#        'text': 'viêm động mạch takayasu',
#        'labels': ['DISEASE']}},
#      {'id': 'a390ab93',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 73,
#        'end': 86,
#        'text': 'bệnh mạch yếu',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'nhiều dấu hiệu và triệu chứng của bệnh viêm động mạch takayasu tương tự như những điều kiện khác , có thể làm cho chẩn đoán đầy thách thức .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '6dcaee3d',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 34,
#        'end': 62,
#        'text': 'bệnh viêm động mạch takayasu',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'nếu đã được chẩn đoán bệnh viêm động mạch takayasu , hãy ghi nhớ rằng các triệu chứng của bệnh bùng phát ( tái phát ) thường tương tự như đã xảy ra khi căn bệnh bắt đầu đầu tiên .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '5c2bb71c',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 22,
#        'end': 50,
#        'text': 'bệnh viêm động mạch takayasu',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'nguyên nhân trong bệnh viêm động mạch takayasu , động mạch chủ và động mạch lớn khác , bao gồm cả những mạch dẫn lên đầu và thận bị viêm .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '96a9aa30',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 18,
#        'end': 46,
#        'text': 'bệnh viêm động mạch takayasu',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'đôi khi động mạch trở nên giãn nở bất thường , dẫn đến chứng phình động mạch và có thể có vỡ .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': 'bf2ee2fd',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 55,
#        'end': 76,
#        'text': 'chứng phình động mạch',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'khả năng bệnh viêm động mạch takayasu là một bệnh tự miễn , trong đó trục trặc hệ thống miễn dịch và tấn công động mạch như thể nó là chất ngoại lai .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': 'ef45a70b',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 9,
#        'end': 37,
#        'text': 'bệnh viêm động mạch takayasu',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'các yếu tố nguy cơ bệnh viêm động mạch takayasu chủ yếu ảnh hưởng đến trẻ em gái và phụ nữ ở độ tuổi 20 và 30. rối loạn xảy ra trên toàn thế giới , nhưng phổ biến nhất ở phụ nữ châu á . các biến chứng mức độ nghiêm trọng của bệnh viêm động mạch takayasu có thể khác nhau .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '9ffffda0',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 19,
#        'end': 47,
#        'text': 'bệnh viêm động mạch takayasu',
#        'labels': ['DISEASE']}},
#      {'id': 'df1dbfd0',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 225,
#        'end': 253,
#        'text': 'bệnh viêm động mạch takayasu',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'suy tim do hở van động mạch chủ , viêm cơ tim hoặc động mạch chủ - tình trạng trong đó van động mạch chủ bị tổn thương cho phép máu trở lại vào tim - hoặc kết hợp .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '29d530c5',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 0,
#        'end': 7,
#        'text': 'suy tim',
#        'labels': ['DISEASE']}},
#      {'id': 'a88ef080',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 11,
#        'end': 31,
#        'text': 'hở van động mạch chủ',
#        'labels': ['CAUSE']}},
#      {'id': 'a1f03538',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 34,
#        'end': 45,
#        'text': 'viêm cơ tim',
#        'labels': ['DISEASE']}},
#      {'from_id': 'a88ef080',
#       'to_id': '29d530c5',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['CAUSES']},
#      {'from_id': 'a88ef080',
#       'to_id': 'a1f03538',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['CAUSES']}]}]},
#  {'data': {'text': 'đột quỵ , thiếu máu cục bộ , một loại đột quỵ xảy ra là kết quả của lưu lượng máu giảm hoặc bị tắc động mạch dẫn đến não .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '6c21dd26',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 0,
#        'end': 7,
#        'text': 'đột quỵ',
#        'labels': ['DISEASE']}},
#      {'id': '86b9ef07',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 38,
#        'end': 45,
#        'text': 'đột quỵ',
#        'labels': ['DISEASE']}},
#      {'id': '6cf72e33',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 68,
#        'end': 120,
#        'text': 'lưu lượng máu giảm hoặc bị tắc động mạch dẫn đến não',
#        'labels': ['CAUSE']}},
#      {'from_id': '6cf72e33',
#       'to_id': '6c21dd26',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['CAUSES']},
#      {'from_id': '6cf72e33',
#       'to_id': '86b9ef07',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['CAUSES']}]}]},
#  {'data': {'text': 'thiếu máu cục bộ thoáng qua , một cơn đột quỵ tạm thời có tất cả các triệu chứng của cơn đột quỵ , thiếu máu cục bộ mà không gây thiệt hại lâu dài .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '03a9012b',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 0,
#        'end': 27,
#        'text': 'thiếu máu cục bộ thoáng qua',
#        'labels': ['DISEASE']}},
#      {'id': 'bbdd72c3',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 38,
#        'end': 45,
#        'text': 'đột quỵ',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'chứng phình động mạch trong động mạch chủ , xảy ra khi thành của các mạch máu bị yếu đi và căng ra , có khả năng vỡ .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': 'a0da9ea3',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 0,
#        'end': 21,
#        'text': 'chứng phình động mạch',
#        'labels': ['DISEASE']}},
#      {'id': '79131566',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 55,
#        'end': 98,
#        'text': 'thành của các mạch máu bị yếu đi và căng ra',
#        'labels': ['CAUSE']}},
#      {'from_id': '79131566',
#       'to_id': 'a0da9ea3',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['CAUSES']}]}]},
#  {'data': {'text': 'nhồi máu cơ tim - mặc dù không phổ biến , nó có thể xảy ra là kết quả của giảm lưu lượng máu đến tim .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': 'cc0e7c03',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 0,
#        'end': 15,
#        'text': 'nhồi máu cơ tim',
#        'labels': ['DISEASE']}},
#      {'id': '6de8bc56',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 74,
#        'end': 100,
#        'text': 'giảm lưu lượng máu đến tim',
#        'labels': ['CAUSE']}},
#      {'from_id': '6de8bc56',
#       'to_id': 'cc0e7c03',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['CAUSES']}]}]},
#  {'data': {'text': 'trong các nghiên cứu , các phụ nữ mang thai với bệnh viêm động mạch takayasu , hầu hết phụ nữ sinh em bé khỏe mạnh .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': 'f6b25492',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 48,
#        'end': 76,
#        'text': 'bệnh viêm động mạch takayasu',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'nếu có bệnh viêm động mạch takayasu và đang có kế hoạch mang thai , điều quan trọng là làm việc với bác sĩ để phát triển một kế hoạch toàn diện để hạn chế biến chứng của thai kỳ trước khi thụ thai .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '15297844',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 7,
#        'end': 35,
#        'text': 'bệnh viêm động mạch takayasu',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'kiểm tra và chẩn đoán bệnh viêm động mạch takayasu có thể được kiểm tra để phát hiện , và một số người không có một chẩn đoán chính xác .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '0f72c937',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 22,
#        'end': 50,
#        'text': 'bệnh viêm động mạch takayasu',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'bác sĩ có thể sử dụng một số bước sau đây và kiểm tra để loại trừ các điều kiện khác gần tương tự như của bệnh viêm động mạch takayasu và xác định chẩn đoán : lịch sử y tế và khám lâm sàng .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': 'cb86056e',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 106,
#        'end': 134,
#        'text': 'bệnh viêm động mạch takayasu',
#        'labels': ['DISEASE']}},
#      {'id': '914af3ed',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 175,
#        'end': 188,
#        'text': 'khám lâm sàng',
#        'labels': ['DIAGNOSTIC']}},
#      {'from_id': '914af3ed',
#       'to_id': 'cb86056e',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['DIAGNOSES']}]}]},
#  {'data': {'text': 'bác sĩ sẽ kiểm tra và hỏi câu hỏi về sức khỏe chung , bao gồm các câu hỏi về tim và bệnh mạch máu .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': 'adc1ebfb',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 84,
#        'end': 97,
#        'text': 'bệnh mạch máu',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'bác sĩ có thể yêu cầu xét nghiệm máu để kiểm tra các dấu hiệu của viêm trong cơ thể , chẳng hạn như tế bào máu trắng hoặc mức c - reactive protein tăng cao .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': 'f3a95d66',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 100,
#        'end': 116,
#        'text': 'tế bào máu trắng',
#        'labels': ['DIAGNOSTIC']}},
#      {'id': 'ec5a488f',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 122,
#        'end': 155,
#        'text': 'mức c - reactive protein tăng cao',
#        'labels': ['DIAGNOSTIC']}}]}]},
#  {'data': {'text': 'xét nghiệm máu thường được sử dụng để giúp xác định rối loạn viêm nhiễm được gọi là tốc độ lắng hồng cầu ( ers ) .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '28b51959',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 84,
#        'end': 104,
#        'text': 'tốc độ lắng hồng cầu',
#        'labels': ['DIAGNOSTIC']}}]}]},
#  {'data': {'text': 'theo truyền thống , các bác sĩ sử dụng x quang chụp mạch kiểm tra , là một trong các kiểm tra dứt khoát hơn để chẩn đoán bệnh viêm động mạch takayasu .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '17131905',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 39,
#        'end': 56,
#        'text': 'x quang chụp mạch',
#        'labels': ['DIAGNOSTIC']}},
#      {'id': '50fbf60e',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 121,
#        'end': 149,
#        'text': 'bệnh viêm động mạch takayasu',
#        'labels': ['DISEASE']}},
#      {'from_id': '17131905',
#       'to_id': '50fbf60e',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['DIAGNOSES']}]}]},
#  {'data': {'text': 'một chất nhuộm đặc biệt ( tương phản ) sau đó được tiêm vào ống thông , và x quang được thực hiện khi nhuộm đầy động mạch hoặc tĩnh mạch .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '406a17f9',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 0,
#        'end': 69,
#        'text': 'một chất nhuộm đặc biệt ( tương phản ) sau đó được tiêm vào ống thông',
#        'labels': ['DIAGNOSTIC']}},
#      {'id': '61d018c2',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 75,
#        'end': 82,
#        'text': 'x quang',
#        'labels': ['DIAGNOSTIC']}}]}]},
#  {'data': {'text': 'càng ngày , các bác sĩ sử dụng hình thức ít xâm lấn hơn như chụp động mạch , là thử nghiệm cho bệnh viêm động mạch takayasu .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '1440fda8',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 60,
#        'end': 74,
#        'text': 'chụp động mạch',
#        'labels': ['DIAGNOSTIC']}},
#      {'id': '891d2703',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 95,
#        'end': 123,
#        'text': 'bệnh viêm động mạch takayasu',
#        'labels': ['DISEASE']}},
#      {'from_id': '1440fda8',
#       'to_id': '891d2703',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['DIAGNOSES']}]}]},
#  {'data': {'text': 'mra sản xuất hình ảnh chi tiết các mạch máu mà không cần sử dụng ống thông hay x quang , mặc dù tương phản thường được sử dụng .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': 'b180789e',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 0,
#        'end': 3,
#        'text': 'mra',
#        'labels': ['DIAGNOSTIC']}},
#      {'id': 'a2fb0790',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 65,
#        'end': 74,
#        'text': 'ống thông',
#        'labels': ['DIAGNOSTIC']}},
#      {'id': '13798817',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 79,
#        'end': 86,
#        'text': 'x quang',
#        'labels': ['DIAGNOSTIC']}}]}]},
#  {'data': {'text': 'mra hoạt động bằng cách sử dụng sóng vô tuyến trong một từ trường mạnh để sản xuất dữ liệu và máy tính biến thành hình ảnh chi tiết của mô lát .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '0c47a22f',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 0,
#        'end': 3,
#        'text': 'mra',
#        'labels': ['DIAGNOSTIC']}}]}]},
#  {'data': {'text': 'mri tương tự như mra ở chỗ nó sử dụng sóng vô tuyến và từ trường để tạo ra hình ảnh chi tiết của các cơ quan trong cơ thể và cho phép bác sĩ kiểm tra thiệt hại có thể xảy ra .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '46fd288b',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 0,
#        'end': 3,
#        'text': 'mri',
#        'labels': ['DIAGNOSTIC']}},
#      {'id': 'b96e317a',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 17,
#        'end': 20,
#        'text': 'mra',
#        'labels': ['DIAGNOSTIC']}}]}]},
#  {'data': {'text': 'đây là một hình thức không xâm lấn của chụp động mạch kết hợp phân tích trên máy vi tính của hình ảnh x quang , với việc sử dụng thuốc nhuộm tương phản để cho phép bác sĩ kiểm tra cấu trúc của động mạch chủ , các nhánh gần của nó , và theo dõi lưu lượng máu .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '261d269c',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 39,
#        'end': 53,
#        'text': 'chụp động mạch',
#        'labels': ['DIAGNOSTIC']}},
#      {'id': '7732a6bf',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 102,
#        'end': 109,
#        'text': 'x quang',
#        'labels': ['DIAGNOSTIC']}}]}]},
#  {'data': {'text': 'siêu âm doppler , có khả năng tạo ra hình ảnh có độ phân giải cao của thành động mạch nhất định , chẳng hạn như động mạch cảnh và động mạch dưới đòn .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': 'b2d06f69',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 0,
#        'end': 15,
#        'text': 'siêu âm doppler',
#        'labels': ['DIAGNOSTIC']}}]}]},
#  {'data': {'text': 'siêu âm doppler cũng có thể giúp phân biệt giữa bệnh viêm động mạch takayasu và xơ vữa động mạch , là tình trạng phổ biến hơn gây ra bởi sự tích tụ của các hạt cholesterol và các mảnh vỡ tế bào khác trong động mạch .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '1c0c2ac7',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 0,
#        'end': 15,
#        'text': 'siêu âm doppler',
#        'labels': ['DIAGNOSTIC']}},
#      {'id': '6e913486',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 48,
#        'end': 76,
#        'text': 'bệnh viêm động mạch takayasu',
#        'labels': ['DISEASE']}},
#      {'id': '56876c4f',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 80,
#        'end': 96,
#        'text': 'xơ vữa động mạch',
#        'labels': ['DISEASE']}},
#      {'from_id': '1c0c2ac7',
#       'to_id': '6e913486',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['DIAGNOSES']},
#      {'from_id': '1c0c2ac7',
#       'to_id': '56876c4f',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['DIAGNOSES']}]}]},
#  {'data': {'text': 'không giống như các loại viêm mạch , loại bỏ và phân tích mô ( sinh thiết ) không thường được sử dụng để chẩn đoán bệnh viêm động mạch takayasu .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '76f0ed33',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 115,
#        'end': 143,
#        'text': 'bệnh viêm động mạch takayasu',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'bởi vì bệnh viêm động mạch takayasu có xu hướng tái phát hoặc bùng lên sau khi thuyên giảm trong một thời gian , các xét nghiệm này có thể được sử dụng không chỉ để chẩn đoán mà còn để theo dõi tiến triển của bệnh và theo dõi hiệu quả điều trị .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': 'ba56fa9d',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 7,
#        'end': 35,
#        'text': 'bệnh viêm động mạch takayasu',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'một số thuốc dùng cho bệnh viêm động mạch takayasu có thể có tác dụng phụ có khả năng gây hại về lâu dài , vì vậy điều quan trọng là biết khi uống thuốc sẽ có rủi ro hay lợi ích lớn hơn .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '0d82def4',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 22,
#        'end': 50,
#        'text': 'bệnh viêm động mạch takayasu',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'takayasu đôi khi có thể khó điều trị bởi vì ngay cả khi thuyên giảm xuất hiện , bệnh có thể vẫn tiếp tục hoạt động âm thầm .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': 'a92618f3',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 0,
#        'end': 8,
#        'text': 'takayasu',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'tác dụng phụ dài hạn của corticosteroid bao gồm đục thủy tinh thể , lượng đường trong máu cao , nguy cơ tăng các bệnh nhiễm trùng , mất canxi xương , kinh nguyệt không đều , ức chế tuyến thượng thận sản xuất hormone , mỏng da , béo phì , dễ bị bầm tím và chậm lành vết thương .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '526d141d',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 25,
#        'end': 39,
#        'text': 'corticosteroid',
#        'labels': ['TREATMENT']}},
#      {'id': '17830063',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 48,
#        'end': 65,
#        'text': 'đục thủy tinh thể',
#        'labels': ['DISEASE']}},
#      {'id': '1e1a855a',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 68,
#        'end': 93,
#        'text': 'lượng đường trong máu cao',
#        'labels': ['SYMPTOM']}},
#      {'id': '939924dc',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 113,
#        'end': 129,
#        'text': 'bệnh nhiễm trùng',
#        'labels': ['DISEASE']}},
#      {'id': '04a4bb5a',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 150,
#        'end': 171,
#        'text': 'kinh nguyệt không đều',
#        'labels': ['SYMPTOM']}},
#      {'id': 'c132493c',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 218,
#        'end': 225,
#        'text': 'mỏng da',
#        'labels': ['SYMPTOM']}},
#      {'id': '0fde61fc',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 228,
#        'end': 235,
#        'text': 'béo phì',
#        'labels': ['SYMPTOM']}},
#      {'id': 'ff75dc02',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 244,
#        'end': 251,
#        'text': 'bầm tím',
#        'labels': ['SYMPTOM']}},
#      {'id': '0c8dc500',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 255,
#        'end': 275,
#        'text': 'chậm lành vết thương',
#        'labels': ['SYMPTOM']}},
#      {'from_id': '17830063',
#       'to_id': '1e1a855a',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['HAS_SYMPTOM']},
#      {'from_id': '17830063',
#       'to_id': '04a4bb5a',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['HAS_SYMPTOM']},
#      {'from_id': '939924dc',
#       'to_id': '1e1a855a',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['HAS_SYMPTOM']},
#      {'from_id': '939924dc',
#       'to_id': '04a4bb5a',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['HAS_SYMPTOM']},
#      {'from_id': '939924dc',
#       'to_id': 'c132493c',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['HAS_SYMPTOM']},
#      {'from_id': '939924dc',
#       'to_id': '0fde61fc',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['HAS_SYMPTOM']},
#      {'from_id': '939924dc',
#       'to_id': 'ff75dc02',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['HAS_SYMPTOM']},
#      {'from_id': '939924dc',
#       'to_id': '0c8dc500',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['HAS_SYMPTOM']},
#      {'from_id': '526d141d',
#       'to_id': '17830063',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['TREATS']},
#      {'from_id': '526d141d',
#       'to_id': '939924dc',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['TREATS']}]}]},
#  {'data': {'text': 'nếu tình trạng không đáp ứng tốt với corticosteroid hoặc gặp khó khăn khi giảm dần thuốc , có thể cần điều trị với các thuốc gây độc tế bào , chẳng hạn như methotrexate ( trexall , rheumatrex ) hoặc azathioprine ( imuran , azasan ) .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': 'fa782123',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 102,
#        'end': 139,
#        'text': 'điều trị với các thuốc gây độc tế bào',
#        'labels': ['TREATMENT']}},
#      {'id': '1beb631e',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 156,
#        'end': 168,
#        'text': 'methotrexate',
#        'labels': ['TREATMENT']}},
#      {'id': '3197b333',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 171,
#        'end': 178,
#        'text': 'trexall',
#        'labels': ['TREATMENT']}},
#      {'id': 'f03abfd4',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 181,
#        'end': 191,
#        'text': 'rheumatrex',
#        'labels': ['TREATMENT']}},
#      {'id': '28207c85',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 199,
#        'end': 211,
#        'text': 'azathioprine',
#        'labels': ['TREATMENT']}},
#      {'id': 'd7061891',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 214,
#        'end': 220,
#        'text': 'imuran',
#        'labels': ['TREATMENT']}},
#      {'id': 'e7ae98e0',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 223,
#        'end': 229,
#        'text': 'azasan',
#        'labels': ['TREATMENT']}}]}]},
#  {'data': {'text': 'có thể làm tăng tính nhạy cảm nhiễm trùng , cũng như nguy cơ phát triển khối u nút bạch huyết ( lymphoma ) và ung thư da .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '7ca9e881',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 30,
#        'end': 41,
#        'text': 'nhiễm trùng',
#        'labels': ['DISEASE']}},
#      {'id': '61a46b2d',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 110,
#        'end': 120,
#        'text': 'ung thư da',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'những loại thuốc này , bao gồm cả mycophenolate ( cellcepx ) , áp chế hệ thống miễn dịch , và đã có hiệu quả giảm viêm mạch máu ở những người có bệnh viêm động mạch takayasu .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': 'f3fb7521',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 145,
#        'end': 173,
#        'text': 'bệnh viêm động mạch takayasu',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'phẫu thuật nếu động mạch trở nên bị thu hẹp hoặc bị chặn , phẫu thuật có thể là cần thiết để mở hoặc bỏ qua nơi động mạch hẹp để cho phép dòng chảy máu liên tục .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '806ec76d',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 0,
#        'end': 10,
#        'text': 'phẫu thuật',
#        'labels': ['TREATMENT']}},
#      {'id': '3695e793',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 59,
#        'end': 69,
#        'text': 'phẫu thuật',
#        'labels': ['TREATMENT']}}]}]},
#  {'data': {'text': 'ngoài ra , nếu phát triển chứng phình động mạch lớn , phẫu thuật có thể cần thiết để ngăn chặn chúng vỡ .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '51bc8118',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 26,
#        'end': 51,
#        'text': 'chứng phình động mạch lớn',
#        'labels': ['DISEASE']}},
#      {'id': '33afaa6f',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 54,
#        'end': 64,
#        'text': 'phẫu thuật',
#        'labels': ['TREATMENT']}},
#      {'from_id': '33afaa6f',
#       'to_id': '51bc8118',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['TREATS']}]}]},
#  {'data': {'text': 'những thủ tục này , tốt nhất thực hiện khi chứng viêm các động mạch nặng bao gồm : phẫu thuật bắc cầu .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': 'd07754ce',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 83,
#        'end': 101,
#        'text': 'phẫu thuật bắc cầu',
#        'labels': ['TREATMENT']}}]}]},
#  {'data': {'text': 'đối phó và hỗ trợ khi bệnh viêm động mạch takayasu được xác định và điều trị sớm , tiên lượng thường là tốt .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': 'b7195623',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 22,
#        'end': 50,
#        'text': 'bệnh viêm động mạch takayasu',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'ăn cũng có thể giúp ngăn ngừa các vấn đề tiềm năng có thể ảnh hưởng đến tình trạng bệnh và tác dụng phụ của thuốc , chẳng hạn như huyết áp cao , loãng xương và bệnh tiểu đường .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': 'c39182e7',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 130,
#        'end': 142,
#        'text': 'huyết áp cao',
#        'labels': ['DISEASE']}},
#      {'id': 'd4fdf34b',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 145,
#        'end': 156,
#        'text': 'loãng xương',
#        'labels': ['DISEASE']}},
#      {'id': 'c0fbced1',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 160,
#        'end': 175,
#        'text': 'bệnh tiểu đường',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'hãy chắc chắn để có được số lượng đầy đủ canxi và vitamin d giúp ngăn ngừa loãng xương , một tác dụng phụ chủ yếu của điều trị bằng corticosteroid .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '6da6b0e4',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 75,
#        'end': 86,
#        'text': 'loãng xương',
#        'labels': ['DISEASE']}},
#      {'id': 'bc77b6e5',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 132,
#        'end': 146,
#        'text': 'corticosteroid',
#        'labels': ['TREATMENT']}},
#      {'from_id': 'bc77b6e5',
#       'to_id': '6da6b0e4',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['TREATS']}]}]},
#  {'data': {'text': 'nếu khó để có canxi từ chế độ ăn uống bởi vì không ăn các sản phẩm từ sữa , ví dụ , hãy nói chuyện với bác sĩ về bổ sung canxi , thường được kết hợp với vitamin d và có thể giúp chống loãng xương .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '4d4c8f8b',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 113,
#        'end': 126,
#        'text': 'bổ sung canxi',
#        'labels': ['TREATMENT']}},
#      {'id': '2ee19e14',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 153,
#        'end': 162,
#        'text': 'vitamin d',
#        'labels': ['TREATMENT']}},
#      {'id': '40f8a1a8',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 184,
#        'end': 195,
#        'text': 'loãng xương',
#        'labels': ['DISEASE']}},
#      {'from_id': '4d4c8f8b',
#       'to_id': '40f8a1a8',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['TREATS']},
#      {'from_id': '2ee19e14',
#       'to_id': '40f8a1a8',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['TREATS']}]}]},
#  {'data': {'text': 'tập thể dục thường xuyên , chẳng hạn như đi bộ , có thể giúp ngăn ngừa mất xương , huyết áp cao và tiểu đường .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '38df6856',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 0,
#        'end': 24,
#        'text': 'tập thể dục thường xuyên',
#        'labels': ['TREATMENT']}},
#      {'id': 'c0f783e2',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 83,
#        'end': 95,
#        'text': 'huyết áp cao',
#        'labels': ['DISEASE']}},
#      {'id': '49f05b30',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 99,
#        'end': 109,
#        'text': 'tiểu đường',
#        'labels': ['DISEASE']}},
#      {'from_id': '38df6856',
#       'to_id': 'c0f783e2',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['TREATS']},
#      {'from_id': '38df6856',
#       'to_id': '49f05b30',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['TREATS']}]}]},
#  {'data': {'text': 'khuyết tật vách liên nhĩ thất , xảy ra khi có lỗ giữa các buồng tim và các vấn đề với van tim , điều chỉnh lưu lượng máu trong tim .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '6cf068f3',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 0,
#        'end': 29,
#        'text': 'khuyết tật vách liên nhĩ thất',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'nếu không chữa trị , khiếm khuyết kênh nhĩ thất có thể gây ra suy tim và tăng áp động mạch phổi .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': 'd0c2fc91',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 21,
#        'end': 47,
#        'text': 'khiếm khuyết kênh nhĩ thất',
#        'labels': ['DISEASE']}},
#      {'id': 'e8b9bae9',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 62,
#        'end': 69,
#        'text': 'suy tim',
#        'labels': ['DISEASE']}},
#      {'id': '81ea49cc',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 73,
#        'end': 95,
#        'text': 'tăng áp động mạch phổi',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'để khắc phục lỗi này , các bác sĩ thường khuyên nên phẫu thuật trong năm đầu tiên của cuộc sống để đóng lỗ và tái tạo lại các van .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '64364f09',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 52,
#        'end': 62,
#        'text': 'phẫu thuật',
#        'labels': ['TREATMENT']}}]}]},
#  {'data': {'text': 'kênh nhĩ thất hoàn toàn các dấu hiệu và triệu chứng của kênh truyền nhĩ thất hoàn toàn thường phát triển trong vài tuần đầu tiên của cuộc sống .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '12918284',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 0,
#        'end': 23,
#        'text': 'kênh nhĩ thất hoàn toàn',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'nếu em bé có kênh truyền nhĩ thất hoàn toàn , cũng có thể phát triển các dấu hiệu và triệu chứng của suy tim , bao gồm : mệt mỏi .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': 'b7552171',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 13,
#        'end': 43,
#        'text': 'kênh truyền nhĩ thất hoàn toàn',
#        'labels': ['DISEASE']}},
#      {'id': '5ca87421',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 101,
#        'end': 108,
#        'text': 'suy tim',
#        'labels': ['DISEASE']}},
#      {'id': 'e4ae1b65',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 121,
#        'end': 128,
#        'text': 'mệt mỏi',
#        'labels': ['SYMPTOM']}},
#      {'from_id': 'b7552171',
#       'to_id': 'e4ae1b65',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['HAS_SYMPTOM']},
#      {'from_id': '5ca87421',
#       'to_id': 'e4ae1b65',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['HAS_SYMPTOM']}]}]},
#  {'data': {'text': 'kênh nhĩ thất một phần các dấu hiệu và triệu chứng của kênh truyền nhĩ thất một phần có thể không xuất hiện cho đến tuổi trưởng thành .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '95ed2dcb',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 0,
#        'end': 22,
#        'text': 'kênh nhĩ thất một phần',
#        'labels': ['DISEASE']}},
#      {'id': '09e84a5a',
#       'from_name': 'label',
# ...
#       'type': 'labels',
#       'value': {'start': 74,
#        'end': 84,
#        'text': 'bệnh crohn',
#        'labels': ['DISEASE']}},
#      {'from_id': 'd8148b31',
#       'to_id': 'ca600978',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['CAUSES']},
#      {'from_id': '45b25112',
#       'to_id': 'ca600978',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['CAUSES']}]}]},
#  {'data': {'text': 'các nhà khoa học tiếp tục tìm kiếm những đột biến gen khác có thể đóng một vai trò trong crohn .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': 'd5eca6fc',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 41,
#        'end': 53,
#        'text': 'đột biến gen',
#        'labels': ['CAUSE']}},
#      {'id': 'a81bce02',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 89,
#        'end': 94,
#        'text': 'crohn',
#        'labels': ['DISEASE']}},
#      {'from_id': 'd5eca6fc',
#       'to_id': 'a81bce02',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['CAUSES']}]}]},
#  {'data': {'text': 'crohn có thể xảy ra ở mọi lứa tuổi , nhưng có khả năng để phát triển các điều kiện khi còn trẻ .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '29d1376b',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 0,
#        'end': 5,
#        'text': 'crohn',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'nếu sống ở một khu vực đô thị hoặc ở một nước công nghiệp , có nhiều khả năng phát triển bệnh crohn .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '20c93044',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 89,
#        'end': 99,
#        'text': 'bệnh crohn',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'bởi vì bệnh crohn xảy ra thường xuyên hơn giữa những người sống ở các thành phố và các quốc gia công nghiệp , nó có thể là các yếu tố môi trường , bao gồm chế độ ăn giàu chất béo trong thực phẩm hoặc tinh chế , đóng vai trò trong bệnh crohn .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '28e02074',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 7,
#        'end': 17,
#        'text': 'bệnh crohn',
#        'labels': ['DISEASE']}},
#      {'id': 'b24ce4e7',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 230,
#        'end': 240,
#        'text': 'bệnh crohn',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'isotretinoin ( accutane ) là một thuốc đôi khi được dùng để điều trị sẹo mụn trứng cá nang hoặc mụn mà không đáp ứng với điều trị khác .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '0f2bf5bb',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 0,
#        'end': 12,
#        'text': 'isotretinoin',
#        'labels': ['TREATMENT']}},
#      {'id': '9ac45ea4',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 15,
#        'end': 23,
#        'text': 'accutane',
#        'labels': ['TREATMENT']}},
#      {'id': 'cadbe942',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 73,
#        'end': 90,
#        'text': 'mụn trứng cá nang',
#        'labels': ['DISEASE']}},
#      {'from_id': '0f2bf5bb',
#       'to_id': 'cadbe942',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['TREATS']},
#      {'from_id': '9ac45ea4',
#       'to_id': 'cadbe942',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['TREATS']}]}]},
#  {'data': {'text': 'mặc dù nguyên nhân và hiệu lực chưa được chứng minh , các nghiên cứu đã báo cáo sự phát triển của bệnh viêm ruột với việc sử dụng isotretinoin .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '8ddac281',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 98,
#        'end': 112,
#        'text': 'bệnh viêm ruột',
#        'labels': ['DISEASE']}},
#      {'id': '7e47bc70',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 142,
#        'end': 143,
#        'text': ' ',
#        'labels': ['TREATMENT']}},
#      {'from_id': '7e47bc70',
#       'to_id': '8ddac281',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['TREATS']}]}]},
#  {'data': {'text': 'mặc dù các thuốc này - ibuprofen , naproxen , diclofenac , piroxicam và những thuốc khác đã không được chứng minh gây ra bệnh crohn , nó có thể gây ra các dấu hiệu và triệu chứng tương tự .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '9fada3b5',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 23,
#        'end': 32,
#        'text': 'ibuprofen',
#        'labels': ['TREATMENT']}},
#      {'id': '83adfe27',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 35,
#        'end': 43,
#        'text': 'naproxen',
#        'labels': ['TREATMENT']}},
#      {'id': '9bf68868',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 46,
#        'end': 56,
#        'text': 'diclofenac',
#        'labels': ['TREATMENT']}},
#      {'id': '237fedd1',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 59,
#        'end': 68,
#        'text': 'piroxicam',
#        'labels': ['TREATMENT']}},
#      {'id': '3123ad7e',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 121,
#        'end': 131,
#        'text': 'bệnh crohn',
#        'labels': ['DISEASE']}},
#      {'from_id': '9fada3b5',
#       'to_id': '3123ad7e',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['TREATS']},
#      {'from_id': '83adfe27',
#       'to_id': '3123ad7e',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['TREATS']},
#      {'from_id': '9bf68868',
#       'to_id': '3123ad7e',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['TREATS']},
#      {'from_id': '237fedd1',
#       'to_id': '3123ad7e',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['TREATS']}]}]},
#  {'data': {'text': 'tiêu chảy , đau bụng và co thắt có thể gây khó khăn để ăn hoặc cho ruột hấp thụ chất dinh dưỡng .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '824e9b11',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 0,
#        'end': 9,
#        'text': 'tiêu chảy',
#        'labels': ['DISEASE']}},
#      {'id': 'fb162377',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 12,
#        'end': 20,
#        'text': 'đau bụng',
#        'labels': ['SYMPTOM']}},
#      {'id': 'b3ddc8a0',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 24,
#        'end': 31,
#        'text': 'co thắt',
#        'labels': ['SYMPTOM']}},
#      {'from_id': '824e9b11',
#       'to_id': 'fb162377',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['HAS_SYMPTOM']},
#      {'from_id': '824e9b11',
#       'to_id': 'b3ddc8a0',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['HAS_SYMPTOM']}]}]},
#  {'data': {'text': 'ngoài viêm và loét ở đường tiêu hóa , crohn có thể gây ra vấn đề trong các bộ phận khác của cơ thể , chẳng hạn như viêm khớp , viêm mắt hoặc da , móng tay hình trùy , sỏi thận , sỏi mật và đôi khi viêm ống dẫn mật .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': 'b7be03da',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 38,
#        'end': 43,
#        'text': 'crohn',
#        'labels': ['DISEASE']}},
#      {'id': '78fe3eea',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 115,
#        'end': 124,
#        'text': 'viêm khớp',
#        'labels': ['DISEASE']}},
#      {'id': 'b68930e2',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 127,
#        'end': 135,
#        'text': 'viêm mắt',
#        'labels': ['DISEASE']}},
#      {'id': '5fdf16b6',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 146,
#        'end': 164,
#        'text': 'móng tay hình trùy',
#        'labels': ['SYMPTOM']}},
#      {'id': 'dfa764af',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 167,
#        'end': 175,
#        'text': 'sỏi thận',
#        'labels': ['DISEASE']}},
#      {'id': 'f74b8ad8',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 178,
#        'end': 185,
#        'text': 'sỏi mật',
#        'labels': ['DISEASE']}},
#      {'id': 'ec041942',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 197,
#        'end': 213,
#        'text': 'viêm ống dẫn mật',
#        'labels': ['DISEASE']}},
#      {'from_id': 'b7be03da',
#       'to_id': '5fdf16b6',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['HAS_SYMPTOM']},
#      {'from_id': '78fe3eea',
#       'to_id': '5fdf16b6',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['HAS_SYMPTOM']},
#      {'from_id': 'b68930e2',
#       'to_id': '5fdf16b6',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['HAS_SYMPTOM']},
#      {'from_id': 'dfa764af',
#       'to_id': '5fdf16b6',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['HAS_SYMPTOM']},
#      {'from_id': 'f74b8ad8',
#       'to_id': '5fdf16b6',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['HAS_SYMPTOM']},
#      {'from_id': 'ec041942',
#       'to_id': '5fdf16b6',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['HAS_SYMPTOM']}]}]},
#  {'data': {'text': 'mặc dù nguy cơ này tăng lên , hơn 90 phần trăm những người bị bệnh viêm ruột không bao giờ phát triển ung thư .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': 'e12bf95d',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 62,
#        'end': 76,
#        'text': 'bệnh viêm ruột',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'nguy cơ lớn nhất là nếu đã bị bệnh viêm ruột ít nhất tám năm và nếu nó đã lây lan qua toàn bộ đại tràng .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '054a2d10',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 30,
#        'end': 44,
#        'text': 'bệnh viêm ruột',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'đã có các bệnh và các khu vực bị ảnh hưởng lớn hơn , nguy cơ bệnh ung thư ruột kết càng lớn .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '2bbc71b5',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 66,
#        'end': 78,
#        'text': 'ung thư ruột',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'trong khi các loại thuốc này làm tăng rủi ro , nó có thể cần thiết cho những người bị bệnh crohn để cải thiện chất lượng cuộc sống và tránh phẫu thuật hoặc nhập viện .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': 'c58e5bc2',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 86,
#        'end': 96,
#        'text': 'bệnh crohn',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'kiểm tra và chẩn đoán bác sĩ có khả năng chẩn đoán bệnh crohn chỉ sau khi loại trừ các nguyên nhân khác có thể có các dấu hiệu và triệu chứng , bao gồm hội chứng ruột kích thích ( ibs ) , viêm túi thừa và ung thư ruột kết .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '2f16829a',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 51,
#        'end': 61,
#        'text': 'bệnh crohn',
#        'labels': ['DISEASE']}},
#      {'id': '313b9331',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 152,
#        'end': 177,
#        'text': 'hội chứng ruột kích thích',
#        'labels': ['DISEASE']}},
#      {'id': 'f99c7d4c',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 180,
#        'end': 183,
#        'text': 'ibs',
#        'labels': ['DISEASE']}},
#      {'id': '7eddc9db',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 188,
#        'end': 201,
#        'text': 'viêm túi thừa',
#        'labels': ['DISEASE']}},
#      {'id': '8e46ee06',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 205,
#        'end': 221,
#        'text': 'ung thư ruột kết',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'để giúp xác nhận chẩn đoán bệnh crohn có thể có một hoặc nhiều xét nghiệm và thủ tục sau đây : xét nghiệm máu .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '65d12c15',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 27,
#        'end': 37,
#        'text': 'bệnh crohn',
#        'labels': ['DISEASE']}},
#      {'id': 'bee127c6',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 95,
#        'end': 109,
#        'text': 'xét nghiệm máu',
#        'labels': ['DIAGNOSTIC']}},
#      {'from_id': 'bee127c6',
#       'to_id': '65d12c15',
#       'type': 'relation',
#       'direction': 'right',
#       'labels': ['DIAGNOSES']}]}]},
#  {'data': {'text': 'bác sĩ có thể đề nghị xét nghiệm máu để kiểm tra xem có thiếu máu - một tình trạng mà trong đó không có đủ tế bào hồng cầu mang ôxy đến các mô hoặc để kiểm tra các dấu hiệu nhiễm trùng .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '1b2e6b2e',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 22,
#        'end': 36,
#        'text': 'xét nghiệm máu',
#        'labels': ['DIAGNOSTIC']}}]}]},
#  {'data': {'text': 'hai xét nghiệm tìm sự hiện diện của kháng thể nào đó đôi khi có thể giúp chẩn đoán loại hình bệnh viêm ruột , nhưng tất cả mọi người không bị bệnh crohn hoặc viêm loét đại tràng cũng có các kháng thể .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': '299fa835',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 93,
#        'end': 107,
#        'text': 'bệnh viêm ruột',
#        'labels': ['DISEASE']}},
#      {'id': '3eafe510',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 142,
#        'end': 152,
#        'text': 'bệnh crohn',
#        'labels': ['DISEASE']}},
#      {'id': 'e2fed929',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 158,
#        'end': 177,
#        'text': 'viêm loét đại tràng',
#        'labels': ['DISEASE']}}]}]},
#  {'data': {'text': 'trong khi bác sĩ có thể chỉ định các xét nghiệm này , phát hiện dương tính không có nghĩa là có bệnh crohn và âm tính không có nghĩa là đang không có bệnh .'},
#   'predictions': [{'model_version': 'v1_rule_based',
#     'result': [{'id': 'f1bd2704',
#       'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'value': {'start': 96,
#        'end': 106,
#        'text': 'bệnh crohn',
#        'labels': ['DISEASE']}}]}]},
#  ...]

# %%
import json

def get_items_with_multiple_relations(data_list):
    """
    Trả về danh sách các item (dict) có số lượng relation > 1.
    """
    complex_items = [] # List chứa kết quả
    
    for item in data_list:
        predictions = item.get("predictions", [])
        
        if not predictions:
            continue
        
        # Lấy danh sách kết quả từ prediction đầu tiên
        results = predictions[0].get("result", [])
        
        # Đếm số relation
        num_relations = sum(1 for r in results if r.get("type") == "relation")
        
        # Nếu > 1 thì thêm toàn bộ item đó vào list
        if num_relations > 1:
            complex_items.append(item)
            
    return complex_items

filtered_list = get_items_with_multiple_relations(ls_tasks)

print(f"Tổng số câu tìm thấy: {len(filtered_list)}")


print("\n--- Ví dụ các câu tìm được ---")
for i, item in enumerate(filtered_list[:3]): # In 3 câu đầu
    text = item['data']['text']
    rels = sum(1 for r in item['predictions'][0]['result'] if r['type'] == 'relation')
    print(f"Câu {i+1} (Relations: {rels}): {text[:100]}...")

with open("complex_sentences_only.json", "w", encoding="utf-8") as f:
    json.dump(filtered_list, f, ensure_ascii=False, indent=2)
print("\nĐã lưu danh sách lọc ra file 'complex_sentences_only.json'")
# Out:
# Tổng số câu tìm thấy: 1543
#
# --- Ví dụ các câu tìm được ---
# Câu 1 (Relations: 9): bệnh viêm động mạch takayasu cũng có thể dẫn đến đau cánh tay hoặc đau ngực , huyết áp cao , và cuối...
# Câu 2 (Relations: 2): suy tim do hở van động mạch chủ , viêm cơ tim hoặc động mạch chủ - tình trạng trong đó van động mạch...
# Câu 3 (Relations: 2): đột quỵ , thiếu máu cục bộ , một loại đột quỵ xảy ra là kết quả của lưu lượng máu giảm hoặc bị tắc đ...
#
# Đã lưu danh sách lọc ra file 'complex_sentences_only.json'

# %%
with open("result_ls_.json", 'w', encoding='utf-8') as f:
    json.dump(ls_tasks, f, ensure_ascii=False, indent=2)
